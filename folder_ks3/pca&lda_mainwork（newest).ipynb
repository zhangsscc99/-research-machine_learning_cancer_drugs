# %%
#a code block that deals with concentration and drug names
#we do not use this block for now.

import pandas as pd
f1 = pd.read_csv('B.csv')
f2 = pd.read_csv('C.csv')
f3=pd.read_csv('D.csv')
f4=pd.read_csv('E.csv')
f5=pd.read_csv('A_ks3.csv')
file = [f1,f2,f3,f5]
train = pd.concat(file,axis=1)
train.to_csv("train.csv", index=0, sep=',')

# %%
#do some further processing with "A" because there are some data error in it
def remove_extradots(string):
    counter=0
    lst=[]
    for i in range(len(string)):
        if string[i]=='.' and counter<1 :
            lst.append(string[i])
            counter+=1
        elif string[i]!='.':
            lst.append(string[i])
    res="".join(lst)
    return res



import csv
res_list=[]
print(remove_extradots("-0.29444.2"))
with open('A_ks3.csv') as file2:
    reader=csv.reader(file2)

    for row in reader:
        data=[]
        for i in range(len(row)):
            
            data.append(remove_extradots(row[i]))
        res_list.append(data)
    


with open('modified_A.csv', 'w') as file3:
    writer = csv.writer(file3)
    writer.writerows(res_list)
file3.close()
# Out:
# -0.294442

# %%
#test file A
import pandas as pd
df_A=pd.read_csv("A_ks3.csv")
df_A.shape
#df_A2=pd.read_csv("A_modified.csv")
#df_A2.shape
# Out:
# (767, 239)

# %%
#a block that is used to concate the drug names(drug combinations and related concentration)

import csv
res_list=[]
with open('train.csv', 'r') as file:
    reader = csv.reader(file)
    
    for row in reader:
        data=[]
        data.append(row[0]+'+'+row[1]+"+"+row[2])
        res_list.append(data)

        
        
with open('concatenated.csv', 'w') as file2:
    writer = csv.writer(file2)
    writer.writerows(res_list)

# %%
#a block that is used to concate concentration and ks numbers.
import pandas as pd
f1 = pd.read_csv('concatenated.csv')
#f2 = pd.read_csv('C.csv')
f3=pd.read_csv('D.csv')
f4=pd.read_csv('E.csv')
f5=pd.read_csv('modified_A.csv')
file = [f1,f5]
train = pd.concat(file,axis=1)
train.to_csv("train3.csv", index=0, sep=',')

# %%
#a block that sets the fields for the drug data
import csv
fields=['drug_name','default']
for i in range(1,239):
    fields.append('ks'+str(i))
rows=[]
with open('train3.csv', 'r') as file:
    reader = csv.reader(file)
    
    for row in reader:
        rows.append(row)

        
        
with open('drug_withfields2.csv', 'w') as file2:
    writer = csv.writer(file2)
    writer.writerow(fields)
    writer.writerows(rows)

# %%
#do some further processing with "drug_withfields" because there are still some data error in it
def remove_extradots(string):
    counter=0
    lst=[]
    for i in range(len(string)):
        if string[i]=='.' and counter<1 :
            lst.append(string[i])
            counter+=1
        elif string[i]!='.':
            lst.append(string[i])
    res="".join(lst)
    return res



import csv
res_list=[]
print(remove_extradots("-0.29444.2"))
with open('drug_withfields2.csv') as file2:
    reader=csv.reader(file2)

    for row in reader:
        data=[]
        for i in range(len(row)):
            
            data.append(remove_extradots(row[i]))
        res_list.append(data)
    


with open('drug_with_fields.csv', 'w') as file3:
    writer = csv.writer(file3)
    writer.writerows(res_list)
file3.close()
# Out:
# -0.294442

# %%
#we take etoposide and palitaxel out. 
df=pd.read_csv('drug_with_fields.csv')
df11=df.loc[(df['drug_name'] =='Etoposide+Etoposide+1') ]
df12=df.loc[(df['drug_name'] =='Etoposide+Etoposide+2') ]
df13=df.loc[(df['drug_name'] =='Etoposide+Etoposide+3') ]
df14=df.loc[(df['drug_name'] =='Etoposide+Etoposide+4') ]
df15=df.loc[(df['drug_name'] =='Etoposide+Etoposide+5') ]
df16=df.loc[(df['drug_name'] =='Etoposide+Etoposide+6') ]
df21=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+1') ]
df22=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+2') ]
df23=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+3') ]
df24=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+4') ]
df25=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+5') ]
df26=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+6') ]
df31=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+1')]
df32=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+2')]
df33=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+3')]
df34=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+4')]
df35=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+5')]
df36=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+6')]
df41=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+1') ]
df42=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+2') ]
df43=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+3') ]
df44=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+4') ]
df45=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+5') ]
df46=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+6') ]
#df51=df.loc[(df['drug_name'] =='DMSO+DMSO+1') ]
#df52=df.loc[(df['drug_name'] =='DMSO+DMSO+2') ]
##df53=df.loc[(df['drug_name'] =='DMSO+DMSO+3') ]
#df54=df.loc[(df['drug_name'] =='DMSO+DMSO+4') ]
#df55=df.loc[(df['drug_name'] =='DMSO+DMSO+5') ]
#df56=df.loc[(df['drug_name'] =='DMSO+DMSO+6') ]


frames = [df11, df12,df13,df14,df15,df16,df21,df22,df23,df24,df25,df26,df31,df32,df33,df34,df35,df36,df41,df42,df43,df44,df45,df46]

e_and_p = pd.concat(frames)
#etoposide and paclitaxel combination. 
e_and_p
# Out:
#                    drug_name  default       ks1       ks2       ks3       ks4  \
# 0      Etoposide+Etoposide+1        0 -0.658330 -0.151980 -0.133790 -0.228720
# 2      Etoposide+Etoposide+2        0 -0.596670 -0.183410 -0.224890 -0.310260
# 4      Etoposide+Etoposide+3        0 -0.507540  0.080714 -0.125940  0.104190
# 6      Etoposide+Etoposide+4        0 -0.053269 -0.097863 -0.140810 -0.122950
# 8      Etoposide+Etoposide+5        0  0.038568 -0.070623 -0.084830 -0.055402
# 10     Etoposide+Etoposide+6        0 -0.021682 -0.073558 -0.087733 -0.079325
# 144  Paclitaxel+Paclitaxel+1        0 -0.955000  0.224410  0.305000 -0.150050
#  -0.50092528 -1.33851564 -1.4141126   0.93331226  1.30482205  0.92954011
#  -1.56548149 -1.52531947  1.22297895  0.87596595 -1.51394904 -1.52059283
#  -1.09399448 -1.50411467 -1.77180313  1.07973343  0.28741188 -0.92219549
#   0.67301653 -1.55582586 -1.54021134 -1.63712028 -1.59669177  1.67655421
#   1.73381979 -1.40081945 -1.4874265   1.20502001 -0.91678382  1.41949515
#  -1.64448486 -1.34006299 -1.60737825 -1.04319662 -0.82525017  0.96849976
#  -1.54710648 -1.40082645 -0.82525856  0.89906541  1.22395008  0.80984053
#   0.1098733  -1.37533939  1.072211    1.25802221  1.16017172  1.06344592
#   0.45958835 -2.23573934  1.03507024  0.8990708   0.4595892  -1.56498692
#  -1.5708676  -0.85184873  1.95626293]

# %%
#see that again
from sklearn.decomposition import PCA
pca = PCA(n_components = 0.99)
pca.fit(X_drug)
reduced = pca.transform(X_drug)
print(len(X_drug[0]))
print(len(reduced[0]))
print(pca.explained_variance_ratio_)
# Out:
# 237
# 16
# [0.49117067 0.17332128 0.11884371 0.06738595 0.04629258 0.02173223
#  0.01602839 0.01303493 0.01009131 0.00729044 0.00694337 0.00569477
#  0.00445214 0.00378925 0.00293235 0.00234187]

# %%
#we take etoposide and palitaxel out. 
df=pd.read_csv('drug_with_fields.csv')
df11=df.loc[(df['drug_name'] =='Etoposide+Etoposide+1') ]
df12=df.loc[(df['drug_name'] =='Etoposide+Etoposide+2') ]
df13=df.loc[(df['drug_name'] =='Etoposide+Etoposide+3') ]
df14=df.loc[(df['drug_name'] =='Etoposide+Etoposide+4') ]
df15=df.loc[(df['drug_name'] =='Etoposide+Etoposide+5') ]
df16=df.loc[(df['drug_name'] =='Etoposide+Etoposide+6') ]
df21=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+1') ]
df22=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+2') ]
df23=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+3') ]
df24=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+4') ]
df25=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+5') ]
df26=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+6') ]
df31=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+1')]
df32=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+2')]
df33=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+3')]
df34=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+4')]
df35=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+5')]
df36=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+6')]
df41=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+1') ]
df42=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+2') ]
df43=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+3') ]
df44=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+4') ]
df45=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+5') ]
df46=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+6') ]
df51=df.loc[(df['drug_name'] =='DMSO+DMSO+1') ]
df52=df.loc[(df['drug_name'] =='DMSO+DMSO+2') ]
df53=df.loc[(df['drug_name'] =='DMSO+DMSO+3') ]
df54=df.loc[(df['drug_name'] =='DMSO+DMSO+4') ]
df55=df.loc[(df['drug_name'] =='DMSO+DMSO+5') ]
df56=df.loc[(df['drug_name'] =='DMSO+DMSO+6') ]


frames = [df11, df12,df13,df14,df15,df16,df21,df22,df23,df24,df25,df26,df31,df32,df33,df34,df35,df36,df41,df42,df43,df44,df45,df46,df51,df52,df53,df54,df55,df56]

e_and_p = pd.concat(frames)
#etoposide and paclitaxel combination. 
e_and_p.iloc[:24,:]
# Out:
#                    drug_name  default       ks1       ks2       ks3       ks4  \
# 0      Etoposide+Etoposide+1        0 -0.658330 -0.151980 -0.133790 -0.228720
# 2      Etoposide+Etoposide+2        0 -0.596670 -0.183410 -0.224890 -0.310260
# 4      Etoposide+Etoposide+3        0 -0.507540  0.080714 -0.125940  0.104190
# 6      Etoposide+Etoposide+4        0 -0.053269 -0.097863 -0.140810 -0.122950
# 8      Etoposide+Etoposide+5        0  0.038568 -0.070623 -0.084830 -0.055402
# 10     Etoposide+Etoposide+6        0 -0.021682 -0.073558 -0.087733 -0.079325
# 144  Paclitaxel+Paclitaxel+1        0 -0.955000  0.224410  0.305000 -0.150050
# 146  Paclitaxel+Paclitaxel+2        0 -0.498500  0.079738  0.073921  0.171920
# 148  Paclitaxel+Paclitaxel+3        0 -0.279380  0.205450  0.210170  0.051049
# 150  Paclitaxel+Paclitaxel+4        0 -0.106570  0.085699  0.131410 -0.050910
# 152  Paclitaxel+Paclitaxel+5        0 -0.076667 -0.047941  0.062510  0.070742
# 154  Paclitaxel+Paclitaxel+6        0  0.041802 -0.077287 -0.084714 -0.071462
# 120   Etoposide+Paclitaxel+1        0 -0.645000 -0.112110  0.118490 -0.169420
# 122   Etoposide+Paclitaxel+2        0 -0.682500 -0.123990 -0.132390 -0.230220
# 124   Etoposide+Paclitaxel+3        0 -0.565830  0.109100 -0.071556  0.181110
# 126   Etoposide+Paclitaxel+4        0 -0.103060 -0.131500 -0.067610 -0.056927
# 128   Etoposide+Paclitaxel+5        0 -0.111310 -0.080389 -0.086067  0.084237
# 130   Etoposide+Paclitaxel+6        0 -0.059167 -0.110190 -0.131330  0.112090
# 24    Paclitaxel+Etoposide+1        0 -0.951670  0.165480  0.198210  0.085595
# 26    Paclitaxel+Etoposide+2        0 -0.404170  0.042516 -0.022722  0.199150
# 28    Paclitaxel+Etoposide+3        0  0.019967 -0.116850 -0.166500  0.167010
# 30    Paclitaxel+Etoposide+4        0 -0.021667 -0.116690 -0.141640  0.157570
# 32    Paclitaxel+Etoposide+5        0 -0.051567 -0.074827 -0.099898 -0.090014
# 34    Paclitaxel+Etoposide+6        0 -0.022507 -0.103480 -0.128450  0.102980
#
#           ks5       ks6       ks7       ks8  ...     ks229     ks230  \
# 0   -0.421970 -0.130760  0.161730  0.208450  ...  0.232730  0.096027
# 122 -0.111970  0.307660  0.304870 -0.110190 -0.543330 -0.515140 -0.199960
# 124 -0.076876  0.381540  0.377910 -0.064363 -0.384620 -0.413360 -0.194100
# 126 -0.042847  0.051451 -0.062674  0.050801 -0.163730 -0.169610 -0.107900
# 128 -0.031534  0.096137  0.092897 -0.032453 -0.164260 -0.139390 -0.044673
# 130 -0.043160 -0.035920 -0.048149  0.030227 -0.068214 -0.083063 -0.061288
# 24  -0.278810  0.417500  0.352260  0.272620 -0.465710 -0.543330 -0.301670
# 26  -0.141790  0.349750  0.292720  0.325110 -0.353420 -0.401200 -0.234110
# 28  -0.045131 -0.038350 -0.053399  0.031471  0.058170 -0.070523 -0.043791
# 30  -0.036411 -0.054934 -0.050371 -0.038630  0.064967 -0.055899 -0.056997
# 32  -0.022207 -0.031160 -0.030967 -0.022369 -0.051402 -0.062275 -0.045546
# 34  -0.030145 -0.048636 -0.055792 -0.019759  0.047466 -0.057486 -0.055365
#
#         ks238
# 0    0.353240
# 2    0.398800
# 4    0.254140
# 6    0.043312
# 8    0.031688
# 10   0.056148
# 144  0.153530
# 146  0.151010
# 148 -0.082601
# 150 -0.033923
# 152  0.029123
# 154  0.039612
# 120  0.140550
# 122  0.187950
# 124  0.166210
# 126 -0.038760
# 128 -0.026636
# 130 -0.033788
# 24   0.329400
# 26   0.185680
# 28   0.043529
# 30   0.038779
# 32   0.026155
# 34   0.033506
#
# [24 rows x 240 columns]

# %%
#see DMSO
e_and_p.iloc[24:,:]
#e_and_p.shape
#72 rows
#dmso each concentration 8 samples. 6*8=48
# Out:
#        drug_name  default       ks1       ks2       ks3       ks4       ks5  \
# 360  DMSO+DMSO+1        0 -0.045833  0.045630  0.069729  0.032458  0.046111
# 361  DMSO+DMSO+1        0 -0.030833 -0.023131 -0.031360  0.062452 -0.053954
# 372  DMSO+DMSO+1        0  0.073695  0.029093  0.060841 -0.051401  0.045579
# 373  DMSO+DMSO+1        0  0.054498 -0.058508 -0.051640  0.054882 -0.083751
# 744  DMSO+DMSO+1        0  0.029236  0.068853  0.090612 -0.056395  0.128060
# 745  DMSO+DMSO+1        0  0.094064  0.033183  0.045444  0.036417  0.050826
# 756  DMSO+DMSO+1        0 -0.055592 -0.037596 -0.074126  0.073131 -0.062658
# 757  DMSO+DMSO+1        0  0.039511 -0.027140  0.037520 -0.073599  0.023893
# 362  DMSO+DMSO+2        0 -0.023333  0.045120  0.054200  0.039305  0.060897
# 363  DMSO+DMSO+2        0  0.069926  0.024255  0.063075  0.054632  0.043439
# 374  DMSO+DMSO+2        0  0.018606  0.028958  0.041390  0.026484 -0.042806
# 375  DMSO+DMSO+2        0 -0.076667  0.033630  0.035200 -0.065921  0.035431
# 746  DMSO+DMSO+2        0 -0.056405 -0.024389 -0.042762  0.047312 -0.032773
# 747  DMSO+DMSO+2        0  0.071958  0.057600  0.050552  0.131620  0.051325
# 758  DMSO+DMSO+2        0 -0.032087 -0.027087 -0.038807  0.105020 -0.035720
# 750  0.083228  0.085822 -0.036315 -0.062242 -0.054002 -0.026925 -0.027312
# 751 -0.055204 -0.046483 -0.072032  0.065028  0.067993  0.044721 -0.061037
# 762  0.031192  0.032828 -0.045174 -0.037696  0.022594  0.039518 -0.026381
# 763  0.041298  0.046207 -0.060165 -0.048079 -0.038779  0.051620 -0.049578
# 368 -0.087371 -0.093078 -0.037384  0.055170  0.050214 -0.034116 -0.022124
# 369 -0.036548 -0.032211 -0.029405  0.056871  0.077058 -0.028452 -0.051003
# 380 -0.026736 -0.026100 -0.021382 -0.048818 -0.053210 -0.027802 -0.036109
# 381  0.060697  0.063298  0.033481 -0.090896 -0.097080 -0.030393  0.041801
# 752  0.082023  0.072043 -0.031923 -0.065190 -0.052946 -0.024140  0.047596
# 753 -0.032864 -0.023487 -0.061764  0.036036  0.041618  0.062322 -0.053981
# 764  0.041709  0.037911 -0.051941 -0.064778 -0.058576 -0.050211  0.040781
# 765  0.055945  0.057423 -0.033471 -0.059149 -0.042904  0.029674  0.027414
# 370 -0.118270 -0.104240 -0.057756  0.075792  0.059856 -0.035129 -0.027168
# 371 -0.031092 -0.025803 -0.036929  0.049817  0.036232  0.037463 -0.027649
# 382  0.127510  0.123030  0.041076 -0.144710 -0.150270 -0.039429  0.039811
# 383  0.100560  0.102540 -0.026349 -0.098545 -0.087436 -0.028672 -0.040644
# 754  0.027212  0.034754 -0.039492  0.023565 -0.032719 -0.018783  0.055371
# 755 -0.030191 -0.029522 -0.045560 -0.022733  0.033174  0.031173 -0.021555
# 766  0.048214  0.050098  0.025392 -0.034964  0.035534  0.019352 -0.049585
# 767  0.047912  0.052508 -0.058880 -0.060345 -0.047938  0.052710 -0.036019
#
# [48 rows x 240 columns]

# %%
#a code block that is used to deal with the data using PCA models(dimensionality reduction)
import pandas as pd
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

X_drug = e_and_p.iloc[:, 3:240].values

X_drug = StandardScaler().fit_transform(X_drug)

pca_drug = PCA(n_components=6)
components = pca_drug.fit_transform(X_drug)
X_drug=pca_drug.fit_transform(X_drug)
principalDf = pd.DataFrame(data = components
             , columns =['principal component 1', 'principal component 2','principal component 3','principal component 4','principal component 5','principal component 6'])
principalDf
# Out:
#     principal component 1  principal component 2  principal component 3  \
# 0               31.096651              -3.942088             -12.452774
# 1               30.951212             -12.803820             -10.485330
# 2               24.348102             -11.653830              11.742975
# 3               -0.303644              -4.392263              -1.465355
# 4               -4.454066               1.658168              -5.257756
# ..                    ...                    ...                    ...
# 67              -3.582969               0.729938               6.965308
# 68              -5.733490              -3.511463              -1.652830
# 69              -4.895699              -0.017854              -1.527433
# 70              -7.157156              -1.312807               4.674588
# 71              -6.349221              -0.726522               2.124672
#
#     principal component 4  principal component 5  principal component 6
# 0               -5.669265              -3.528074               0.122483
# 1               -0.525292              -7.942970              -1.209977
# 2                2.705483               0.802041              -0.757039
# 3                8.096490              -0.822362               3.395888
# 4                2.514074               1.886575               1.443037
# ..                    ...                    ...                    ...
# 67              -4.803481              -1.935554               1.714068
# 68               0.071817              -4.204879              -2.731765
# 69              -2.044073               1.847911              -1.406201
# 70              -6.732061              -1.214040               1.006603
# 71              -7.120589              -0.439730              -0.272257
#
# [72 rows x 6 columns]

# %%
#see the principalDf
principalDf.iloc[0,:]
# Out:
# principal component 1    31.096651
# principal component 2    -3.942088
# principal component 3   -12.452774
# principal component 4    -5.669265
# principal component 5    -3.528074
# principal component 6     0.122483
# Name: 0, dtype: float64

# %%
#wipe out those whose concentration is not valid
def get_centroid(point_lst):
    x_sum=0
    y_sum=0
    z1_sum=0
    z2_sum=0
    z3_sum=0
    z4_sum=0


    for i in range(len(point_lst)):
        x_sum+=point_lst[i][0]
        y_sum+=point_lst[i][1]
        z1_sum+=point_lst[i][2]
        z2_sum+=point_lst[i][3]
        z3_sum+=point_lst[i][4]
        z4_sum+=point_lst[i][5]


    x_mean=x_sum/len(point_lst)
    y_mean=y_sum/len(point_lst)
    z1_mean=z1_sum/len(point_lst)
    z2_mean=z2_sum/len(point_lst)
    z3_mean=z3_sum/len(point_lst)
    z4_mean=z4_sum/len(point_lst)
    centroid=[]
    centroid.append(x_mean)
    centroid.append(y_mean)
    centroid.append(z1_mean)
    centroid.append(z2_mean)
    centroid.append(z3_mean)
    centroid.append(z4_mean)
    centroid.append(point_lst[0][-1])
    return centroid

# %%
#calculate DMSO circle
p_DMSO=[]
for i in range(24,72):
    p_DMSO.append([principalDf.iloc[i,:][0],principalDf.iloc[i,:][1],principalDf.iloc[i,:][2],principalDf.iloc[i,:][3],principalDf.iloc[i,:][4],principalDf.iloc[i,:][5],'DMSO+DMSO'])
p_DMSO[0]
p=[]
for i in range(24):
    p.append([principalDf.iloc[i,:][0],principalDf.iloc[i,:][1],principalDf.iloc[i,:][2],principalDf.iloc[i,:][3],principalDf.iloc[i,:][4],principalDf.iloc[i,:][5]])
len(p)
p_combi=p[12:]
len(p_combi)
#print(p_combi)
#for j in range(6):
   # p_combi[j].append('Etoposide+Paclitaxel')
#for k in range(6,12):
   # p_combi[k].append('Paclitaxel+Etoposide')
#print(p_combi)
# Out:
# 12

# %%
#get the centroid of DMSO
centroid_DMSO=get_centroid(p_DMSO)
centroid_DMSO
# Out:
# [-4.819513609895871,
#  -1.1246832915361666,
#  0.9425990689507122,
#  -0.9813964587164032,
#  0.07965121615757853,
#  -0.6952740776055025,
#  'DMSO+DMSO']

# %%
#get the DMSO circle
#
#
#
#max_dist we got
from math import sqrt
def euclidean_distance(row1, row2):
    distance =0
	#print(len(row1)-1) this is to ensure that we calculate 6 points
    for i in range(len(row1)-1):

	

        distance += (row1[i] - row2[i])**2
    return sqrt(distance)

	

import math
dist_lst=[]
for i in range(len(p_DMSO)):

    dist_lst.append(euclidean_distance(centroid_DMSO,p_DMSO[i]))
#print(dist_lst)
print(len(dist_lst))
dist_lst.sort()
ave_dist=sum(dist_lst)/len(dist_lst)

max_dist=(dist_lst[-1]+dist_lst[-2]+dist_lst[-3]+dist_lst[-4]+dist_lst[-5])/5.0
max_dist*=2
print(max_dist)
print(dist_lst)
# Out:
# 48
# 24.123365934834816
# [2.57293048616941, 2.9152849084716994, 3.0761364850397435, 3.2028534375219277, 3.30723314125956, 3.3313862590298644, 3.4775533059055386, 3.6636704248816407, 3.8270923590375103, 3.9644503111543345, 4.081972049187137, 4.114370801041626, 4.2225583858908, 4.3295448556064775, 4.361718839765776, 4.504359003669327, 4.579243823788924, 4.625338269074247, 4.699804119562287, 4.7879133072341356, 4.842662369273499, 5.061451422218801, 5.079476491150127, 5.180862163787105, 5.244393053858565, 5.2465002401620335, 5.362440804075769, 5.587153367906151, 5.893086035133131, 5.906501385617196, 6.07306188302842, 6.102600886705169, 6.410867805165928, 6.430287966396056, 6.483380419402675, 6.535398787134202, 6.605463688925831, 6.615575352380072, 7.044810398909809, 7.21529404833305, 7.22305306897158, 7.554327907167261, 7.68416480870827, 7.947291624870364, 8.104980891409252, 8.106540376793099, 9.297819396078221, 26.851782547936093]

# %%
#still wiping out not effective concentration
p=[]
for i in range(24):
    p.append([principalDf.iloc[i,:][0],principalDf.iloc[i,:][1],principalDf.iloc[i,:][2],principalDf.iloc[i,:][3],principalDf.iloc[i,:][4],principalDf.iloc[i,:][5]])
for i in range(6):
    p[i].append('Etoposide')
for j in range(6):
    p[j+6].append('Paclitaxel')
for k in range(6):
    p[k+12].append('Etoposide+Paclitaxel')
for m in range(6):
    p[m+18].append("Paclitaxel+Etoposide")
#print(p)
dist_lst2=[]
for i in range(24):
    dist_lst2.append(euclidean_distance(centroid_DMSO,p[i]))
#print(dist_lst2)
#record the index
#then, according to the index, wipe out those same index in p
effect=[]
indexlst=[]
for i in range(12):
    dist=euclidean_distance(centroid_DMSO,p[i])
    
    if dist>max_dist:
        effect.append(p[i])
        indexlst.append(i)
#24 becomes 24
print(effect,len(effect),indexlst)
#1,2,3
#1,2,3,4
print(len(X_drug))

print(len(X_drug2[-1]))
print(len(indexlst))
# Out:
# [[31.096650517273975, -3.942088130330507, -12.452774435772978, -5.669264678582478, -3.528074219754371, 0.12248326757891906, 'Etoposide'], [30.951211710613254, -12.803820459480228, -10.485329504945296, -0.5252920771124701, -7.9429702121694845, -1.2099766305825714, 'Etoposide'], [24.348102255999436, -11.653829783891805, 11.742974909105238, 2.7054825310101616, 0.8020407776488481, -0.7570392998976161, 'Etoposide'], [20.375356859951996, 25.51182523261299, 2.080735050628143, 0.12482324691485232, 0.2569894397375238, -7.8806975894089755, 'Paclitaxel'], [15.503299954328883, 5.957406829866675, 10.35808752957411, -0.8117513837350393, -5.738309124109451, 9.679954915094639, 'Paclitaxel'], [8.102896285762888, 15.515572209498899, 5.356627968603825, -3.1819330377660706, 11.206256642608972, 2.005597906978641, 'Paclitaxel']] 6 [0, 1, 2, 6, 7, 8]
# 72
# 237
# 6

# %%
#again. computing distances.
#0-5  etoposide
#6-11 paclitaxel
#plus 12 first. then plus 18
import math
distance=[]
#between effective etoposide and combination (average distance)
for i in range(3):
    distance.append(euclidean_distance(p[indexlst[i]],p[i+12]))
distance=sum(distance)/len(distance)
print(distance)
distance2=[]
for j in range(3,7):
    distance2.append(euclidean_distance(p[indexlst[j]],p[j+6]))
distance2=sum(distance2)/len(distance2)
print(distance2)
#since distance<distance2, etoposide is more similar to the combination
# Out:
# 11.050659556152498
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-770278b09d7b> in <module>
#      12 distance2=[]
#      13 for j in range(3,7):
# ---> 14     distance2.append(euclidean_distance(p[indexlst[j]],p[j+6]))
#      15 distance2=sum(distance2)/len(distance2)
#      16 print(distance2)
#
# IndexError: list index out of range

# %%
#the last set of the combination
distance3=[]
for m in range(3):
    distance3.append(euclidean_distance(p[indexlst[m]],p[m+18]))
print(distance3)
distance3=sum(distance3)/len(distance3)

distance4=[]
for n in range(3,7):
    distance4.append(euclidean_distance(p[indexlst[n]],p[n+12]))
distance4=sum(distance4)/len(distance4)
print(distance3,distance4)
#still etoposide is more effective. 
#one question 
#this time, conclusion: etoposide is more effective
# Out:
# [35.47758904012807, 31.50175779479175, 35.61194034965293]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-105-bdbabe647ca6> in <module>
#       8 distance4=[]
#       9 for n in range(3,7):
# ---> 10     distance4.append(euclidean_distance(p[indexlst[n]],p[n+12]))
#      11 distance4=sum(distance4)/len(distance4)
#      12 print(distance3,distance4)
#
# IndexError: list index out of range

# %%
#considering that the combination may not be effective
effect2=[]
indexlst2=[]
for i in range(12,24):
    dist2=euclidean_distance(centroid_DMSO,p[i])
    
    if dist2>max_dist:
        effect2.append(p[i])
        indexlst2.append(i)

print(effect2,indexlst2)
#
#1,2,3
#1,2,3,4
#above are for etoposide or paclitaxel
#1,2,3,4(1,2,3;1,2,3,4)
#1,2(1,2;1,2)
print(indexlst2)
# Out:
# [[27.744449953840657, 1.9276816728624617, -12.042352454108292, -4.908107589717231, 7.0825661010079015, 0.6284290164074671, 'Etoposide+Paclitaxel'], [30.987721224005842, -4.781072350780384, -9.818804566794757, -6.780415450338014, 1.9569997340513692, -2.352295814466586, 'Etoposide+Paclitaxel'], [24.876490367683328, -9.423642065796203, 12.840653612827374, 1.4932176086093663, 5.591756322766171, -3.6730708772889287, 'Etoposide+Paclitaxel'], [21.28233270657006, 18.22852172586145, 7.940324666599714, 7.378928935214844, -8.01065928971897, -7.9133820948717775, 'Paclitaxel+Etoposide'], [15.718211449333428, 2.137947630612223, 9.035535812605255, 1.8441908952294777, -7.111864428921676, 11.02483617625481, 'Paclitaxel+Etoposide']] [12, 13, 14, 18, 19]
# [12, 13, 14, 18, 19]

# %%
#calculate every point in here



lst1=[]
lst2=[]
lst3=[]
lst4=[]
for i in range(len(indexlst)):
    if indexlst[i]<6:
        lst1.append(indexlst[i])
    else:
        lst2.append(indexlst[i]-6)
for j in range(len(indexlst2)):
    if indexlst2[j]<18:
        lst3.append(indexlst2[j]-12)
    else:
        lst4.append(indexlst2[j]-18)
#print(lst1,lst2,lst3,lst4)
intersectlst1=list(set(lst1)&set(lst2)&set(lst3))
intersectlst2=list(set(lst1)&set(lst2)&set(lst4))
print(intersectlst1,intersectlst2)

e1=0
p1=0
for i in range(len(intersectlst1)):
    if min(euclidean_distance(p[intersectlst1[i]],p[intersectlst1[i]+12]),euclidean_distance(p[intersectlst1[i]+6],p[intersectlst1[i]+12]))\
        ==euclidean_distance(p[intersectlst1[i]],p[intersectlst1[i]+12]):
        e1+=1
    else:
        p1+=1
e2=0
p2=0
for j in range(len(intersectlst2)):
    if min(euclidean_distance(p[intersectlst1[j]],p[intersectlst1[j]+18]),euclidean_distance(p[intersectlst1[j]+6],p[intersectlst1[j]+18]))\
        ==euclidean_distance(p[intersectlst1[j]],p[intersectlst1[j]+18]):
        e2+=1
    else:
        p2+=1
print(e1,p1,e2,p2)
et=e1+e2
pt=p1+p2
print(et,pt)



"""
min_l1=min(len(lst1),len(lst2),len(lst3))
if len(lst1)==min_l1:
    lst_1=lst1
elif len(lst2)==min_l1:
    lst_1=lst2
elif len(lst3)==min_l1:
    lst_1=lst3
#not the shortest list, but the overlapped list. 
min_l2=min(len(lst1),len(lst2),len(lst4))
if len(lst1)==min_l2:
    lst_2=lst1
elif len(lst2)==min_l2:
    lst_2=lst2
elif len(lst4)==min_l2:
    lst_2=lst3
print(lst_1,lst_2)
#for i in range(min_l1):
 #   if min(euclidean_distance(p[lst_1[i]]))
 """
# Out:
# [0, 1, 2] [0, 1]
# 3 0 0 2
# 3 2
# '\nmin_l1=min(len(lst1),len(lst2),len(lst3))\nif len(lst1)==min_l1:\n    lst_1=lst1\nelif len(lst2)==min_l1:\n    lst_1=lst2\nelif len(lst3)==min_l1:\n    lst_1=lst3\n#not the shortest list, but the overlapped list. \nmin_l2=min(len(lst1),len(lst2),len(lst4))\nif len(lst1)==min_l2:\n    lst_2=lst1\nelif len(lst2)==min_l2:\n    lst_2=lst2\nelif len(lst4)==min_l2:\n    lst_2=lst3\nprint(lst_1,lst_2)\n#for i in range(min_l1):\n #   if min(euclidean_distance(p[lst_1[i]]))\n '

# %%
#do distance comparison again(both effective)
import math
distance=[]
#between effective etoposide and combination (average distance)
for i in range(3):
    #1,2,3
    distance.append(euclidean_distance(p[indexlst[i]],p[i+12]))
distance=sum(distance)/len(distance)
print(distance)
distance2=[]
for j in range(3,7):
    #1,2,3,4
    distance2.append(euclidean_distance(p[indexlst[j]],p[j+6]))
distance2=sum(distance2)/len(distance2)
print(distance2)
if distance<distance2:
    similar='Etoposide'
else:
    similar='Paclitaxel'
print(similar)
# Out:
# 11.050659556152498
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-107-aed9b8fe601d> in <module>
#      11 for j in range(3,7):
#      12     #1,2,3,4
# ---> 13     distance2.append(euclidean_distance(p[indexlst[j]],p[j+6]))
#      14 distance2=sum(distance2)/len(distance2)
#      15 print(distance2)
#
# IndexError: list index out of range

# %%
#do distance comparison again
distance3=[]
for m in range(2):
    distance3.append(euclidean_distance(p[indexlst[m]],p[m+18]))

distance3=sum(distance3)/len(distance3)
#print(distance3)

distance4=[]
for n in range(3,5):
    distance4.append(euclidean_distance(p[indexlst[n]],p[n+12]))
distance4=sum(distance4)/len(distance4)
print(distance3,distance4)

#so still, etoposide is more similar
#the conclusion changes after the second problem got solved

#find similar drug response(below markdown)
if distance3<distance4:
    similar='Etoposide'
else:
    similar='Paclitaxel'
print(similar)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-108-5677a356325b> in <module>
#       9 distance4=[]
#      10 for n in range(3,5):
# ---> 11     distance4.append(euclidean_distance(p[indexlst[n]],p[n+12]))
#      12 distance4=sum(distance4)/len(distance4)
#      13 print(distance3,distance4)
#
# IndexError: list index out of range

# %% [markdown]
# # Since we calculated the distances twice and made comparisons twice, and we got that the distance between drug combination and etoposide is smaller that the distance between drug combination and paclitaxel,  we got that etoposide is a more similar single drug. (This time the conclusion changes. When I changed the number of components, the conclusion did not change. still, paclitaxel was more similar. But after I removed those drugs whose location is within the domain of DMSO control group, I found that etoposide is more similar to "Etoposide+Paclitaxel" drug combination. )

# %%
#see first version X_drug(but take only training data)
X_drug2
# Out:
# array([[-1.05937541, -0.73128197, -1.53781116, ..., -1.5708676 ,
#         -0.85184873,  1.95626293],
#        [-1.32862221, -1.40313433, -2.09914064, ..., -1.60790337,
#         -0.88898536,  2.31093355],
#        [ 0.93401032, -0.6733891 ,  0.7539744 , ..., -0.79550243,
#         -0.24993911,  1.18479982],
#        ...,
#        [ 0.97671459,  1.22453849, -0.31374943, ...,  0.41007431,
#          0.50059107, -1.05768227],
#        [-0.16811969,  0.71640867,  0.52371504, ...,  0.71968348,
#          0.84050231, -0.5668885 ],
#        [-0.41951379, -0.36935194, -0.45523144, ...,  1.06858041,
#          1.02070488, -0.48523485]])

# %%
#LDA model 
#from sklearn.lda import LDA
#lda = LDA(n_components=2)
#X_r2 = lda.fit(X, y).transform(X)
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
y=[]
for i in range(6):
    y.append('Etoposide')
for j in range(6):
    y.append("Paclitaxel")

lda = LinearDiscriminantAnalysis(n_components=None)
X_lda = lda.fit(X_drug2, y)
lda_var_ratios=lda.explained_variance_ratio_

# %%
# Create a function for lda to "select n components"
def select_n_components(var_ratio, goal_var: float) -> int:
    # Set initial variance explained so far
    total_variance = 0.0
    
    # Set initial number of features
    n_components = 0
    
    # For the explained variance of each feature:
    for explained_variance in var_ratio:
        
        # Add the explained variance to the total
        total_variance += explained_variance
        
        # Add one to the number of components
        n_components += 1
        
        # If we reach our goal level of explained variance
        if total_variance >= goal_var:
            # End the loop
            break
            
    # Return the number of components
    return n_components

# %%
select_n_components(lda_var_ratios, 0.95)
# Out:
# 1

# %%
#test iris
# Load the Iris flower dataset:
"""
from sklearn import datasets
iris = datasets.load_iris()
X = iris.data
y = iris.target
X
y
lda = LinearDiscriminantAnalysis(n_components=None)
X_lda = lda.fit(X, y)
lda_var_ratios = lda.explained_variance_ratio_
lda_var_ratios
select_n_components(lda_var_ratios, 0.95)
"""
# Out:
# '\nfrom sklearn import datasets\niris = datasets.load_iris()\nX = iris.data\ny = iris.target\nX\ny\nlda = LinearDiscriminantAnalysis(n_components=None)\nX_lda = lda.fit(X, y)\nlda_var_ratios = lda.explained_variance_ratio_\nlda_var_ratios\nselect_n_components(lda_var_ratios, 0.95)\n'

# %%
lda = LinearDiscriminantAnalysis(n_components=1)

# either use: lda.fit_transform(X, y)
X_r2 = lda.fit_transform(X_drug2, y)

## PREFERRED WAY
# or, use: lda.fit(X, y)
# followed by lda.transform(X)
lda.fit(X_drug2, y)
X_r2 = lda.transform(X_drug2)
X_r2
# Out:
# array([[-2.10835477],
#        [-1.96437339],
#        [-2.62436749],
#        [-2.69675791],
#        [-1.07330215],
#        [ 0.21653351],
#        [ 2.14368521],
#        [ 2.18173581],
#        [ 2.61738827],
#        [ 1.96484049],
#        [ 1.11534763],
#        [ 0.22762479]])

# %%
#prepare training data and testing data
p=[]
for i in range(24):
    p.append([principalDf.iloc[i,:][0],principalDf.iloc[i,:][1],principalDf.iloc[i,:][2],principalDf.iloc[i,:][3],principalDf.iloc[i,:][4],principalDf.iloc[i,:][5]])

X_train=[]
for i in range(len(indexlst)):
    X_train.append(p[indexlst[i]])

y_train=[]
#for y setting, we also need to write a general function here.
for i in range(len(indexlst)):
    if indexlst[i]<6:
        y_train.append('Etoposide')
    else:
        y_train.append('Paclitaxel')
y_train
len(X_train)
p_combi_effect=[]
for i in range(len(indexlst2)):

    p_combi_effect.append(p[indexlst2[i]])
p_combi_effect=[]  
for i in range(12,24):
    p_combi_effect.append(p[i])
print(len(p_combi_effect))
p_combi_effect[0]
# Out:
# 12
# [27.744449953840657,
#  1.9276816728624617,
#  -12.042352454108292,
#  -4.908107589717231,
#  7.0825661010079015,
#  0.6284290164074671]

# %%
#model
# make a prediction with a lda model on the dataset
from sklearn.datasets import make_classification
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
# define dataset
# define model
model = LinearDiscriminantAnalysis(n_components=1)
X_train2=model.fit(X_train,y_train).transform(X_train)
# fit model

model.fit(X_train,y_train)
# define new data
row = [0.12777556,-3.64400522,-2.23268854,-1.82114386,1.75466361,0.1243966,1.03397657,2.35822076,1.01001752,0.56768485]
# make a prediction
#yhat=model.predict([row])
yhat = model.predict(p_combi_effect)
# summarize prediction
print('Predicted Class: %s' % yhat)
cne=0
cnp=0
for i in range(len(yhat)):
    if yhat[i]=='Etoposide':
        cne+=1
    elif yhat[i]=='Paclitaxel':
        cnp+=1

if cne>cnp:
    similar_drug='Etoposide'
else:
    similar_drug="Paclitaxel"

print("e:%d, p:%d"%(cne,cnp))
# Out:
# Predicted Class: ['Etoposide' 'Etoposide' 'Etoposide' 'Etoposide' 'Etoposide' 'Etoposide'
#  'Paclitaxel' 'Paclitaxel' 'Etoposide' 'Etoposide' 'Etoposide' 'Etoposide']
# e:10, p:2

# %%
#indexlst for the single drug. indexlst2 for the drug combination
print(indexlst)
print(indexlst2)
len(p)
p_combi_effect=[]
for i in range(len(indexlst2)):

    p_combi_effect.append(p[indexlst2[i]])
print(len(p_combi_effect))
# Out:
# [0, 1, 2, 6]
# [12, 13, 14, 18]
# 4

# %%
#conclusion:
# PCA: etoposide :2 . paclitaxel: 0(PCA: etoposide)
#LDA: paclitaxel

# %%
#final conclusion and stats:
#PCA: ks4: etoposide:2. paclitaxel:0
#ks3: etoposide:2 paclitaxel:0

#LDA: ks2: ks3:Paclitaxel ks4: Paclitaxel. ks5:
print(len(indexlst),len(indexlst2))
# Out:
# 4 4
