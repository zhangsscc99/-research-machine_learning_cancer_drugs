# %%
#a code block that deals with concentration and drug names
#we do not use this block for now.

import pandas as pd
f1 = pd.read_csv('B.csv')
f2 = pd.read_csv('C.csv')
f3=pd.read_csv('D.csv')
f4=pd.read_csv('E.csv')
f5=pd.read_csv('A_ks1.csv')
file = [f1,f2,f3,f5]
train = pd.concat(file,axis=1)
train.to_csv("train.csv", index=0, sep=',')

# %%
#do some further processing with "A" because there are some data error in it
def remove_extradots(string):
    counter=0
    lst=[]
    for i in range(len(string)):
        if string[i]=='.' and counter<1 :
            lst.append(string[i])
            counter+=1
        elif string[i]!='.':
            lst.append(string[i])
    res="".join(lst)
    return res



import csv
res_list=[]
print(remove_extradots("-0.29444.2"))
with open('A_ks1.csv') as file2:
    reader=csv.reader(file2)

    for row in reader:
        data=[]
        for i in range(len(row)):
            
            data.append(remove_extradots(row[i]))
        res_list.append(data)
    


with open('modified_A.csv', 'w') as file3:
    writer = csv.writer(file3)
    writer.writerows(res_list)
file3.close()
# Out:
# -0.294442

# %%
#test file A
import pandas as pd
df_A=pd.read_csv("A_ks1.csv")
df_A.shape
#df_A2=pd.read_csv("A_modified.csv")
#df_A2.shape
# Out:
# (1535, 239)

# %%
#a block that is used to concate the drug names(drug combinations and related concentration)

import csv
res_list=[]
with open('train.csv', 'r') as file:
    reader = csv.reader(file)
    
    for row in reader:
        data=[]
        data.append(row[0]+'+'+row[1]+"+"+row[2])
        res_list.append(data)

        
        
with open('concatenated.csv', 'w') as file2:
    writer = csv.writer(file2)
    writer.writerows(res_list)

# %%
#a block that is used to concate concentration and ks numbers.
import pandas as pd
f1 = pd.read_csv('concatenated.csv')
#f2 = pd.read_csv('C.csv')
f3=pd.read_csv('D.csv')
f4=pd.read_csv('E.csv')
f5=pd.read_csv('modified_A.csv')
file = [f1,f5]
train = pd.concat(file,axis=1)
train.to_csv("train3.csv", index=0, sep=',')

# %%
#a block that sets the fields for the drug data
import csv
fields=['drug_name','default']
for i in range(1,239):
    fields.append('ks'+str(i))
rows=[]
with open('train3.csv', 'r') as file:
    reader = csv.reader(file)
    
    for row in reader:
        rows.append(row)

        
        
with open('drug_withfields2.csv', 'w') as file2:
    writer = csv.writer(file2)
    writer.writerow(fields)
    writer.writerows(rows)

# %%
#do some further processing with "drug_withfields" because there are still some data error in it
def remove_extradots(string):
    counter=0
    lst=[]
    for i in range(len(string)):
        if string[i]=='.' and counter<1 :
            lst.append(string[i])
            counter+=1
        elif string[i]!='.':
            lst.append(string[i])
    res="".join(lst)
    return res



import csv
res_list=[]
print(remove_extradots("-0.29444.2"))
with open('drug_withfields2.csv') as file2:
    reader=csv.reader(file2)

    for row in reader:
        data=[]
        for i in range(len(row)):
            
            data.append(remove_extradots(row[i]))
        res_list.append(data)
    


with open('drug_with_fields.csv', 'w') as file3:
    writer = csv.writer(file3)
    writer.writerows(res_list)
file3.close()
# Out:
# -0.294442

# %%
#we take etoposide and palitaxel out. 
df=pd.read_csv('drug_with_fields.csv')
df11=df.loc[(df['drug_name'] =='Etoposide+Etoposide+1') ]
df12=df.loc[(df['drug_name'] =='Etoposide+Etoposide+2') ]
df13=df.loc[(df['drug_name'] =='Etoposide+Etoposide+3') ]
df14=df.loc[(df['drug_name'] =='Etoposide+Etoposide+4') ]
df15=df.loc[(df['drug_name'] =='Etoposide+Etoposide+5') ]
df16=df.loc[(df['drug_name'] =='Etoposide+Etoposide+6') ]
df21=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+1') ]
df22=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+2') ]
df23=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+3') ]
df24=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+4') ]
df25=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+5') ]
df26=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+6') ]
df31=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+1')]
df32=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+2')]
df33=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+3')]
df34=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+4')]
df35=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+5')]
df36=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+6')]
df41=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+1') ]
df42=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+2') ]
df43=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+3') ]
df44=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+4') ]
df45=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+5') ]
df46=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+6') ]
#df51=df.loc[(df['drug_name'] =='DMSO+DMSO+1') ]
#df52=df.loc[(df['drug_name'] =='DMSO+DMSO+2') ]
##df53=df.loc[(df['drug_name'] =='DMSO+DMSO+3') ]
#df54=df.loc[(df['drug_name'] =='DMSO+DMSO+4') ]
#df55=df.loc[(df['drug_name'] =='DMSO+DMSO+5') ]
#df56=df.loc[(df['drug_name'] =='DMSO+DMSO+6') ]


frames = [df11, df12,df13,df14,df15,df16,df21,df22,df23,df24,df25,df26,df31,df32,df33,df34,df35,df36,df41,df42,df43,df44,df45,df46]

e_and_p = pd.concat(frames)
#etoposide and paclitaxel combination. 
e_and_p
# Out:
#                    drug_name  default      ks1      ks2       ks3       ks4  \
# 1260   Etoposide+Etoposide+1        0 -0.77875  0.39606  0.292640  0.123950
# 1261   Etoposide+Etoposide+1        0 -0.38667  0.33070  0.236550  0.137830
# 1284   Etoposide+Etoposide+1        0 -0.88125  0.36467  0.310090  0.265020
# 1285   Etoposide+Etoposide+1        0 -0.56417  0.34078  0.218040  0.083652
# 1262   Etoposide+Etoposide+2        0  0.21785 -0.08226 -0.056185 -0.086997
# ...                      ...      ...      ...      ...       ...       ...
# 717   Paclitaxel+Etoposide+5        0  0.32494 -0.21024 -0.238100 -0.189520
# 694   Paclitaxel+Etoposide+6        0  0.19610 -0.32310 -0.377260 -0.183170
# 695   Paclitaxel+Etoposide+6        0 -0.15500 -0.24733 -0.298550 -0.158500
# 718   Paclitaxel+Etoposide+6        0 -0.25500 -0.16240 -0.187920 -0.197080
# 719   Paclitaxel+Etoposide+6        0 -0.21958 -0.10550 -0.168440 -0.112280
#
#            ks5       ks6       ks7       ks8  ...    ks229     ks230  \
# 1260  0.308230  0.260660  0.290950  0.288450  ...  0.41438  0.174010
# 1261  0.437920  0.236370  0.211090  0.202800  ...  0.38191 -0.046066
# 1284  0.300460  0.275790  0.291340  0.283840  ...  0.57984  0.086348
# 1285  0.383480  0.236470  0.171030  0.173160  ...  0.37669  0.120880
# 1262  0.037115  0.044479 -0.076923 -0.077915  ... -0.12969  0.029113
# ...        ...       ...       ...       ...  ...      ...       ...
# 717  -0.406310 -0.372620 -0.210060 -0.065655  ... -0.40411 -0.382560
# 694  -0.502560 -0.471610 -0.346270 -0.199080  ... -0.41389 -0.392620
# 695  -0.478550 -0.423340 -0.267830 -0.163930  ... -0.26505 -0.402140
# 718  -0.347980 -0.316650 -0.169120 -0.061322  ... -0.30129 -0.418860
# 719  -0.267540 -0.259430 -0.143360 -0.073079  ... -0.16516 -0.280070
#
#          ks231    ks232    ks233     ks234    ks235    ks236     ks237  \
# 1260 -0.220500  0.52568  0.49970  0.174010 -0.31217 -0.34820 -0.114280
# 1261  0.133960  0.37798  0.44027 -0.046066 -0.17349 -0.12375  0.063556
# 1284 -0.130420  0.63192  0.65020  0.086348 -0.44698 -0.37187 -0.177510
# 1285 -0.129410  0.44691  0.43522  0.120880 -0.27632 -0.30755 -0.104170
# 1262  0.094438 -0.14285 -0.14722  0.029113  0.17254  0.18214  0.026177
# ...        ...      ...      ...       ...      ...      ...       ...
# 717   0.505710 -0.56702 -0.50310 -0.382560  0.43214  0.51667  0.228870
# 694   0.570810 -0.55877 -0.49334 -0.392620  0.40435  0.52364  0.230560
# 695   0.367340 -0.46561 -0.40113 -0.402140  0.31879  0.38349  0.203480
# 718   0.346590 -0.48713 -0.43220 -0.418860  0.42117  0.42337  0.206760
# 719   0.101720 -0.23692 -0.24252 -0.280070  0.25524  0.17287  0.127400
#
#          ks238
# 1260  0.173150
# 1261 -0.145510
# 1284  0.114580
# 1285  0.111670
# 1262 -0.091803
# ...        ...
# 717  -0.518930
# 694  -0.551150
# 695  -0.357290
# 718  -0.342960
# 719  -0.114860
#
# [72 rows x 240 columns]

# %%
# to see the proper number of principle components
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
X_drug = e_and_p.iloc[:, 3:240].values

X_drug = StandardScaler().fit_transform(X_drug)
pca = PCA(n_components = 0.9)
pca.fit(X_drug)
reduced = pca.transform(X_drug)
print(len(X_drug[0]))
print(len(reduced[0]))
print(pca.explained_variance_ratio_)
# Out:
# 237
# 8
# [0.35543619 0.21118806 0.10118632 0.08728788 0.07023916 0.04453568
#  0.02395896 0.02087442]

# %%
#see that again
from sklearn.decomposition import PCA
pca = PCA(n_components = 0.95)
pca.fit(X_drug)
reduced = pca.transform(X_drug)
print(len(X_drug[0]))
print(len(reduced[0]))
print(pca.explained_variance_ratio_)
# Out:
# 237
# 13
# [0.35543619 0.21118806 0.10118632 0.08728788 0.07023916 0.04453568
#  0.02395896 0.02087442 0.01154034 0.00733613 0.0069409  0.00641359
#  0.00585744]

# %%
df=pd.read_csv('drug_with_fields.csv')
#one type first type. dna
df11=df.loc[(df['drug_name'] =='Etoposide+Gemcitabine+1') ]
df12=df.loc[(df['drug_name'] =='Etoposide+Gemcitabine+2') ]

df21=df.loc[(df['drug_name'] =='Gemcitabine+Etoposide+1') ]
df22=df.loc[(df['drug_name'] =='Gemcitabine+Etoposide+2') ]

df31=df.loc[(df['drug_name'] =='Etoposide+Etoposide+1') ]
df32=df.loc[(df['drug_name'] =='Etoposide+Etoposide+2') ]

df41=df.loc[(df['drug_name'] =='Gemcitabine+Gemcitabine+1') ]
df42=df.loc[(df['drug_name'] =='Gemcitabine+Gemcitabine+2') ]

df51=df.loc[(df['drug_name'] =='Gemcitabine+DMSO+1') ]
df52=df.loc[(df['drug_name'] =='Gemcitabine+DMSO+2') ]



df61=df.loc[(df['drug_name'] =='Etoposide+DMSO+1') ]
df62=df.loc[(df['drug_name'] =='Etoposide+DMSO+2') ]



frames = [df11, df12,df21,df22,df31,df32,df41,df42,df51,df52,df61,df62]
dna = pd.concat(frames)
dna
# Out:
#                     drug_name  default      ks1       ks2       ks3       ks4  \
# 288   Gemcitabine+Etoposide+1        0  0.17306  0.219080 -0.053243  0.336470
# 289   Gemcitabine+Etoposide+1        0  0.19757  0.397610  0.223340  0.288050
# 312   Gemcitabine+Etoposide+1        0  0.16819  0.353130  0.185070  0.375970
# 313   Gemcitabine+Etoposide+1        0 -0.14083 -0.367980 -0.535750  0.088006
# 290   Gemcitabine+Etoposide+2        0  0.14529  0.356890  0.270510  0.226440
# 291   Gemcitabine+Etoposide+2        0 -0.17292  0.201480 -0.078689  0.259020
# 314   Gemcitabine+Etoposide+2        0  0.23637  0.215890  0.075893  0.230600
# 315   Gemcitabine+Etoposide+2        0  0.19536  0.339220  0.240660  0.166420
# 1260    Etoposide+Etoposide+1        0 -0.77875  0.396060  0.292640  0.123950
# 1261    Etoposide+Etoposide+1        0 -0.38667  0.330700  0.236550  0.137830
# 1284    Etoposide+Etoposide+1        0 -0.88125  0.364670  0.310090  0.265020
# 1285    Etoposide+Etoposide+1        0 -0.56417  0.340780  0.218040  0.083652
# 1262    Etoposide+Etoposide+2        0  0.21785 -0.082260 -0.056185 -0.086997
# 1263    Etoposide+Etoposide+2        0 -0.60125  0.142220  0.160970 -0.195030
# 1286    Etoposide+Etoposide+2        0  0.23576  0.134440  0.149710 -0.125680
# 1287    Etoposide+Etoposide+2        0 -0.28167 -0.071806 -0.041269 -0.168100
# 60         Gemcitabine+DMSO+1        0 -0.18875  0.351840  0.239840  0.149810
# 61         Gemcitabine+DMSO+1        0  0.19388  0.077443 -0.144060  0.115230
# 84         Gemcitabine+DMSO+1        0  0.30279  0.178120 -0.071630  0.126460
# 85         Gemcitabine+DMSO+1        0  0.26543  0.072495 -0.170250  0.178600
# 62         Gemcitabine+DMSO+2        0  0.13227  0.284730  0.150340  0.129070
# 1323 -0.184630  0.129690  0.100300  0.122620 -0.214340 -0.219090 -0.126550
#
#          ks238
# 288  -0.194790
# 289   0.083986
# 312   0.039097
# 313  -0.199560
# 290   0.147920
# 291   0.152750
# 314  -0.137860
# 315   0.085031
# 1260  0.173150
# 1261 -0.145510
# 1284  0.114580
# 1285  0.111670
# 1262 -0.091803
# 1263  0.095081
# 1286 -0.181810
# 1287 -0.071787
# 60    0.194530
# 61   -0.175070
# 84   -0.262950
# 85   -0.223290
# 62    0.085173
# 63   -0.268190
# 86   -0.111430
# 87    0.118130
# 1296 -0.254390
# 1297  0.184910
# 1320  0.283820
# 1321  0.106340
# 1298 -0.077043
# 1299 -0.228130
# 1322 -0.205570
# 1323  0.189340
#
# [32 rows x 240 columns]

# %%
#one type first type. mt
df11=df.loc[(df['drug_name'] =='Paclitaxel+Vinblastine+1') ]
df12=df.loc[(df['drug_name'] =='Paclitaxel+Vinblastine+2') ]

df21=df.loc[(df['drug_name'] =='Vinblastine+Paclitaxel+1') ]
df22=df.loc[(df['drug_name'] =='Vinblastine+Paclitaxel+2') ]

df31=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+1') ]
df32=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+2') ]

df41=df.loc[(df['drug_name'] =='Vinblastine+Vinblastine+1') ]
df42=df.loc[(df['drug_name'] =='Vinblastine+Vinblastine+2') ]

df51=df.loc[(df['drug_name'] =='Paclitaxel+DMSO+1') ]
df52=df.loc[(df['drug_name'] =='Paclitaxel+DMSO+2') ]

df61=df.loc[(df['drug_name'] =='Vinblastine+DMSO+1') ]
df62=df.loc[(df['drug_name'] =='Vinblastine+DMSO+2') ]



frames2 = [df11, df12,df21,df22,df31,df32,df41,df42,df51,df52,df61,df62]
mt= pd.concat(frames)
mt
#print(len(dna),len(mt))
# Out:
#                     drug_name  default      ks1       ks2       ks3       ks4  \
# 288   Gemcitabine+Etoposide+1        0  0.17306  0.219080 -0.053243  0.336470
# 289   Gemcitabine+Etoposide+1        0  0.19757  0.397610  0.223340  0.288050
# 312   Gemcitabine+Etoposide+1        0  0.16819  0.353130  0.185070  0.375970
# 313   Gemcitabine+Etoposide+1        0 -0.14083 -0.367980 -0.535750  0.088006
# 290   Gemcitabine+Etoposide+2        0  0.14529  0.356890  0.270510  0.226440
# 291   Gemcitabine+Etoposide+2        0 -0.17292  0.201480 -0.078689  0.259020
# 314   Gemcitabine+Etoposide+2        0  0.23637  0.215890  0.075893  0.230600
# 315   Gemcitabine+Etoposide+2        0  0.19536  0.339220  0.240660  0.166420
# 1260    Etoposide+Etoposide+1        0 -0.77875  0.396060  0.292640  0.123950
# 1261    Etoposide+Etoposide+1        0 -0.38667  0.330700  0.236550  0.137830
# 1284    Etoposide+Etoposide+1        0 -0.88125  0.364670  0.310090  0.265020
# 1285    Etoposide+Etoposide+1        0 -0.56417  0.340780  0.218040  0.083652
# 1262    Etoposide+Etoposide+2        0  0.21785 -0.082260 -0.056185 -0.086997
# 1263    Etoposide+Etoposide+2        0 -0.60125  0.142220  0.160970 -0.195030
# 1296  0.242050  0.498560  0.587060 -0.101790 -0.398990 -0.123780  0.066441
# 1297 -0.161160  0.494910  0.468700  0.240320 -0.540600 -0.439490 -0.255090
# 1320 -0.280480  0.489410  0.484520  0.072215 -0.492650 -0.453140  0.099123
# 1321 -0.158570  0.411490  0.397460  0.206380 -0.423240 -0.316340 -0.087391
# 1298  0.083224 -0.049670 -0.032375 -0.036301 -0.090245 -0.030341  0.039935
# 1299  0.251090 -0.320680 -0.306550 -0.062574  0.270960  0.322160  0.082416
# 1322  0.200090 -0.093808 -0.059454 -0.053562  0.125650  0.140990  0.055969
# 1323 -0.184630  0.129690  0.100300  0.122620 -0.214340 -0.219090 -0.126550
#
#          ks238
# 288  -0.194790
# 289   0.083986
# 312   0.039097
# 313  -0.199560
# 290   0.147920
# 291   0.152750
# 314  -0.137860
# 315   0.085031
# 1260  0.173150
# 1261 -0.145510
# 1284  0.114580
# 1285  0.111670
# 1262 -0.091803
# 1263  0.095081
# 1286 -0.181810
# 1287 -0.071787
# 60    0.194530
# 61   -0.175070
# 84   -0.262950
# 85   -0.223290
# 62    0.085173
# 63   -0.268190
# 86   -0.111430
# 87    0.118130
# 1296 -0.254390
# 1297  0.184910
# 1320  0.283820
# 1321  0.106340
# 1298 -0.077043
# 1299 -0.228130
# 1322 -0.205570
# 1323  0.189340
#
# [32 rows x 240 columns]

# %%
frames3=[]
for i in range(1,3):
    frames3.append(df.loc[(df['drug_name'] =='17AAG+AUY922+'+str(i)) ])
for j in range(1,3):
    frames3.append(df.loc[(df['drug_name'] =='AUY922+17AAG+'+str(j)) ])
for k in range(1,3):
    frames3.append(df.loc[(df['drug_name'] =='AUY922+AUY922+'+str(k)) ])
for m in range(1,3):
    frames3.append(df.loc[(df['drug_name'] =='17AAG+17AAG+'+str(m)) ])

df51=df.loc[(df['drug_name'] =='17AAG+DMSO+1') ]
df52=df.loc[(df['drug_name'] =='17AAG+DMSO+2') ]

df61=df.loc[(df['drug_name'] =='AUY922+DMSO+1') ]
df62=df.loc[(df['drug_name'] =='AUY922+DMSO+2') ]
another_lst=[df51,df52,df61,df62]
frames3=frames3+another_lst
HSP= pd.concat(frames3)
HSP
# Out:
#             drug_name  default      ks1       ks2      ks3       ks4  \
# 432    17AAG+AUY922+1        0  0.38254 -0.319130 -0.49668  0.102920
# 433    17AAG+AUY922+1        0  0.30820 -0.093626 -0.27533  0.176300
# 456    17AAG+AUY922+1        0  0.30428 -0.190720 -0.40694  0.116050
# 457    17AAG+AUY922+1        0  0.26654 -0.066365 -0.21994  0.116900
# 434    17AAG+AUY922+2        0 -0.14833  0.096539 -0.19490  0.195540
# 435    17AAG+AUY922+2        0  0.28087  0.158100 -0.16509  0.356660
# 458    17AAG+AUY922+2        0  0.20192 -0.356280 -0.55289  0.083562
# 459    17AAG+AUY922+2        0  0.32270 -0.123100 -0.35626  0.108100
# 1356  AUY922+AUY922+1        0 -0.84792  0.180000 -0.17583  0.248750
# 1357  AUY922+AUY922+1        0 -0.57417 -0.128070 -0.23345  0.289200
# 1383  0.560490  0.487580  0.164960 -0.412880 -0.433450 -0.196100  0.308410
# 480  -0.064361  0.092774  0.019503  0.074195  0.260980 -0.045382 -0.236180
# 481   0.074687  0.101250  0.026458  0.114580  0.248650 -0.088750 -0.190940
# 504  -0.066667  0.101250 -0.019722 -0.058472  0.225560 -0.064861 -0.230140
# 505  -0.142780 -0.088722 -0.032774  0.102260  0.275610 -0.058561 -0.245720
# 482   0.123510  0.163290 -0.037751  0.067737  0.223140 -0.035178 -0.187880
# 483   0.117180  0.156700 -0.027432  0.132550  0.226260 -0.030727 -0.178010
# 506   0.180240  0.231380 -0.040060  0.086735  0.146890 -0.069540 -0.136110
# 507  -0.124290 -0.065203 -0.056322  0.221600  0.316910 -0.044201 -0.235370
# 1440  0.194860  0.229070 -0.053922  0.114550  0.136250 -0.048549 -0.114270
# 1441  0.184670  0.212530  0.072728 -0.220580  0.161740 -0.133520 -0.178010
# 1464  0.320130  0.289470  0.084276 -0.278290 -0.270830 -0.166820  0.296780
# 1465  0.395650  0.470120  0.077976 -0.171900  0.142260 -0.113750 -0.310420
# 1442  0.243880  0.265090  0.048286 -0.106890 -0.100390 -0.053087  0.060862
# 1443  0.326290  0.375950  0.069583 -0.234130 -0.094697 -0.118790 -0.078788
# 1466  0.434420  0.432040  0.149050 -0.472580 -0.319490 -0.143970  0.215070
# 1467  0.371160  0.427580  0.064004 -0.255690 -0.207580 -0.117730 -0.088420
#
# [32 rows x 240 columns]

# %%
#Dna ： etoposide，Gemcitabine
#mt：paclitaxel，Vinblastine
#hsp：17aag，auy922

#prot："MG132"，ps341
#hdac：saha，apicidin

frames4=[]
for i in range(1,3):
    frames4.append(df.loc[(df['drug_name'] =='MG132+PS341+'+str(i)) ])
for j in range(1,3):
    frames4.append(df.loc[(df['drug_name'] =='PS341+MG132+'+str(j)) ])
for k in range(1,3):
    frames4.append(df.loc[(df['drug_name'] =='MG132+MG132+'+str(k)) ])
for m in range(1,3):
    frames4.append(df.loc[(df['drug_name'] =='PS341+PS341+'+str(m)) ])
df51=df.loc[(df['drug_name'] =='MG132+DMSO+1') ]
df52=df.loc[(df['drug_name'] =='MG132+DMSO+2') ]

df61=df.loc[(df['drug_name'] =='PS341+DMSO+1') ]
df62=df.loc[(df['drug_name'] =='PS341+DMSO+2') ]
another_lst=[df51,df52,df61,df62]
frames4=frames4+another_lst
PROT= pd.concat(frames4)
PROT
# Out:
#           drug_name  default      ks1      ks2      ks3       ks4      ks5  \
# 396   PS341+MG132+1        0 -0.36708 -0.38086 -0.18950 -0.203010 -0.60708
# 397   PS341+MG132+1        0 -0.18750 -0.35625 -0.25722 -0.144520 -0.62690
# 420   PS341+MG132+1        0 -0.25875 -0.39535 -0.30461 -0.199130 -0.65693
# 421   PS341+MG132+1        0 -0.15500 -0.38833 -0.35250 -0.098333 -0.56583
# 398   PS341+MG132+2        0 -0.32208 -0.37288 -0.25125 -0.148610 -0.57595
# 399   PS341+MG132+2        0 -0.23042 -0.33885 -0.27531 -0.150310 -0.49552
# 1308  0.25902  0.222080 -0.452870 -0.404140 -0.334910  0.173240
# 1309 -0.56724 -0.162530  0.266220  0.246910 -0.197600 -0.151460
# 1332  0.26733  0.215290 -0.437550 -0.402700 -0.381550  0.286760
# 1333 -0.50584 -0.155010  0.184680  0.140190 -0.230590  0.075153
# 1310  0.18129  0.164300 -0.446480 -0.398980 -0.316050  0.383480
# 1311 -0.27768  0.090325  0.097647 -0.205350 -0.187000  0.320850
# 1334 -0.23902 -0.074306 -0.224440 -0.188990 -0.277670  0.267010
# 1335 -0.35455 -0.104200  0.145980  0.124090 -0.187390  0.180000
# 1392 -0.24175  0.100730 -0.235810 -0.238610 -0.261340  0.284320
# 1393 -0.55447 -0.138690  0.320990  0.279770 -0.234750 -0.188700
# 1416 -0.26018  0.060714 -0.198210 -0.215060 -0.264230  0.288990
# 1417  0.30779  0.130850 -0.441010 -0.338700 -0.213380  0.159370
# 1394 -0.19890  0.151870  0.168060  0.233420 -0.142160 -0.120090
# 1395 -0.13608  0.114490  0.059987  0.247030 -0.079625 -0.191980
# 1418 -0.24993  0.092590  0.203080  0.223580 -0.076851 -0.136220
# 1419 -0.17244  0.120100  0.079112 -0.085902 -0.120140  0.099611
# 492  -0.35113 -0.095287  0.075736  0.167010 -0.161980 -0.137160
# 493  -0.32135  0.051807  0.039491  0.209080 -0.148920 -0.148920
# 516  -0.37515 -0.085899  0.098706  0.211340 -0.117630 -0.161600
# 517  -0.34477 -0.062778  0.132750  0.203520 -0.104480 -0.162990
# 494  -0.34190 -0.072885  0.128680  0.318480 -0.065186 -0.286130
# 495  -0.26377  0.061897  0.031779  0.225430 -0.104330 -0.191300
# 518  -0.32891  0.064082  0.064209  0.298150 -0.107250 -0.286580
# 519  -0.29163  0.043657  0.115380  0.257490 -0.060810 -0.216320
#
# [32 rows x 240 columns]

# %%
frames5=[]
for i in range(1,3):
    frames5.append(df.loc[(df['drug_name'] =='SAHA+Apicidin+'+str(i)) ])
for j in range(1,3):
    frames5.append(df.loc[(df['drug_name'] =='Apicidin+SAHA+'+str(j)) ])
for k in range(1,3):
    frames5.append(df.loc[(df['drug_name'] =='Apicidin+Apicidin+'+str(k)) ])
for m in range(1,3):
    frames5.append(df.loc[(df['drug_name'] =='SAHA+SAHA+'+str(m)) ])

df51=df.loc[(df['drug_name'] =='SAHA+DMSO+1') ]
df52=df.loc[(df['drug_name'] =='SAHA+DMSO+2') ]

df61=df.loc[(df['drug_name'] =='Apicidin+DMSO+1') ]
df62=df.loc[(df['drug_name'] =='Apicidin+DMSO+2') ]

another_lst=[df51,df52,df61,df62]
frames5=frames5+another_lst
HDAC= pd.concat(frames5)
HDAC
# Out:
#                 drug_name  default      ks1       ks2       ks3       ks4  \
# 912       Apicidin+SAHA+1        0 -0.37333 -0.207520 -0.130960 -0.168720
# 913       Apicidin+SAHA+1        0  0.15296 -0.157610 -0.069122 -0.165660
# 936       Apicidin+SAHA+1        0 -0.23375 -0.113200 -0.084618 -0.140240
# 937       Apicidin+SAHA+1        0 -0.14000 -0.143000 -0.118130 -0.124860
# 1237  0.305100 -0.389710 -0.381510 -0.089359  0.258110  0.37939 -0.166630
# 1214  0.086482 -0.087814 -0.135240  0.163110 -0.108160  0.25582 -0.098464
# 1215  0.117270 -0.098878 -0.120290  0.092722 -0.089612  0.27149 -0.067738
# 1238  0.118150 -0.062440 -0.065397  0.117220 -0.107340  0.23786 -0.079028
# 1239  0.059217 -0.110550 -0.110650  0.080610  0.123830  0.19897 -0.062195
# 1152  0.174100 -0.166990 -0.202970  0.121050  0.135080  0.30145 -0.078962
# 1153  0.188660 -0.200540 -0.203010 -0.060119  0.160240  0.33443 -0.044643
# 1176 -0.347210  0.230000  0.204070  0.090711 -0.150490 -0.24169 -0.142620
# 1177  0.267770 -0.238650 -0.229860 -0.112500  0.241040  0.35466 -0.057199
# 1154  0.185650 -0.162010 -0.174250  0.061636  0.089552  0.29775 -0.046026
# 1155  0.203870 -0.132420 -0.126480  0.064894  0.087892  0.28387  0.038683
# 1178  0.054114 -0.044615 -0.046499  0.070210  0.371250  0.22306  0.046033
# 1179  0.224490 -0.115410 -0.090586 -0.068754  0.292770  0.38042 -0.050627
# 1104  0.214440 -0.190590 -0.190090  0.055818  0.229210  0.36764 -0.059676
# 1105  0.215710 -0.204780 -0.204890  0.061721  0.202630  0.35730 -0.063678
# 1128  0.091637 -0.102090 -0.140290  0.097039  0.138150  0.30274  0.049668
# 1129  0.183130 -0.191480 -0.197920  0.050107  0.221520  0.34980 -0.038440
# 1106  0.311120 -0.349930 -0.337700 -0.027830  0.317780  0.44635  0.087301
# 1107  0.254900 -0.264410 -0.250760  0.051417  0.203220  0.36298  0.054469
# 1130  0.185310 -0.161460 -0.176670  0.098542  0.203020  0.33740  0.041042
# 1131  0.132790 -0.196810 -0.234660  0.117980  0.239560  0.32927 -0.093371
#
#          ks238
# 912  -0.293600
# 913  -0.189880
# 936  -0.237400
# 937  -0.237280
# 914  -0.172220
# 915  -0.200000
# 938  -0.213480
# 939  -0.182720
# 1212 -0.260330
# 1213 -0.080041
# 1236 -0.208810
# 1237 -0.303690
# 1214 -0.082219
# 1215 -0.116520
# 1238 -0.106290
# 1239 -0.051128
# 1152 -0.167570
# 1153 -0.182110
# 1176  0.336350
# 1177 -0.260550
# 1154 -0.181950
# 1155 -0.193300
# 1178 -0.058803
# 1179 -0.234850
# 1104 -0.205050
# 1105 -0.212550
# 1128 -0.090104
# 1129 -0.191500
# 1106 -0.326370
# 1107 -0.252050
# 1130 -0.195630
# 1131 -0.134750
#
# [32 rows x 240 columns]

# %%
frames6=[]
for i in range(1,3):
    frames6.append(df.loc[(df['drug_name'] =='DMSO+DMSO+'+str(i)) ])

DMSO= pd.concat(frames6)
DMSO
#len(DMSO)
# Out:
#         drug_name  default      ks1       ks2       ks3       ks4       ks5  \
# 1404  DMSO+DMSO+1        0  0.28193 -0.120800 -0.171690  0.105560 -0.088192
# 1405  DMSO+DMSO+1        0 -0.35167 -0.202130 -0.197960 -0.143000 -0.123330
# 1428  DMSO+DMSO+1        0 -0.26333 -0.223560 -0.223560 -0.074205 -0.078636
# 1429  DMSO+DMSO+1        0 -0.90875  0.606230  0.585870 -0.257320  0.501570
# 1452  DMSO+DMSO+1        0 -0.43042  0.198640  0.146110  0.121070  0.237410
# 1453  DMSO+DMSO+1        0  0.18096 -0.053108  0.033851 -0.126070  0.049516
# 1476  DMSO+DMSO+1        0 -0.52750  0.276010  0.303460 -0.145330  0.217900
# 1477  DMSO+DMSO+1        0 -0.56250  0.186680  0.276830 -0.130040  0.163140
# 1488  DMSO+DMSO+1        0  0.31253 -0.321030 -0.397380  0.078948 -0.202090
# 1489  DMSO+DMSO+1        0  0.21851  0.057658 -0.082311  0.239820  0.079555
# 1500  DMSO+DMSO+1        0 -0.40083 -0.135670 -0.146750 -0.050250 -0.067083
# 1501  DMSO+DMSO+1        0  0.21448  0.085059  0.068093 -0.067973  0.072149
# 1512  DMSO+DMSO+1        0  0.24996  0.051981 -0.083216  0.248960  0.064682
# 1513  DMSO+DMSO+1        0  0.13227  0.066549 -0.084442  0.201760 -0.066989
# 1524  DMSO+DMSO+1        0  0.33684  0.034416 -0.040952 -0.058228  0.081374
# 1525  DMSO+DMSO+1        0 -0.44792 -0.080893 -0.090893 -0.126190 -0.061845
# 1406  DMSO+DMSO+2        0  0.24120  0.073456  0.071912 -0.071912  0.134950
# 1407  DMSO+DMSO+2        0 -0.13583 -0.147000 -0.160410 -0.040899 -0.103070
# 1430  DMSO+DMSO+2        0 -0.13792 -0.060757  0.049434 -0.065483  0.113120
# 1431  DMSO+DMSO+2        0 -0.36417  0.253330  0.300230 -0.056806  0.210930
# 1454  DMSO+DMSO+2        0  0.20548 -0.232080 -0.205380 -0.094133 -0.250430
# 1455  DMSO+DMSO+2        0  0.39349 -0.061048 -0.053663 -0.088242  0.087692
# 1478  DMSO+DMSO+2        0  0.20689 -0.542080 -0.523760 -0.216760 -0.425110
# 1479  DMSO+DMSO+2        0 -0.15042 -0.260240 -0.243760 -0.146530 -0.211220
# 1490  DMSO+DMSO+2        0  0.40167 -0.482300 -0.611620  0.268850 -0.579680
# 1491  DMSO+DMSO+2        0  0.40356 -0.206490 -0.351280  0.296360 -0.256090
# 1502  DMSO+DMSO+2        0 -0.21500 -0.133600 -0.133380  0.091013 -0.094338
# 1503  DMSO+DMSO+2        0  0.16322  0.118180  0.155640 -0.120370  0.109250
# 1514  DMSO+DMSO+2        0  0.17625  0.146520  0.067454  0.257730  0.163270
# 1515  DMSO+DMSO+2        0 -0.16083 -0.060406 -0.123230  0.162340 -0.115560
# 1526  DMSO+DMSO+2        0 -0.31833  0.080216  0.079485 -0.095923  0.080036
# 1527  DMSO+DMSO+2        0 -0.37083  0.095056  0.155560 -0.124930 -0.086039
#
#            ks6       ks7       ks8  ...     ks229     ks230     ks231  \
# 1404 -0.164090 -0.165230 -0.161620  ... -0.144880 -0.030822  0.131350
# 1405 -0.187120 -0.192810 -0.191990  ...  0.159460  0.064615 -0.182080
# 1428 -0.196780 -0.231170 -0.233710  ...  0.163640  0.033674 -0.095530
# 1429  0.590090  0.536340  0.555680  ...  0.375640  0.084358  0.386400
# 1488 -0.206260 -0.150780 -0.100520  0.126980  0.275030  0.096608 -0.287700
# 1489 -0.169590 -0.118170 -0.095479  0.295480  0.274160  0.063980 -0.201140
# 1500  0.078417  0.068167 -0.076000 -0.126750 -0.112920 -0.042750  0.119330
# 1501 -0.090763 -0.093320  0.028239  0.135560  0.109390  0.037128  0.043021
# 1512 -0.063219  0.060671 -0.057452  0.110350  0.116250  0.040815 -0.130400
# 1513  0.054458 -0.059819 -0.025000  0.155390  0.052170 -0.093538  0.069379
# 1524 -0.153860 -0.134090 -0.053489  0.164830  0.173660  0.066028 -0.120520
# 1525  0.070714  0.084881  0.061488 -0.134640 -0.131370 -0.064226  0.136130
# 1406 -0.151320 -0.157430 -0.035319  0.203550  0.158530  0.048284 -0.081495
# 1407 -0.038099  0.027697 -0.030295 -0.094069  0.063158  0.070962 -0.066153
# 1430 -0.047765 -0.034315  0.028133 -0.072948 -0.057630  0.039940  0.045858
# 1431  0.106440  0.099537  0.088380 -0.068704 -0.130510 -0.102040  0.105740
# 1454 -0.216300 -0.210220  0.032350  0.091283  0.168470  0.028683 -0.094467
# 1455 -0.352520 -0.308300 -0.101870  0.299280  0.345680  0.102630 -0.290880
# 1478 -0.332270 -0.358070  0.063555  0.187520  0.363360 -0.065843 -0.238440
# 1479 -0.069781 -0.077036 -0.034385 -0.109140 -0.070048 -0.043210  0.076291
# 1490 -0.272000 -0.226080 -0.088326  0.131990  0.321080  0.067275 -0.304050
# 1491 -0.192610 -0.135090 -0.112380  0.167700  0.245950  0.052275 -0.235490
# 1502  0.077201  0.084449  0.086878 -0.097726 -0.077242 -0.043945  0.084100
# 1503 -0.228160 -0.231970 -0.047522  0.285040  0.242760  0.072829 -0.139010
# 1514 -0.048116 -0.033541 -0.110150  0.164600  0.111220  0.056916 -0.109790
# 1515  0.091506  0.078141  0.044006 -0.099530 -0.117350 -0.078323  0.084573
# 1526 -0.052645  0.068674 -0.070544  0.072244  0.140110  0.071049 -0.177630
# 1527  0.081887 -0.071077  0.120000 -0.059209 -0.157560 -0.086859  0.253510
#
# [32 rows x 240 columns]

# %%
combi=frames+frames2+frames3+frames4+frames5+frames6
training= pd.concat(combi)

print(len(training))
# Out:
# 192

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

X_drug = training.iloc[:, 2:240].values

X_drug = StandardScaler().fit_transform(X_drug)

pca_drug = PCA(n_components=8)
components = pca_drug.fit_transform(X_drug)
components
principalDf = pd.DataFrame(data = components
             , columns = ['principal component 1', 'principal component 2','principal component 3', 'principal component 4','principal component 5', 'principal component 6','principal component 7', 'principal component 8'])
principalDf
# Out:
#      principal component 1  principal component 2  principal component 3  \
# 0                 6.760969               2.209524              -9.046118
# 1                 6.357031               8.391221              -9.321456
# 2                 6.265565               5.322309              -8.023314
# 3                 1.010550               2.568477              -6.657290
# 4                 6.934998              11.264736              -5.481955
# ..                     ...                    ...                    ...
# 187              -2.240835               3.498694              -7.084789
# 188               2.259008               4.153742              -6.298908
# 189              -0.287842               8.426695              -0.170663
# 190              -2.401563               8.285019              -9.343254
# 191              -3.583347              10.871820               0.364323
#
#      principal component 4  principal component 5  principal component 6  \
# 0                -1.197911              -0.684326              -3.448654
# 1                 8.015750               2.434229              -0.926539
# 2                 4.299766               5.107189              -4.043344
# 3                -8.055369             -12.075460               1.240920
# 4                 8.006162               2.050578              -2.181269
# ..                     ...                    ...                    ...
# 187              -1.364050               3.429144              -6.894723
# 188               0.305713               3.679237              -2.611310
# 189               7.921060              -4.622038               2.000614
# 190              -2.080821              -1.283934               2.084570
# 191               2.816775               1.378415              -2.774685
#
#      principal component 7  principal component 8
# 0                -0.980760               0.833803
# 1                -2.435199              -0.667717
# 2                -1.686767              -0.841781
# 3                -3.020952               2.659951
# 4                -2.798423              -1.544231
# ..                     ...                    ...
# 187               2.261249              -1.812041
# 188              -0.977183              -0.890192
# 189              -0.834651              -1.895973
# 190               1.198727               3.816875
# 191               5.080467              -1.223045
#
# [192 rows x 8 columns]

# %%
type(training.iloc[:, 0].values)
import numpy as np
all_names=np.ndarray.tolist(training.iloc[:,0].values)

# %%
components2=np.ndarray.tolist(components)

for i in range(len(all_names)):
    components2[i].append(all_names[i])
#components2

# %%
#class preparation
train_drug_name_without_concentration2=[]
#dna,mt,hsp,prot,hdac
for i in range(32):
    train_drug_name_without_concentration2.append('DNA')
for i in range(32):
    train_drug_name_without_concentration2.append('MT')
for i in range(32):
    train_drug_name_without_concentration2.append('HSP')
for i in range(32):
    train_drug_name_without_concentration2.append('PROT')
for i in range(32):
    train_drug_name_without_concentration2.append('HDAC')
for i in range(32):
    train_drug_name_without_concentration2.append("DMSO")

#train_drug_name_without_concentration2

# %%
fig = px.scatter(components, x=0, y=1, color=train_drug_name_without_concentration2)
fig.show()

# %%
def get_centroid(point_lst):
    x_sum=0
    y_sum=0
    z1_sum=0
    z2_sum=0
    z3_sum=0
    z4_sum=0
    z5_sum=0
    z6_sum=0


    for i in range(len(point_lst)):
        x_sum+=point_lst[i][0]
        y_sum+=point_lst[i][1]
        z1_sum+=point_lst[i][2]
        z2_sum+=point_lst[i][3]
        z3_sum+=point_lst[i][4]
        z4_sum+=point_lst[i][5]
        z5_sum+=point_lst[i][6]
        z6_sum+=point_lst[i][7]


    x_mean=x_sum/len(point_lst)
    y_mean=y_sum/len(point_lst)
    z1_mean=z1_sum/len(point_lst)
    z2_mean=z2_sum/len(point_lst)
    z3_mean=z3_sum/len(point_lst)
    z4_mean=z4_sum/len(point_lst)
    z5_mean=z5_sum/len(point_lst)
    z6_mean=z6_sum/len(point_lst)
    centroid=[]
    centroid.append(x_mean)
    centroid.append(y_mean)
    centroid.append(z1_mean)
    centroid.append(z2_mean)
    centroid.append(z3_mean)
    centroid.append(z4_mean)
    centroid.append(z5_mean)
    centroid.append(z6_mean)
    
    return centroid

# %%
training
# Out:
#                     drug_name  default      ks1       ks2       ks3       ks4  \
# 288   Gemcitabine+Etoposide+1        0  0.17306  0.219080 -0.053243  0.336470
# 289   Gemcitabine+Etoposide+1        0  0.19757  0.397610  0.223340  0.288050
# 312   Gemcitabine+Etoposide+1        0  0.16819  0.353130  0.185070  0.375970
# 313   Gemcitabine+Etoposide+1        0 -0.14083 -0.367980 -0.535750  0.088006
# 290   Gemcitabine+Etoposide+2        0  0.14529  0.356890  0.270510  0.226440
# ...                       ...      ...      ...       ...       ...       ...
# 1503              DMSO+DMSO+2        0  0.16322  0.118180  0.155640 -0.120370
# 1514              DMSO+DMSO+2        0  0.17625  0.146520  0.067454  0.257730
# 1515              DMSO+DMSO+2        0 -0.16083 -0.060406 -0.123230  0.162340
# 1526              DMSO+DMSO+2        0 -0.31833  0.080216  0.079485 -0.095923
# 1527              DMSO+DMSO+2        0 -0.37083  0.095056  0.155560 -0.124930
#
#            ks5       ks6       ks7       ks8  ...     ks229     ks230  \
# 288   0.184400 -0.069588 -0.058647 -0.062607  ...  0.165150 -0.034639
# 289   0.421090  0.169830  0.229360  0.237120  ...  0.240370 -0.047966
# 312   0.332010  0.118060  0.191600  0.198190  ...  0.141530 -0.046458
# 313  -0.299360 -0.510220 -0.551110 -0.553600  ...  0.237900 -0.027997
# 290   0.397160  0.237380  0.254320  0.254030  ...  0.296920  0.032509
# ...        ...       ...       ...       ...  ...       ...       ...
# 1503  0.109250  0.188160  0.135920  0.135700  ... -0.207700 -0.047522
# 1514  0.163270 -0.063778  0.091284  0.098474  ...  0.055885 -0.110150
# 1515 -0.115560 -0.143340 -0.106500 -0.104360  ...  0.076271  0.044006
# 1526  0.080036  0.089363  0.078124  0.068124  ...  0.078173 -0.070544
# 1527 -0.086039  0.174390  0.140600  0.147200  ... -0.126880  0.120000
#
#          ks231     ks232     ks233     ks234     ks235     ks236     ks237  \
# 288   0.190640  0.173850  0.221510 -0.034639  0.219360  0.238150  0.074180
# 289  -0.107710  0.238880  0.250470 -0.047966  0.200810 -0.086302  0.045653
# 312  -0.046597  0.136530  0.162850 -0.046458  0.275140  0.057083 -0.045694
# 313   0.209760  0.271750  0.311850 -0.027997 -0.291240  0.183490  0.121260
# 290  -0.176890  0.323380  0.331790  0.032509 -0.084316 -0.250850  0.066819
# ...        ...       ...       ...       ...       ...       ...       ...
# 1503  0.144190 -0.228160 -0.231970 -0.047522  0.285040  0.242760  0.072829
# 1514  0.107740 -0.048116 -0.033541 -0.110150  0.164600  0.111220  0.056916
# 1515 -0.081197  0.091506  0.078141  0.044006 -0.099530 -0.117350 -0.078323
# 1526  0.184600 -0.052645  0.068674 -0.070544  0.072244  0.140110  0.071049
# 1527 -0.253070  0.081887 -0.071077  0.120000 -0.059209 -0.157560 -0.086859
#
#          ks238
# 288  -0.194790
# 289   0.083986
# 312   0.039097
# 313  -0.199560
# 290   0.147920
# ...        ...
# 1503 -0.139010
# 1514 -0.109790
# 1515  0.084573
# 1526 -0.177630
# 1527  0.253510
#
# [192 rows x 240 columns]

# %%
len(principalDf[-32:])
# Out:
# 32

# %%
#DMSO filtering part
dmso_centroid=get_centroid(components[-32:])

# %%
dmso_lst=components[-32:]

# %%
#calculating the distance
from math import sqrt
def euclidean_distance(row1, row2):
    distance =0
	#print(len(row1)-1) this is to ensure that we calculate 6 points
    for i in range(len(row1)-1):

	

        distance += (row1[i] - row2[i])**2
    return sqrt(distance)

# %%
dist_lst=[]
for i in range(len(dmso_lst)):
    dist_lst.append(euclidean_distance(dmso_lst[i],dmso_centroid))
dist_lst.sort()
print(len(dist_lst))
max_ave=sum(dist_lst[-5:-1])/len(dist_lst[-5:-1])
max_ave
max_ave*=2
max_ave
# Out:
# 32
# 30.372306613832187

# %%
#outlier computation
# method 1.
Q1 = np.percentile(dist_lst , 25)
Q3 = np.percentile(dist_lst , 75)
# method 2.
Q1,Q3 = np.percentile(dist_lst , [25,75])

# %%
IQR = Q3 - Q1
ul = Q3+1.5*IQR
ll = Q1-1.5*IQR
print(ul,ll)
# Out:
# 16.022946342088872 1.8720613478730996

# %%
Q1
# Out:
# 7.178643220704014

# %%
Q3
# Out:
# 10.716364469257957

# %%
def euclidean_distance2(row1, row2):
    distance =0
	#print(len(row1)-1) this is to ensure that we calculate 6 points
    for i in range(8):

	

        distance += (row1[i] - row2[i])**2
    return sqrt(distance)

# %%
dist_lst2=[]
filtered_lst=[]
index_lst=[]
for i in range(len(components2[:160])):
    dist_lst2.append(euclidean_distance2(components2[i],dmso_centroid))
    if euclidean_distance2(components2[i],dmso_centroid)>ul:
        filtered_lst.append(components2[i])
        index_lst.append(i)
#filtered_lst
#dist_lst2
print(len(filtered_lst))
print(len(dist_lst2))
print(len(index_lst))
#filtered_lst
# Out:
# 84
# 160
# 84

# %%
#index_lst

# %%
# labels for class. second time
class_name=[]
cnt1=cnt2=cnt3=cnt4=cnt5=0

for i in range(len(index_lst)):
    if index_lst[i]<32:
        class_name.append('DNA')
        cnt1+=1

    
    elif index_lst[i]<64:
        class_name.append('MT')
        cnt2+=1

    
    elif index_lst[i]<96:
        class_name.append('HSP')
        cnt3+=1
    
    elif index_lst[i]<128:
        cnt4+=1
        
        class_name.append('PROT')
    
    elif index_lst[i]<160:
        cnt5+=1
        class_name.append('HDAC')

for i in range(32):
    class_name.append("DMSO")
len(class_name)
predict_counter=[cnt1,cnt2,cnt3,cnt4,cnt5]
print(predict_counter)
# Out:
# [6, 23, 31, 19, 5]

# %%
#second scatterplot
components5=[]
for i in range(len(index_lst)):
    components5.append(components[i])
for i in range(160,192):
    components5.append(components[i])
components5
# Out:
# [array([ 6.76096911,  2.20952377, -9.04611836, -1.19791131, -0.68432623,
#         -3.44865406, -0.98075983,  0.83380293]),
#  array([ 6.35703093,  8.39122092, -9.32145605,  8.01574983,  2.43422897,
#         -0.92653948, -2.43519912, -0.66771693]),
#  array([ 6.26556453,  5.32230911, -8.02331361,  4.29976608,  5.107189  ,
#         -4.04334401, -1.6867668 , -0.84178116]),
#  array([  1.0105504 ,   2.56847671,  -6.65728961,  -8.05536948,
#         -12.07546021,   1.2409201 ,  -3.02095182,   2.65995108]),
#  array([ 6.93499808, 11.26473633, -5.48195502,  8.00616223,  2.05057761,
#         -2.18126894, -2.79842339, -1.5442305 ]),
#  array([ 5.65925735,  8.46944427, -4.56118286, -0.72240886,  1.83630478,
#         -5.32279004, -1.89292856, -1.09785659]),
#  array([ 3.65828914,  5.0626098 , -8.69449856,  6.70905619, -3.98753348,
#   -1.5055727012938334,
#   -1.6285036932001962,
#   'MG132+MG132+2'],
#  [-10.236010199970513,
#   5.748344343977433,
#   11.957504751634618,
#   0.8235629656821856,
#   -1.8713983320890404,
#   -0.8967318757960996,
#   -0.6334021864519701,
#   -0.6879690761385922,
#   'MG132+DMSO+1'],
#  [-13.971228648581567,
#   -3.129400947413465,
#   4.6760260832220135,
#   3.686524723306145,
#   7.52601634257981,
#   -4.711572374766742,
#   -0.38130205148472,
#   1.5001982023609692,
#   'MG132+DMSO+1'],
#  [-11.547705237545621,
#   4.057409621599819,
#   11.091397767354989,
#   -0.8429164412514842,
#   -0.9279169474576919,
#   0.8497236454800305,
#   -1.653278876040946,
#   -0.033168863863606596,
#   'MG132+DMSO+1'],
#  [-8.965832389108057,
#   11.97049682674414,
#   15.076819680881188,
#   -4.742114540518108,
#   -2.4690324646540507,
#   -2.01525234921803,
#   -0.5497796396668856,
#   -3.8597575459822684,
#   'MG132+DMSO+1'],
#  [-13.428767042585845,
#   -0.4061355794818497,
#   3.419506061394323,
#   0.2673791956279658,
#   0.021935082260941655,
#   -1.0059044884152235,
#   -1.8954101812872235,
#   3.9593077492292292,
#   'PS341+DMSO+1'],
#  [-13.214180558026074,
#   -1.4455174992730953,
#   2.075657032141086,
#   -0.218179139279883,
#   1.0980035838484286,
#   -0.7497038226053624,
#   -1.622492524093998,
#   4.53240411679788,
#   'PS341+DMSO+1'],
#  [-12.906173481123929,
#   -2.5100923680001914,
#   4.291719118422221,
#   -1.3832146042266154,
#   -2.7005627730762134,
#   -5.336471403044237,
#   -2.869297985180838,
#   4.617462635549303,
#   'PS341+DMSO+2'],
#  [2.396031748750743,
#   -5.102035251980702,
#   0.1564137618695422,
#   -4.01781162898253,
#   2.0995095299828015,
#   7.017713553959846,
#   5.769352696502447,
#   1.0863281137483154,
#   'Apicidin+Apicidin+1'],
#  [10.074477206102545,
#   -0.6218271090725099,
#   5.364083845790307,
#   -1.5177847718094692,
#   2.6004627045894435,
#   5.788192314464297,
#   3.3497301272084234,
#   -1.8639805929340885,
#   'SAHA+DMSO+1'],
#  [2.5559475059781804,
#   -7.227613270243007,
#   1.2692991047484832,
#   13.962883082071219,
#   -3.2605868693708695,
#   4.821885968525944,
#   3.7182243954663736,
#   -3.15318221902647,
#   'SAHA+DMSO+1'],
#  [12.514942895626385,
#   -6.694776341643409,
#   -4.426635358038853,
#   5.218288707756859,
#   6.687369834866278,
#   1.0672933410996353,
#   3.6275172205474315,
#   -1.103156294314016,
#   'SAHA+DMSO+2'],
#  [7.567509758023959,
#   -6.955825467987919,
#   -1.8619494906209235,
#   10.67660274776486,
#   -1.5773727947980352,
#   5.17866103061981,
#   2.7484558025848065,
#   0.3239184484916036,
#   'SAHA+DMSO+2']]

# %%
fig = px.scatter(components5, x=0, y=1, color=class_name)
#training['drug_name']
fig.show()

# %%
#after using pca to do the filter, we gonna use LDA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
model = LinearDiscriminantAnalysis(n_components=4)
y2=[]
for i in range(32):
    y2.append('DNA')
for j in range(32):
    y2.append('MT')
for k in range(32):
    y2.append('HSP')
for m in range(32):
    y2.append('PROT')
for n in range(32):
    y2.append('HDAC')
for k in range(32):
    y2.append("DMSO")
#model.fit(X_drug, y)
#X_drug2 = model.transform(X_drug)
X_drug5=training.iloc[:,2:240].values
X_drug5=model.fit(X_drug5,y2).transform(X_drug5)

# %%
len(X_drug5)
# Out:
# 192

# %%
# Create a function
def select_n_components(var_ratio, goal_var: float) -> int:
    # Set initial variance explained so far
    total_variance = 0.0
    
    # Set initial number of features
    n_components = 0
    
    # For the explained variance of each feature:
    for explained_variance in var_ratio:
        
        # Add the explained variance to the total
        total_variance += explained_variance
        
        # Add one to the number of components
        n_components += 1
        
        # If we reach our goal level of explained variance
        if total_variance >= goal_var:
            # End the loop
            break
            
    # Return the number of components
    return n_components

# %%
lda = LinearDiscriminantAnalysis(n_components=None)
X_lda=lda.fit(X_drug5,y2)
lda_var_ratios = lda.explained_variance_ratio_
print(lda_var_ratios)
print(select_n_components(lda_var_ratios, 0.95))
print(select_n_components(lda_var_ratios, 0.85))
print(select_n_components(lda_var_ratios, 0.75))
print(select_n_components(lda_var_ratios, 0.65))
print(select_n_components(lda_var_ratios, 0.35))
#print(X_drug5)
# Out:
# [0.38284556 0.31650891 0.20396575 0.09667978]
# 4
# 3
# 3
# 2
# 1

# %%
filtered_lda=np.ndarray.tolist(X_drug5)

# %%
#filtered_lda
filtered_drug=[]
for i in range(len(index_lst)):
    filtered_drug.append(filtered_lda[i])
for i in range(160,192):
    filtered_drug.append(filtered_lda[i])
print(len(filtered_drug),len(class_name))
# Out:
# 116 116

# %%
fig = px.scatter(filtered_drug, x=0, y=1, color=class_name)
#training['drug_name']
fig.show()

# %%
#original figure
class_name
fig = px.scatter(X_drug5, x=0, y=1, color=train_drug_name_without_concentration2)
#training['drug_name']
fig.show()

# %%
#bootstrapping
for i in range(len(filtered_lst)):
    print(filtered_lst[i][-1])
# Out:
# Etoposide+Etoposide+1
# Etoposide+Etoposide+1
# Etoposide+DMSO+1
# Etoposide+DMSO+1
# Etoposide+DMSO+1
# Etoposide+DMSO+1
# Paclitaxel+Vinblastine+1
# Paclitaxel+Vinblastine+1
# Paclitaxel+Vinblastine+1
# Paclitaxel+Vinblastine+1
# Paclitaxel+Vinblastine+2
# Paclitaxel+Vinblastine+2
# Paclitaxel+Vinblastine+2
# Paclitaxel+Vinblastine+2
# Paclitaxel+Paclitaxel+1
# Paclitaxel+Paclitaxel+1
# Paclitaxel+Paclitaxel+1
# Paclitaxel+Paclitaxel+1
# Paclitaxel+DMSO+1
# Paclitaxel+DMSO+1
# Paclitaxel+DMSO+1
# Paclitaxel+DMSO+1
# Paclitaxel+DMSO+2
# Paclitaxel+DMSO+2
# Paclitaxel+DMSO+2
# Vinblastine+DMSO+1
# Vinblastine+DMSO+1
# Vinblastine+DMSO+1
# Vinblastine+DMSO+1
# 17AAG+AUY922+1
# 17AAG+AUY922+1
# 17AAG+AUY922+1
# 17AAG+AUY922+1
# 17AAG+AUY922+2
# 17AAG+AUY922+2
# 17AAG+AUY922+2
# 17AAG+AUY922+2
# AUY922+AUY922+1
# AUY922+AUY922+1
# AUY922+AUY922+1
# AUY922+AUY922+1
# AUY922+AUY922+2
# AUY922+AUY922+2
# AUY922+AUY922+2
# AUY922+AUY922+2
# 17AAG+DMSO+1
# 17AAG+DMSO+1
# 17AAG+DMSO+1
# 17AAG+DMSO+2
# 17AAG+DMSO+2
# 17AAG+DMSO+2
# 17AAG+DMSO+2
# AUY922+DMSO+1
# AUY922+DMSO+1
# AUY922+DMSO+1
# AUY922+DMSO+1
# AUY922+DMSO+2
# AUY922+DMSO+2
# AUY922+DMSO+2
# AUY922+DMSO+2
# PS341+MG132+1
# PS341+MG132+1
# PS341+MG132+1
# PS341+MG132+2
# PS341+MG132+2
# MG132+MG132+1
# MG132+MG132+1
# MG132+MG132+1
# MG132+MG132+1
# MG132+MG132+2
# MG132+MG132+2
# MG132+MG132+2
# MG132+DMSO+1
# MG132+DMSO+1
# MG132+DMSO+1
# MG132+DMSO+1
# PS341+DMSO+1
# PS341+DMSO+1
# PS341+DMSO+2
# Apicidin+Apicidin+1
# SAHA+DMSO+1
# SAHA+DMSO+1
# SAHA+DMSO+2
# SAHA+DMSO+2

# %%
len(filtered_lst)
# Out:
# 84

# %%
def accuracy(list1,list2):
    length=len(list1)
    list3=[]
    for i in range(cnt1//4):
        list3.append(list2[0])
    for j in range(cnt2//4):
        list3.append(list2[1])
    for m in range(cnt3//4):
        list3.append(list2[2])
    for n in range(cnt4//4):
        list3.append(list2[3])
    for k in range(cnt5//4):
        list3.append(list2[4])
    for k in range(8):
        list3.append(list2[5])

    counter=0
    for k in range(len(list1)):

        if list1[k]==list3[k]:
            counter+=1
    return counter/length

# %%
len(index_lst)
# Out:
# 84

# %%
lst=[1,2,3,4,5,6]
print(lst[:4])
# Out:
# [1, 2, 3, 4]

# %%
print(predict_counter)
#predict:1,5,7,4,1  18
#training:84-18=56
#56+24=90
# Out:
# [6, 23, 31, 19, 5]

# %%
len(training_index)
# Out:
# 96

# %%
#training and testing data preparation
#

import random
global random_chosen
global chosen_index_lst
global left_lst

random_chosen=[]
chosen_index_lst=[]

chosen_index_lst+=random.sample(index_lst[:cnt1],cnt1//4)
chosen_index_lst+=random.sample(index_lst[cnt1:cnt1+cnt2],cnt2//4)
chosen_index_lst+=random.sample(index_lst[cnt1+cnt2:cnt1+cnt2+cnt3],cnt3//4)
chosen_index_lst+=random.sample(index_lst[cnt1+cnt2+cnt3:cnt1+cnt2+cnt3+cnt4],cnt4//4)
chosen_index_lst+=random.sample(index_lst[cnt1+cnt2+cnt3+cnt4:cnt1+cnt2+cnt3+cnt4+cnt5],cnt5//4)
chosen_index_lst

#print([cnt1,cnt2,cnt3,cnt4,cnt5])
#print(chosen_index_lst)
left_lst=list(set(index_lst)^set(chosen_index_lst))
#print(left_lst)
#print(len(chosen_index_lst))
#print(len(left_lst))
#print(len(chosen_index_lst)+len(left_lst))

# %%
len(chosen_index_lst)
len(index_lst)
len(left_lst)
# Out:
# 66

# %%
#training and testing dataset
import random

global training_index
global testing_index
global dmso_left
global left_lst

dmso_index=[]
for i in range(160,192):
    dmso_index.append(i)
dmso_chosen=random.sample(dmso_index,32//4)
#chosen_index_lst+=dmso_chosen
dmso_left=list(set(dmso_index)^set(dmso_chosen))
print(len(dmso_left))
training_index=left_lst+dmso_left
testing_index=chosen_index_lst+dmso_chosen
#print(len(training_index))
#print(len(testing_index))
# Out:
# 24

# %%
len(dmso_left)
len(left_lst)
# Out:
# 66

# %%
#training data and testing data

global X_train
global X_test
X_train=[]
X_test=[]
for i in range(len(training_index)):
    X_train.append(X_drug5[training_index[i]])
for i in range(len(testing_index)):
    X_test.append(X_drug5[testing_index[i]])

# %%
len(index_lst)
# Out:
# 84

# %%
# labels for class. second time

global class_name_train
index_lst2=training_index
print(len(index_lst2))
#class_name_train=[]
#cnt1=cnt2=cnt3=cnt4=cnt5=0
class_name_train=[]
for i in range(len(index_lst2)):
    if index_lst2[i]<32:
        class_name_train.append('DNA')
        
        #cnt1+=1

    
    elif index_lst2[i]<64:
        class_name_train.append('MT')
        
        #cnt2+=1

    
    elif index_lst2[i]<96:
        class_name_train.append('HSP')
        
    #cnt3+=1

    elif index_lst2[i]<128:
        #cnt4+=1
        
        class_name_train.append('PROT')
        
    
    elif index_lst2[i]<160:
        #cnt5+=1
        class_name_train.append('HDAC')
        
print(len(class_name_train))
for i in range(24):
    class_name_train.append("DMSO")
print(len(class_name_train))
#print(len(class_name))
#predict_counter=[cnt1,cnt2,cnt3,cnt4,cnt5]
#print(predict_counter)
#class_name_train=class_name
# Out:
# 90
# 66
# 90

# %%
label_setting()
# Out:
# 90
# 66
# 90

# %%
len(training_index)
len(testing_index)
# Out:
# 26

# %%
#prediction LDA
model2 = LinearDiscriminantAnalysis(n_components=4)
model2.fit(X_train,class_name_train)
yhat2=model2.predict(X_test)

print(yhat2)
print(len(yhat2))
# Out:
# ['DNA' 'MT' 'MT' 'MT' 'MT' 'MT' 'HSP' 'HSP' 'HSP' 'HSP' 'HSP' 'HSP' 'HSP'
#  'PROT' 'PROT' 'PROT' 'PROT' 'HDAC' 'DMSO' 'DMSO' 'DMSO' 'DMSO' 'DMSO'
#  'DMSO' 'DMSO' 'DMSO']
# 26

# %%
#accuracy
accuracy( yhat2,['DNA',"MT","HSP","PROT","HDAC","DMSO"])
# Out:
# 1.0

# %%
accuracy_lst=[]
def pipeline():
    
    import random
    global random_chosen
    global chosen_index_lst
    global left_lst

    random_chosen=[]
    chosen_index_lst=[]

    chosen_index_lst+=random.sample(index_lst[:cnt1],cnt1//4)
    chosen_index_lst+=random.sample(index_lst[cnt1:cnt1+cnt2],cnt2//4)
    chosen_index_lst+=random.sample(index_lst[cnt1+cnt2:cnt1+cnt2+cnt3],cnt3//4)
    chosen_index_lst+=random.sample(index_lst[cnt1+cnt2+cnt3:cnt1+cnt2+cnt3+cnt4],cnt4//4)
    chosen_index_lst+=random.sample(index_lst[cnt1+cnt2+cnt3+cnt4:cnt1+cnt2+cnt3+cnt4+cnt5],cnt5//4)
    chosen_index_lst

    #print([cnt1,cnt2,cnt3,cnt4,cnt5])
    #print(chosen_index_lst)
    left_lst=list(set(index_lst)^set(chosen_index_lst))
    #print(left_lst)
    #print(len(chosen_index_lst))
    #print(len(left_lst))
    #print(len(chosen_index_lst)+len(left_lst))



    # %%
    #training and testing dataset
    import random

    global training_index
    global testing_index
    global dmso_left
    

    dmso_index=[]
    for i in range(160,192):
        dmso_index.append(i)
    dmso_chosen=random.sample(dmso_index,32//4)
    #chosen_index_lst+=dmso_chosen
    dmso_left=list(set(dmso_index)^set(dmso_chosen))
    #print(len(dmso_left))
    training_index=left_lst+dmso_left
    testing_index=chosen_index_lst+dmso_chosen
    #print(len(training_index))
    #print(len(testing_index))


    # %%
    #training data and testing data

    global X_train
    global X_test
    X_train=[]
    X_test=[]
    for i in range(len(training_index)):
        X_train.append(X_drug5[training_index[i]])
    for i in range(len(testing_index)):
        X_test.append(X_drug5[testing_index[i]])


    # %%
    #len(index_lst)

    # %%
    # labels for class. second time

    global class_name_train
    index_lst2=training_index
    #print(len(index_lst2))
    #class_name_train=[]
    #cnt1=cnt2=cnt3=cnt4=cnt5=0
    class_name_train=[]
    for i in range(len(index_lst2)):
        if index_lst2[i]<32:
            class_name_train.append('DNA')
            
            #cnt1+=1

        
        elif index_lst2[i]<64:
            class_name_train.append('MT')
            
            #cnt2+=1

        
        elif index_lst2[i]<96:
            class_name_train.append('HSP')
            
        #cnt3+=1

        elif index_lst2[i]<128:
            #cnt4+=1
            
            class_name_train.append('PROT')
            
        
        elif index_lst2[i]<160:
            #cnt5+=1
            class_name_train.append('HDAC')
            
    #print(len(class_name_train))
    for i in range(24):
        class_name_train.append("DMSO")
    #print(len(class_name_train))
    #print(len(class_name))
    #predict_counter=[cnt1,cnt2,cnt3,cnt4,cnt5]
    #print(predict_counter)
    #class_name_train=class_name




    # %%
    #prediction LDA
    model2 = LinearDiscriminantAnalysis(n_components=4)
    model2.fit(X_train,class_name_train)
    yhat2=model2.predict(X_test)

    #print(yhat2)
    #print(len(yhat2))

    # %%
    #accuracy
    accuracy_score=accuracy( yhat2,['DNA',"MT","HSP","PROT","HDAC","DMSO"])
    accuracy_lst.append(accuracy_score)

    # %%

# %%
#ten times test (LDA)
accuracy_lst=[]
for i in range(20):
    pipeline()
print(accuracy_lst)
print("average accuracy: "+str(sum(accuracy_lst)/len(accuracy_lst)))
# Out:
# [0.9230769230769231, 0.9615384615384616, 0.8846153846153846, 1.0, 0.9615384615384616, 0.9615384615384616, 0.9615384615384616, 0.9230769230769231, 0.9615384615384616, 1.0, 0.9615384615384616, 0.9230769230769231, 0.9230769230769231, 0.9615384615384616, 1.0, 1.0, 0.9615384615384616, 0.9615384615384616, 1.0, 0.9615384615384616]
# average accuracy: 0.9596153846153845

# %%
#prediction
accuracy_lst=[]
def pipeline():
    
    import random
    global random_chosen
    global chosen_index_lst
    global left_lst

    random_chosen=[]
    chosen_index_lst=[]

    chosen_index_lst+=random.sample(index_lst[:cnt1],cnt1//4)
    chosen_index_lst+=random.sample(index_lst[cnt1:cnt1+cnt2],cnt2//4)
    chosen_index_lst+=random.sample(index_lst[cnt1+cnt2:cnt1+cnt2+cnt3],cnt3//4)
    chosen_index_lst+=random.sample(index_lst[cnt1+cnt2+cnt3:cnt1+cnt2+cnt3+cnt4],cnt4//4)
    chosen_index_lst+=random.sample(index_lst[cnt1+cnt2+cnt3+cnt4:cnt1+cnt2+cnt3+cnt4+cnt5],cnt5//4)
    chosen_index_lst

    #print([cnt1,cnt2,cnt3,cnt4,cnt5])
    #print(chosen_index_lst)
    left_lst=list(set(index_lst)^set(chosen_index_lst))
    #print(left_lst)
    #print(len(chosen_index_lst))
    #print(len(left_lst))
    #print(len(chosen_index_lst)+len(left_lst))



    # %%
    #training and testing dataset
    import random

    global training_index
    global testing_index
    global dmso_left
    

    dmso_index=[]
    for i in range(160,192):
        dmso_index.append(i)
    dmso_chosen=random.sample(dmso_index,32//4)
    #chosen_index_lst+=dmso_chosen
    dmso_left=list(set(dmso_index)^set(dmso_chosen))
    #print(len(dmso_left))
    training_index=left_lst+dmso_left
    testing_index=chosen_index_lst+dmso_chosen
    #print(len(training_index))
    #print(len(testing_index))


    # %%
    #training data and testing data

    global X_train
    global X_test
    X_train=[]
    X_test=[]
    for i in range(len(training_index)):
        X_train.append(X_drug5[training_index[i]])
    for i in range(len(testing_index)):
        X_test.append(X_drug5[testing_index[i]])


    # %%
    #len(index_lst)

    # %%
    # labels for class. second time

    global class_name_train
    index_lst2=training_index
    #print(len(index_lst2))
    #class_name_train=[]
    #cnt1=cnt2=cnt3=cnt4=cnt5=0
    class_name_train=[]
    for i in range(len(index_lst2)):
        if index_lst2[i]<32:
            class_name_train.append('DNA')
            
            #cnt1+=1

        
        elif index_lst2[i]<64:
            class_name_train.append('MT')
            
            #cnt2+=1

        
        elif index_lst2[i]<96:
            class_name_train.append('HSP')
            
        #cnt3+=1

        elif index_lst2[i]<128:
            #cnt4+=1
            
            class_name_train.append('PROT')
            
        
        elif index_lst2[i]<160:
            #cnt5+=1
            class_name_train.append('HDAC')
            
    #print(len(class_name_train))
    for i in range(24):
        class_name_train.append("DMSO")
    #print(len(class_name_train))
    #print(len(class_name))
    #predict_counter=[cnt1,cnt2,cnt3,cnt4,cnt5]
    #print(predict_counter)
    #class_name_train=class_name




    # %%
    #prediction LDA
    from sklearn.neighbors import KNeighborsClassifier
    from sklearn.metrics import accuracy_score
    knn5 = KNeighborsClassifier(n_neighbors=20)
    knn5.fit(X_train, class_name_train)
    y_pred_5 = knn5.predict(X_test)
    #model2 = LinearDiscriminantAnalysis(n_components=4)
    #model2.fit(X_train,class_name_train)
    #yhat2=model2.predict(X_test)

    #print(yhat2)
    #print(len(yhat2))

    # %%
    #accuracy
    accuracy_score=accuracy( y_pred_5,['DNA',"MT","HSP","PROT","HDAC","DMSO"])
    accuracy_lst.append(accuracy_score)

    # %%
    
    
#knn

#print("Accuracy with k=5", accuracy_score(y_test, y_pred_5)*100)

# %%
accuracy_lst=[]
for i in range(30):
    pipeline()
#print(accuracy_lst)
print(sum(accuracy_lst)/len(accuracy_lst))
# Out:
# 0.9230769230769232
