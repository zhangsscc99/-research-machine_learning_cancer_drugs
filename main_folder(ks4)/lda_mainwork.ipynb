# %%
#a code block that deals with concentration and drug names
#we do not use this block for now.

import pandas as pd
f1 = pd.read_csv('B.csv')
f2 = pd.read_csv('C.csv')
f3=pd.read_csv('D.csv')
f4=pd.read_csv('E.csv')
f5=pd.read_csv('A.csv')
file = [f1,f2,f3,f5]
train = pd.concat(file,axis=1)
train.to_csv("train.csv", index=0, sep=',')

# %%
#do some further processing with "A" because there are some data error in it
def remove_extradots(string):
    counter=0
    lst=[]
    for i in range(len(string)):
        if string[i]=='.' and counter<1 :
            lst.append(string[i])
            counter+=1
        elif string[i]!='.':
            lst.append(string[i])
    res="".join(lst)
    return res



import csv
res_list=[]
print(remove_extradots("-0.29444.2"))
with open('A.csv') as file2:
    reader=csv.reader(file2)

    for row in reader:
        data=[]
        for i in range(len(row)):
            
            data.append(remove_extradots(row[i]))
        res_list.append(data)
    


with open('modified_A.csv', 'w') as file3:
    writer = csv.writer(file3)
    writer.writerows(res_list)
file3.close()
# Out:
# -0.294442

# %%
#test file A
import pandas as pd
df_A=pd.read_csv("A.csv")
df_A.shape
#df_A2=pd.read_csv("A_modified.csv")
#df_A2.shape
# Out:
# (767, 239)

# %%
#a block that is used to concate the drug names(drug combinations and related concentration)

import csv
res_list=[]
with open('train.csv', 'r') as file:
    reader = csv.reader(file)
    
    for row in reader:
        data=[]
        data.append(row[0]+'+'+row[1]+"+"+row[2])
        res_list.append(data)

        
        
with open('concatenated.csv', 'w') as file2:
    writer = csv.writer(file2)
    writer.writerows(res_list)

# %%
#a block that is used to concate concentration and ks numbers.
import pandas as pd
f1 = pd.read_csv('concatenated.csv')
#f2 = pd.read_csv('C.csv')
f3=pd.read_csv('D.csv')
f4=pd.read_csv('E.csv')
f5=pd.read_csv('modified_A.csv')
file = [f1,f5]
train = pd.concat(file,axis=1)
train.to_csv("train3.csv", index=0, sep=',')

# %%
#a block that sets the fields for the drug data
import csv
fields=['drug_name','default']
for i in range(1,239):
    fields.append('ks'+str(i))
rows=[]
with open('train3.csv', 'r') as file:
    reader = csv.reader(file)
    
    for row in reader:
        rows.append(row)

        
        
with open('drug_withfields2.csv', 'w') as file2:
    writer = csv.writer(file2)
    writer.writerow(fields)
    writer.writerows(rows)

# %%
#do some further processing with "drug_withfields" because there are still some data error in it
def remove_extradots(string):
    counter=0
    lst=[]
    for i in range(len(string)):
        if string[i]=='.' and counter<1 :
            lst.append(string[i])
            counter+=1
        elif string[i]!='.':
            lst.append(string[i])
    res="".join(lst)
    return res



import csv
res_list=[]
print(remove_extradots("-0.29444.2"))
with open('drug_withfields2.csv') as file2:
    reader=csv.reader(file2)

    for row in reader:
        data=[]
        for i in range(len(row)):
            
            data.append(remove_extradots(row[i]))
        res_list.append(data)
    


with open('drug_with_fields.csv', 'w') as file3:
    writer = csv.writer(file3)
    writer.writerows(res_list)
file3.close()
# Out:
# -0.294442

# %%
df=pd.read_csv('drug_with_fields.csv')
#one type first type. dna
df11=df.loc[(df['drug_name'] =='Etoposide+Gemcitabine+1') ]
df12=df.loc[(df['drug_name'] =='Etoposide+Gemcitabine+2') ]
df13=df.loc[(df['drug_name'] =='Etoposide+Gemcitabine+3') ]
df14=df.loc[(df['drug_name'] =='Etoposide+Gemcitabine+4') ]
df15=df.loc[(df['drug_name'] =='Etoposide+Gemcitabine+5') ]
df16=df.loc[(df['drug_name'] =='Etoposide+Gemcitabine+6') ]
df21=df.loc[(df['drug_name'] =='Gemcitabine+Etoposide+1') ]
df22=df.loc[(df['drug_name'] =='Gemcitabine+Etoposide+2') ]
df23=df.loc[(df['drug_name'] =='Gemcitabine+Etoposide+3') ]
df24=df.loc[(df['drug_name'] =='Gemcitabine+Etoposide+4') ]
df25=df.loc[(df['drug_name'] =='Gemcitabine+Etoposide+5') ]
df26=df.loc[(df['drug_name'] =='Gemcitabine+Etoposide+6') ]
df31=df.loc[(df['drug_name'] =='Etoposide+Etoposide+1') ]
df32=df.loc[(df['drug_name'] =='Etoposide+Etoposide+2') ]
df33=df.loc[(df['drug_name'] =='Etoposide+Etoposide+3') ]
df34=df.loc[(df['drug_name'] =='Etoposide+Etoposide+4') ]
df35=df.loc[(df['drug_name'] =='Etoposide+Etoposide+5') ]
df36=df.loc[(df['drug_name'] =='Etoposide+Etoposide+6') ]
df41=df.loc[(df['drug_name'] =='Gemcitabine+Gemcitabine+1') ]
df42=df.loc[(df['drug_name'] =='Gemcitabine+Gemcitabine+2') ]
df43=df.loc[(df['drug_name'] =='Gemcitabine+Gemcitabine+3') ]
df44=df.loc[(df['drug_name'] =='Gemcitabine+Gemcitabine+4') ]
df45=df.loc[(df['drug_name'] =='Gemcitabine+Gemcitabine+5') ]
df46=df.loc[(df['drug_name'] =='Gemcitabine+Gemcitabine+6') ]
frames = [df11, df12,df13,df14,df15,df16,df21,df22,df23,df24,df25,df26,df31,df32,df33,df34,df35,df36,df41,df42,df43,df44,df45,df46]
dna = pd.concat(frames)
dna
# Out:
#                     drug_name  default       ks1       ks2       ks3  \
# 12    Etoposide+Gemcitabine+1        0 -0.825000 -0.463430 -0.623680
# 14    Etoposide+Gemcitabine+2        0 -0.850830 -0.166270  0.283220
# 16    Etoposide+Gemcitabine+3        0 -0.690000  0.233580 -0.093266
# 18    Etoposide+Gemcitabine+4        0 -0.682500  0.227200  0.109890
# 20    Etoposide+Gemcitabine+5        0 -0.153740 -0.136810 -0.168360
# 22    Etoposide+Gemcitabine+6        0  0.023568 -0.042826  0.057062
# 72    Gemcitabine+Etoposide+1        0 -0.825000 -0.537260 -0.763460
# 74    Gemcitabine+Etoposide+2        0 -0.901670 -0.396500 -0.427270
# 76    Gemcitabine+Etoposide+3        0 -0.864170 -0.188210  0.287800
# 78    Gemcitabine+Etoposide+4        0  0.070186 -0.086002 -0.037225
# 80    Gemcitabine+Etoposide+5        0  0.090969 -0.095617  0.039580
# 82    Gemcitabine+Etoposide+6        0  0.102160 -0.140670 -0.078014
# 0       Etoposide+Etoposide+1        0 -0.915000 -0.309170 -0.266390
# 2       Etoposide+Etoposide+2        0 -0.827500 -0.185050  0.225330
# 4       Etoposide+Etoposide+3        0 -0.590000  0.163430 -0.071733
# 12 -0.246260 -0.134130 -0.121170  0.197050 -0.292570 -0.349690 -0.322820
# 14 -0.391330  0.255540  0.227910  0.161250 -0.654050 -0.670060 -0.371160
# 16 -0.367780  0.699280  0.635780  0.292200 -0.463030 -0.545270 -0.203230
# 18 -0.230140  0.620040  0.570010  0.313020 -0.455040 -0.469060 -0.143330
# 20 -0.121030  0.080550  0.058614  0.060248 -0.137510 -0.156480 -0.074083
# 22 -0.037457 -0.072875 -0.075814  0.050176  0.065241  0.034346 -0.058737
# 72 -0.152290 -0.216300 -0.202430  0.148460 -0.202780 -0.236710 -0.261870
# 74 -0.214250  0.090169 -0.077283  0.188880 -0.542280 -0.524420 -0.375000
# 76 -0.322140  0.282800  0.227020  0.166790 -0.682740 -0.669520 -0.399400
# 78 -0.036929 -0.139270 -0.148780  0.031322  0.116830  0.081344 -0.062593
# 80  0.032327 -0.151700 -0.164260  0.042661  0.113470  0.083392 -0.084182
# 82 -0.044912 -0.168990 -0.170570  0.027195  0.086867  0.050217 -0.048399
# 0  -0.259170  0.202780  0.171941  0.273332 -0.601110 -0.586391 -0.432780
# 2  -0.334970  0.319720  0.240240  0.209750 -0.635440 -0.644490 -0.349710
# 4  -0.213230  0.495230  0.458200  0.210270 -0.405370 -0.440270 -0.207970
# 6  -0.052402 -0.114600 -0.130490  0.056149  0.083671  0.055863 -0.075631
# 8   0.039006 -0.113550 -0.121610  0.032801  0.100530  0.067107 -0.044104
# 10 -0.043273 -0.109670 -0.119730  0.036606  0.080060  0.045157 -0.077717
# 84 -0.092857 -0.284760 -0.280000  0.123330  0.158330 -0.187140 -0.251550
# 86 -0.194500 -0.229140 -0.225360  0.169460 -0.256330 -0.303920 -0.334170
# 88 -0.326910  0.285590  0.215340  0.184610 -0.616830 -0.590190 -0.369800
# 90 -0.273610  0.600770  0.549850  0.281040 -0.500910 -0.524250 -0.195260
# 92 -0.089763 -0.038022 -0.051581  0.065418 -0.084015 -0.103710 -0.088941
# 94  0.044667 -0.147680 -0.157920  0.056514  0.098122  0.063929 -0.069854
#
#        ks238
# 12  0.267480
# 14  0.469350
# 16  0.417000
# 18  0.260370
# 20  0.104870
# 22  0.041194
# 72  0.172340
# 74  0.263310
# 76  0.415770
# 78 -0.037988
# 80 -0.035931
# 82  0.039932
# 0   0.321670
# 2   0.430350
# 4   0.249330
# 6   0.045953
# 8  -0.039664
# 10  0.024058
# 84  0.128210
# 86  0.214050
# 88  0.392780
# 90  0.297960
# 92  0.081480
# 94 -0.027119
#
# [24 rows x 240 columns]

# %%
#one type first type. mt
df11=df.loc[(df['drug_name'] =='Paclitaxel+Vinblastine+1') ]
df12=df.loc[(df['drug_name'] =='Paclitaxel+Vinblastine+2') ]
df13=df.loc[(df['drug_name'] =='Paclitaxel+Vinblastine+3') ]
df14=df.loc[(df['drug_name'] =='Paclitaxel+Vinblastine+4') ]
df15=df.loc[(df['drug_name'] =='Paclitaxel+Vinblastine+5') ]
df16=df.loc[(df['drug_name'] =='Paclitaxel+Vinblastine+6') ]
df21=df.loc[(df['drug_name'] =='Vinblastine+Paclitaxel+1') ]
df22=df.loc[(df['drug_name'] =='Vinblastine+Paclitaxel+2') ]
df23=df.loc[(df['drug_name'] =='Vinblastine+Paclitaxel+3') ]
df24=df.loc[(df['drug_name'] =='Vinblastine+Paclitaxel+4') ]
df25=df.loc[(df['drug_name'] =='Vinblastine+Paclitaxel+5') ]
df26=df.loc[(df['drug_name'] =='Vinblastine+Paclitaxel+6') ]
df31=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+1') ]
df32=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+2') ]
df33=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+3') ]
df34=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+4') ]
df35=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+5') ]
df36=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+6') ]
df41=df.loc[(df['drug_name'] =='Vinblastine+Vinblastine+1') ]
df42=df.loc[(df['drug_name'] =='Vinblastine+Vinblastine+2') ]
df43=df.loc[(df['drug_name'] =='Vinblastine+Vinblastine+3') ]
df44=df.loc[(df['drug_name'] =='Vinblastine+Vinblastine+4') ]
df45=df.loc[(df['drug_name'] =='Vinblastine+Vinblastine+5') ]
df46=df.loc[(df['drug_name'] =='Vinblastine+Vinblastine+6') ]
frames2 = [df11, df12,df13,df14,df15,df16,df21,df22,df23,df24,df25,df26,df31,df32,df33,df34,df35,df36,df41,df42,df43,df44,df45,df46]
mt= pd.concat(frames)
mt
# Out:
#                     drug_name  default       ks1       ks2       ks3  \
# 12    Etoposide+Gemcitabine+1        0 -0.825000 -0.463430 -0.623680
# 14    Etoposide+Gemcitabine+2        0 -0.850830 -0.166270  0.283220
# 16    Etoposide+Gemcitabine+3        0 -0.690000  0.233580 -0.093266
# 18    Etoposide+Gemcitabine+4        0 -0.682500  0.227200  0.109890
# 20    Etoposide+Gemcitabine+5        0 -0.153740 -0.136810 -0.168360
# 22    Etoposide+Gemcitabine+6        0  0.023568 -0.042826  0.057062
# 72    Gemcitabine+Etoposide+1        0 -0.825000 -0.537260 -0.763460
# 74    Gemcitabine+Etoposide+2        0 -0.901670 -0.396500 -0.427270
# 76    Gemcitabine+Etoposide+3        0 -0.864170 -0.188210  0.287800
# 78    Gemcitabine+Etoposide+4        0  0.070186 -0.086002 -0.037225
# 80    Gemcitabine+Etoposide+5        0  0.090969 -0.095617  0.039580
# 82    Gemcitabine+Etoposide+6        0  0.102160 -0.140670 -0.078014
# 0       Etoposide+Etoposide+1        0 -0.915000 -0.309170 -0.266390
# 2       Etoposide+Etoposide+2        0 -0.827500 -0.185050  0.225330
# 4       Etoposide+Etoposide+3        0 -0.590000  0.163430 -0.071733
# 6       Etoposide+Etoposide+4        0  0.055863 -0.089835 -0.060518
# 8       Etoposide+Etoposide+5        0  0.072606 -0.050656  0.029489
# 10      Etoposide+Etoposide+6        0  0.051316 -0.086824 -0.048019
# 84  Gemcitabine+Gemcitabine+1        0 -0.737500 -0.573210 -0.803810
# 20 -0.121030  0.080550  0.058614  0.060248 -0.137510 -0.156480 -0.074083
# 22 -0.037457 -0.072875 -0.075814  0.050176  0.065241  0.034346 -0.058737
# 72 -0.152290 -0.216300 -0.202430  0.148460 -0.202780 -0.236710 -0.261870
# 74 -0.214250  0.090169 -0.077283  0.188880 -0.542280 -0.524420 -0.375000
# 76 -0.322140  0.282800  0.227020  0.166790 -0.682740 -0.669520 -0.399400
# 78 -0.036929 -0.139270 -0.148780  0.031322  0.116830  0.081344 -0.062593
# 80  0.032327 -0.151700 -0.164260  0.042661  0.113470  0.083392 -0.084182
# 82 -0.044912 -0.168990 -0.170570  0.027195  0.086867  0.050217 -0.048399
# 0  -0.259170  0.202780  0.171941  0.273332 -0.601110 -0.586391 -0.432780
# 2  -0.334970  0.319720  0.240240  0.209750 -0.635440 -0.644490 -0.349710
# 4  -0.213230  0.495230  0.458200  0.210270 -0.405370 -0.440270 -0.207970
# 6  -0.052402 -0.114600 -0.130490  0.056149  0.083671  0.055863 -0.075631
# 8   0.039006 -0.113550 -0.121610  0.032801  0.100530  0.067107 -0.044104
# 10 -0.043273 -0.109670 -0.119730  0.036606  0.080060  0.045157 -0.077717
# 84 -0.092857 -0.284760 -0.280000  0.123330  0.158330 -0.187140 -0.251550
# 86 -0.194500 -0.229140 -0.225360  0.169460 -0.256330 -0.303920 -0.334170
# 88 -0.326910  0.285590  0.215340  0.184610 -0.616830 -0.590190 -0.369800
# 90 -0.273610  0.600770  0.549850  0.281040 -0.500910 -0.524250 -0.195260
# 92 -0.089763 -0.038022 -0.051581  0.065418 -0.084015 -0.103710 -0.088941
# 94  0.044667 -0.147680 -0.157920  0.056514  0.098122  0.063929 -0.069854
#
#        ks238
# 12  0.267480
# 14  0.469350
# 16  0.417000
# 18  0.260370
# 20  0.104870
# 22  0.041194
# 72  0.172340
# 74  0.263310
# 76  0.415770
# 78 -0.037988
# 80 -0.035931
# 82  0.039932
# 0   0.321670
# 2   0.430350
# 4   0.249330
# 6   0.045953
# 8  -0.039664
# 10  0.024058
# 84  0.128210
# 86  0.214050
# 88  0.392780
# 90  0.297960
# 92  0.081480
# 94 -0.027119
#
# [24 rows x 240 columns]

# %%
#Dna ： etoposide，Gemcitabine
#hsp：17aag，auy922
#mt：paclitaxel，Vinblastine
#prot："MG132"，ps341
#hdac：saha，apicidin

frames3=[]
for i in range(1,7):
    frames3.append(df.loc[(df['drug_name'] =='17AAG+AUY922+'+str(i)) ])
for j in range(1,7):
    frames3.append(df.loc[(df['drug_name'] =='AUY922+17AAG+'+str(j)) ])
for k in range(1,7):
    frames3.append(df.loc[(df['drug_name'] =='AUY922+AUY922+'+str(k)) ])
for m in range(1,7):
    frames3.append(df.loc[(df['drug_name'] =='17AAG+17AAG+'+str(m)) ])
HSP= pd.concat(frames3)
HSP
# Out:
#            drug_name  default       ks1       ks2       ks3       ks4  \
# 397   17AAG+AUY922+1        0 -0.767500 -0.577600 -0.800500 -0.933350
# 399   17AAG+AUY922+2        0 -0.855830 -0.333280 -0.409610 -0.662020
# 479 -0.056056
# 385  0.359470
# 387  0.469600
# 389  0.271910
# 391 -0.030044
# 393 -0.064635
# 395 -0.050724
#
# [24 rows x 240 columns]

# %%
#Dna ： etoposide，Gemcitabine
#mt：paclitaxel，Vinblastine
#hsp：17aag，auy922

#prot："MG132"，ps341
#hdac：saha，apicidin

frames4=[]
for i in range(1,7):
    frames4.append(df.loc[(df['drug_name'] =='MG132+PS341+'+str(i)) ])
for j in range(1,7):
    frames4.append(df.loc[(df['drug_name'] =='PS341+MG132+'+str(j)) ])
for k in range(1,7):
    frames4.append(df.loc[(df['drug_name'] =='MG132+MG132+'+str(k)) ])
for m in range(1,7):
    frames4.append(df.loc[(df['drug_name'] =='PS341+PS341+'+str(m)) ])
PROT= pd.concat(frames4)
PROT
# Out:
#          drug_name  default       ks1       ks2       ks3       ks4       ks5  \
# 541  MG132+PS341+1        0 -0.980830  0.275420  0.463330 -0.309580  0.193750
# 543  MG132+PS341+2        0 -0.560000  0.530740  0.558230  0.126370  0.610510
# 545  MG132+PS341+3        0 -0.352500  0.313820  0.287250  0.204430  0.248170
# 547  MG132+PS341+4        0 -0.201720  0.217710  0.269260  0.109690  0.220390
# 549  MG132+PS341+5        0 -0.066823  0.069562  0.086963  0.017766  0.051397
# 551  MG132+PS341+6        0  0.096792 -0.029772  0.051313 -0.073721  0.032557
# 601  PS341+MG132+1        0 -0.201670 -0.780090 -0.999200 -0.999200 -1.000000
# 603  PS341+MG132+2        0 -0.842500  0.222630  0.417240 -0.108640  0.102980
# 605  PS341+MG132+3        0 -0.601670  0.329910  0.396860  0.094715  0.267520
# 607  PS341+MG132+4        0 -0.407500  0.371080  0.421490  0.140580  0.406780
# 609  PS341+MG132+5        0 -0.139100  0.040512 -0.064549 -0.025732  0.058738
# 611  PS341+MG132+6        0  0.111620 -0.103320 -0.119630  0.073187 -0.159250
# 529  MG132+MG132+1        0 -0.202530 -0.771890 -0.996780 -1.000000 -1.000000
# 531  MG132+MG132+2        0 -0.550270  0.265850  0.320740  0.096816  0.242260
# 533  MG132+MG132+3        0 -0.352500  0.237920  0.234320  0.138870  0.130440
# 535  MG132+MG132+4        0 -0.298330  0.202930  0.258550  0.109530  0.181600
# 537  MG132+MG132+5        0 -0.114170  0.093214  0.112740  0.039167  0.068571
# 539  MG132+MG132+6        0  0.104270 -0.097685 -0.066722 -0.086166 -0.123200
# 613  PS341+PS341+1        0 -0.131670 -0.798930 -0.997070 -1.000000 -1.000000
# 615  PS341+PS341+2        0 -0.820830  0.415250  0.444770  0.075250  0.489880
# 617  PS341+PS341+3        0 -0.531670  0.563460  0.624960  0.154780  0.461170
# 619  PS341+PS341+4        0 -0.434170  0.327380  0.373860  0.137210  0.365040
# 621  PS341+PS341+5        0 -0.165370 -0.032087 -0.087419 -0.060405 -0.108050
# 623  PS341+PS341+6        0  0.069655 -0.053471 -0.031627  0.054596  0.025207
#
#           ks6       ks7       ks8  ...     ks229     ks230     ks231  \
# 541  0.522500  0.439170  0.423330  ...  0.390830  0.215830 -0.303750
# 535  0.287980  0.276520  0.095216 -0.292840 -0.224100 -0.097955  0.067075
# 537  0.116430  0.105120  0.050833 -0.113100 -0.088929 -0.038810 -0.047262
# 539 -0.121410 -0.113910  0.029607  0.098738  0.073260 -0.066491 -0.034854
# 613 -0.578970 -0.532870 -0.089377  0.930160  0.911360  0.296230 -0.715000
# 615  0.542430  0.539200 -0.070117 -0.556290 -0.561650 -0.203100  0.335200
# 617  0.421300  0.437780  0.054898 -0.384960 -0.373330 -0.287500  0.124810
# 619  0.374190  0.363900  0.089419 -0.313930 -0.243720 -0.133310 -0.022674
# 621  0.121470  0.111450  0.037262 -0.114010 -0.106340 -0.047639  0.073148
# 623 -0.047150 -0.063368 -0.023373  0.062554  0.053102 -0.036159 -0.032426
#
# [24 rows x 240 columns]

# %%
#Dna ： etoposide，Gemcitabine
#hsp：17aag，auy922
#mt：paclitaxel，Vinblastine
#prot："MG132"，ps341
#hdac：saha，apicidin

frames5=[]
for i in range(1,7):
    frames5.append(df.loc[(df['drug_name'] =='SAHA+Apicidin+'+str(i)) ])
for j in range(1,7):
    frames5.append(df.loc[(df['drug_name'] =='Apicidin+SAHA+'+str(j)) ])
for k in range(1,7):
    frames5.append(df.loc[(df['drug_name'] =='Apicidin+Apicidin+'+str(k)) ])
for m in range(1,7):
    frames5.append(df.loc[(df['drug_name'] =='SAHA+SAHA+'+str(m)) ])
HDAC= pd.concat(frames5)
HDAC
# Out:
#                drug_name  default       ks1       ks2       ks3       ks4  \
# 672      SAHA+Apicidin+1        0 -0.895830  0.214310  0.321900 -0.144170
# 674      SAHA+Apicidin+2        0 -0.575830  0.546330  0.570710  0.147600
# 676      SAHA+Apicidin+3        0 -0.075150  0.416830  0.464100  0.192980
# 678      SAHA+Apicidin+4        0 -0.043026  0.097982  0.071053  0.119250
# 680      SAHA+Apicidin+5        0 -0.054167 -0.090500 -0.122330 -0.053667
# 682      SAHA+Apicidin+6        0  0.061709 -0.115710 -0.127120  0.061750
# 289      Apicidin+SAHA+1        0 -0.937500  0.275810  0.458540 -0.191050
# 291      Apicidin+SAHA+2        0 -0.605840  0.665340  0.722010  0.169270
# 293      Apicidin+SAHA+3        0  0.048769  0.322460  0.465320  0.156850
# 295      Apicidin+SAHA+4        0  0.081883 -0.031892  0.042259  0.074661
# 297      Apicidin+SAHA+5        0  0.035269 -0.084705 -0.034474 -0.035295
# 299      Apicidin+SAHA+6        0  0.064319 -0.110200 -0.102150  0.077367
# 673  Apicidin+Apicidin+1        0 -0.935000  0.359170  0.515830 -0.144170
# 675  Apicidin+Apicidin+2        0 -0.536670  0.603580  0.645670  0.184680
# 677  Apicidin+Apicidin+3        0 -0.077500  0.400230  0.448270  0.188270
# 679  Apicidin+Apicidin+4        0  0.057114  0.069390  0.087154  0.136990
# 681  Apicidin+Apicidin+5        0  0.040290 -0.053320 -0.056615  0.078565
# 683  Apicidin+Apicidin+6        0  0.075676 -0.124450 -0.200030  0.082567
# 288          SAHA+SAHA+1        0 -0.954170  0.308430  0.481910 -0.112810
# 293  0.095628  0.029247  0.041040  0.039193  0.195800  0.173700 -0.040303
# 295  0.074579 -0.129490 -0.128390 -0.028830  0.147040  0.118340 -0.025270
# 297 -0.038179 -0.093295 -0.103510  0.040154  0.075782  0.050949 -0.057487
# 299 -0.048098 -0.132930 -0.144800  0.028050  0.128750  0.078345 -0.053770
# 673 -0.353750  0.448330  0.420420  0.265000 -0.553750 -0.557080 -0.451670
# 675 -0.143200  0.609000  0.594110  0.136740 -0.483390 -0.467140 -0.089290
# 677  0.055950  0.165730  0.171340  0.029927  0.141210  0.145020 -0.036993
# 679  0.044309 -0.051240 -0.037215  0.041809  0.109700  0.101000 -0.030305
# 681 -0.037933 -0.049245 -0.052553  0.056320  0.093685  0.075398 -0.060004
# 683  0.031345 -0.093021 -0.082360  0.040278  0.107210  0.090869 -0.051162
# 288 -0.477780  0.487590  0.431140  0.275490 -0.600120 -0.617410 -0.358700
# 290 -0.155500  0.597550  0.585120  0.155110 -0.497830 -0.492170 -0.133120
# 292  0.097150  0.078057  0.084993  0.030012  0.165220  0.154520 -0.039340
# 294  0.056691 -0.061606 -0.064976  0.024933  0.112500  0.081841 -0.028175
# 296 -0.058015 -0.054617 -0.068953  0.041535  0.077927 -0.056419 -0.059348
# 298 -0.058545 -0.071344 -0.080024 -0.022251  0.045747 -0.036961 -0.051677
#
#         ks238
# 672  0.443200
# 674  0.247120
# 676 -0.090956
# 678 -0.047018
# 680  0.039333
# 682 -0.024943
# 289  0.537480
# 291  0.228870
# 293 -0.077990
# 295 -0.076521
# 297 -0.030218
# 299  0.045058
# 673  0.412500
# 675  0.225130
# 677 -0.075964
# 679 -0.056240
# 681 -0.039912
# 683 -0.036304
# 288  0.552410
# 290  0.241290
# 292 -0.085260
# 294 -0.053385
# 296  0.047265
# 298  0.049158
#
# [24 rows x 240 columns]

# %%
combi=frames+frames2+frames3+frames4+frames5
training= pd.concat(combi)
training
# Out:
#                    drug_name  default       ks1       ks2       ks3       ks4  \
# 12   Etoposide+Gemcitabine+1        0 -0.825000 -0.463430 -0.623680 -0.811710
# 14   Etoposide+Gemcitabine+2        0 -0.850830 -0.166270  0.283220 -0.518290
# 16   Etoposide+Gemcitabine+3        0 -0.690000  0.233580 -0.093266  0.163760
# 18   Etoposide+Gemcitabine+4        0 -0.682500  0.227200  0.109890  0.123580
# 20   Etoposide+Gemcitabine+5        0 -0.153740 -0.136810 -0.168360 -0.151440
# ..                       ...      ...       ...       ...       ...       ...
# 290              SAHA+SAHA+2        0 -0.575830  0.614180  0.676500  0.127380
# 292              SAHA+SAHA+3        0 -0.039234  0.357270  0.467940  0.189710
# 294              SAHA+SAHA+4        0  0.042073  0.090531  0.140260  0.093571
# 296              SAHA+SAHA+5        0 -0.037934 -0.052660 -0.028860  0.057298
# 298              SAHA+SAHA+6        0 -0.025114 -0.112470 -0.111420 -0.072167
#
#           ks5       ks6       ks7       ks8  ...     ks229     ks230  \
# 12  -0.887700 -0.625570 -0.599290 -0.572840  ... -0.185950  0.197050
# 14  -0.644780 -0.131510  0.334720  0.418330  ...  0.173700  0.161250
# 16   0.195020 -0.093485 -0.094498 -0.089402  ...  0.484000  0.292200
# 18   0.155430  0.110520  0.096807  0.088164  ...  0.407050  0.313020
# 20  -0.222490 -0.169770 -0.157740 -0.151010  ...  0.036541  0.060248
# ..        ...       ...       ...       ...  ...       ...       ...
# 290  0.676570  0.688240  0.657050  0.620200  ...  0.501140  0.155110
# 292  0.540580  0.464200  0.437200  0.413260  ...  0.075193  0.030012
# 294  0.183460  0.141350  0.129490  0.116210  ... -0.063889  0.024933
# 296  0.026528 -0.030210 -0.030452 -0.033717  ... -0.067626  0.041535
# 298 -0.133120 -0.117890 -0.103570 -0.097284  ... -0.070852 -0.022251
#
#         ks231     ks232     ks233     ks234     ks235     ks236     ks237  \
# 12  -0.246260 -0.134130 -0.121170  0.197050 -0.292570 -0.349690 -0.322820
# 14  -0.391330  0.255540  0.227910  0.161250 -0.654050 -0.670060 -0.371160
# 16  -0.367780  0.699280  0.635780  0.292200 -0.463030 -0.545270 -0.203230
# 18  -0.230140  0.620040  0.570010  0.313020 -0.455040 -0.469060 -0.143330
# 20  -0.121030  0.080550  0.058614  0.060248 -0.137510 -0.156480 -0.074083
# ..        ...       ...       ...       ...       ...       ...       ...
# 290 -0.155500  0.597550  0.585120  0.155110 -0.497830 -0.492170 -0.133120
# 292  0.097150  0.078057  0.084993  0.030012  0.165220  0.154520 -0.039340
# 294  0.056691 -0.061606 -0.064976  0.024933  0.112500  0.081841 -0.028175
# 296 -0.058015 -0.054617 -0.068953  0.041535  0.077927 -0.056419 -0.059348
# 298 -0.058545 -0.071344 -0.080024 -0.022251  0.045747 -0.036961 -0.051677
#
#         ks238
# 12   0.267480
# 14   0.469350
# 16   0.417000
# 18   0.260370
# 20   0.104870
# ..        ...
# 290  0.241290
# 292 -0.085260
# 294 -0.053385
# 296  0.047265
# 298  0.049158
#
# [120 rows x 240 columns]

# %%
#lda model
#just sample
#Dna ： etoposide，Gemcitabine
#mt：paclitaxel，Vinblastine
#hsp：17aag，auy922

#prot："MG132"，ps341
#hdac：saha，apicidin
from sklearn.datasets import make_classification
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

X_drug=training.iloc[:, 3:240].values

y=[]
for i in range(24):
    y.append('DNA')
for j in range(24):
    y.append('MT')
for k in range(24):
    y.append('HSP')
for m in range(24):
    y.append('PROT')
for n in range(24):
    y.append('HDAC')
print(len(X_drug[0]))
model = LinearDiscriminantAnalysis(n_components=4)
#model.fit(X_drug, y)
#X_drug2 = model.transform(X_drug)
#reduce dimension for the data
X_drug2=model.fit(X_drug,y).transform(X_drug)
X_drug2
print(len(X_drug2[0]))
# Out:
# 237
# 4

# %%
#pca_drug = PCA(n_components=6)
#components = pca_drug.fit_transform(X_drug)
principalDf = pd.DataFrame(data = X_drug2
             , columns =['principal component 1', 'principal component 2','principal component 3','principal component 4'])
principalDf
# Out:
#      principal component 1  principal component 2  principal component 3  \
# 0                -3.252321              -0.549709               4.233718
# 1                -3.428148              -0.461099               4.660474
# 2                -3.631864              -0.755152               4.348255
# 3                -3.405172              -0.528072               4.279064
# 4                -3.572289               1.157390               3.429835
# ..                     ...                    ...                    ...
# 115               1.453716               7.831404               0.252974
# 116               0.983922               5.738939               1.050120
# 117               2.602001               6.308003               1.520111
# 118               1.551104               7.264680               0.095375
# 119               2.206484               7.439078               0.757224
#
#      principal component 4
# 0                 2.384586
# 1                 1.632272
# 2                 1.386191
# 3                 1.937831
# 4                 0.583612
# ..                     ...
# 115               0.863162
# 116              -2.065507
# 117               0.106051
# 118              -0.003251
# 119               0.679434
#
# [120 rows x 4 columns]

# %%
#predict
#still sample but useful this block 
#model2 = LinearDiscriminantAnalysis(n_components=1)
#model2.fit(X_drug2,y)
#row=X_drug2
#yhat = model2.predict(row)
# summarize prediction
#print('Predicted Class: %s' % yhat)

# %%
all_list=[]

for i in range(len(X_drug2)):
    all_list.append(X_drug2[i])
print(len(all_list))
# Out:
# 120

# %%
X_training=[]
X_testing=[]

X_training=all_list[6:24]+all_list[30:48]+all_list[54:72]+all_list[78:96]+all_list[102:120]

X_testing=all_list[:6]+all_list[24:30]+all_list[48:54]+all_list[72:78]+all_list[96:102]
#X_testing.append()
print(len(X_training))
print(len(X_testing))
y=[]
for i in range(18):
    y.append('DNA')
for j in range(18):
    y.append("MT")
for k in range(18):
    y.append("HSP")
for m in range(18):
    y.append("PROT")
for n in range(18):
    y.append("HDAC")
model2 = LinearDiscriminantAnalysis(n_components=4)
model2.fit(X_training,y)
yhat2=model2.predict(X_testing)

print(yhat2)
# Out:
# 90
# 30
# ['DNA' 'DNA' 'DNA' 'DNA' 'DNA' 'DNA' 'MT' 'MT' 'MT' 'MT' 'MT' 'MT' 'HSP'
#  'HSP' 'HSP' 'HSP' 'HSP' 'HSP' 'PROT' 'PROT' 'PROT' 'PROT' 'PROT' 'PROT'
#  'HDAC' 'HDAC' 'HDAC' 'HDAC' 'HDAC' 'HDAC']

# %%
def accuracy(list1,list2):
    length=len(list1)
    list3=[]
    for i in range(int(length/5.0)):
        list3.append(list2[0])
    for j in range(int(length/5.0)):
        list3.append(list2[1])
    for m in range(int(length/5.0)):
        list3.append(list2[2])
    for n in range(int(length/5.0)):
        list3.append(list2[3])
    for k in range(int(length/5.0)):
        list3.append(list2[4])

    counter=0
    for k in range(len(list1)):

        if list1[k]==list3[k]:
            counter+=1
    return counter/length

# %%
#test accuracy
'%.2f%%' % ((accuracy( yhat2,['DNA',"MT","HSP","PROT","HDAC"]))*100)
# Out:
# '100.00%'

# %%
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
model = LinearDiscriminantAnalysis(n_components=4)
y2=[]
for i in range(24):
    y2.append('DNA')
for j in range(24):
    y2.append('MT')
for k in range(24):
    y2.append('HSP')
for m in range(24):
    y2.append('PROT')
for n in range(24):
    y2.append('HDAC')
#model.fit(X_drug, y)
#X_drug2 = model.transform(X_drug)
X_drug3=training.iloc[:,2:240].values
X_drug3=model.fit(X_drug3,y2).transform(X_drug3)
fig = px.scatter(X_drug3, x=0, y=1, color=training['drug_name'])
fig.show()
#these 5 groups are very clearly separated, as we can see in the image

# %%
# Create a function
def select_n_components(var_ratio, goal_var: float) -> int:
    # Set initial variance explained so far
    total_variance = 0.0
    
    # Set initial number of features
    n_components = 0
    
    # For the explained variance of each feature:
    for explained_variance in var_ratio:
        
        # Add the explained variance to the total
        total_variance += explained_variance
        
        # Add one to the number of components
        n_components += 1
        
        # If we reach our goal level of explained variance
        if total_variance >= goal_var:
            # End the loop
            break
            
    # Return the number of components
    return n_components

# %%
lda = LinearDiscriminantAnalysis(n_components=None)
y5=[]
for i in range(18):
    y5.append('DNA')
for j in range(18):
    y5.append("MT")
for k in range(18):
    y5.append("HSP")
for m in range(18):
    y5.append("PROT")
for n in range(18):
    y5.append("HDAC")

X_lda=lda.fit(X_training,y5)

# %%
# Create array of explained variance ratios
lda_var_ratios = lda.explained_variance_ratio_
lda_var_ratios
# Out:
# array([0.4150517 , 0.33917834, 0.17749731, 0.06827265])

# %%
# Run function
print(select_n_components(lda_var_ratios, 0.95))
print(select_n_components(lda_var_ratios, 0.85))
print(select_n_components(lda_var_ratios, 0.75))
print(select_n_components(lda_var_ratios, 0.65))
print(select_n_components(lda_var_ratios, 0.35))
# Out:
# 4
# 3
# 2
# 2
# 1

# %%
#pca_drug = PCA(n_components=6)
#components = pca_drug.fit_transform(X_drug)
principalDf = pd.DataFrame(data = X_drug2
             , columns =['principal component 1', 'principal component 2','principal component 3','principal component 4'])
principalDf
# Out:
#      principal component 1  principal component 2  principal component 3  \
# 0                -3.252321              -0.549709               4.233718
# 1                -3.428148              -0.461099               4.660474
# 2                -3.631864              -0.755152               4.348255
# 3                -3.405172              -0.528072               4.279064
# 4                -3.572289               1.157390               3.429835
# ..                     ...                    ...                    ...
# 115               1.453716               7.831404               0.252974
# 116               0.983922               5.738939               1.050120
# 117               2.602001               6.308003               1.520111
# 118               1.551104               7.264680               0.095375
# 119               2.206484               7.439078               0.757224
#
#      principal component 4
# 0                 2.384586
# 1                 1.632272
# 2                 1.386191
# 3                 1.937831
# 4                 0.583612
# ..                     ...
# 115               0.863162
# 116              -2.065507
# 117               0.106051
# 118              -0.003251
# 119               0.679434
#
# [120 rows x 4 columns]

# %%
training
# Out:
#                    drug_name  default       ks1       ks2       ks3       ks4  \
# 12   Etoposide+Gemcitabine+1        0 -0.825000 -0.463430 -0.623680 -0.811710
# 14   Etoposide+Gemcitabine+2        0 -0.850830 -0.166270  0.283220 -0.518290
# 16   Etoposide+Gemcitabine+3        0 -0.690000  0.233580 -0.093266  0.163760
# 18   Etoposide+Gemcitabine+4        0 -0.682500  0.227200  0.109890  0.123580
# 20   Etoposide+Gemcitabine+5        0 -0.153740 -0.136810 -0.168360 -0.151440
# ..                       ...      ...       ...       ...       ...       ...
# 290              SAHA+SAHA+2        0 -0.575830  0.614180  0.676500  0.127380
# 292              SAHA+SAHA+3        0 -0.039234  0.357270  0.467940  0.189710
# 294              SAHA+SAHA+4        0  0.042073  0.090531  0.140260  0.093571
# 296              SAHA+SAHA+5        0 -0.037934 -0.052660 -0.028860  0.057298
# 298              SAHA+SAHA+6        0 -0.025114 -0.112470 -0.111420 -0.072167
#
#           ks5       ks6       ks7       ks8  ...     ks229     ks230  \
# 12  -0.887700 -0.625570 -0.599290 -0.572840  ... -0.185950  0.197050
# 14  -0.644780 -0.131510  0.334720  0.418330  ...  0.173700  0.161250
# 16   0.195020 -0.093485 -0.094498 -0.089402  ...  0.484000  0.292200
# 18   0.155430  0.110520  0.096807  0.088164  ...  0.407050  0.313020
# 20  -0.222490 -0.169770 -0.157740 -0.151010  ...  0.036541  0.060248
# ..        ...       ...       ...       ...  ...       ...       ...
# 290  0.676570  0.688240  0.657050  0.620200  ...  0.501140  0.155110
# 292  0.540580  0.464200  0.437200  0.413260  ...  0.075193  0.030012
# 294  0.183460  0.141350  0.129490  0.116210  ... -0.063889  0.024933
# 296  0.026528 -0.030210 -0.030452 -0.033717  ... -0.067626  0.041535
# 298 -0.133120 -0.117890 -0.103570 -0.097284  ... -0.070852 -0.022251
#
#         ks231     ks232     ks233     ks234     ks235     ks236     ks237  \
# 12  -0.246260 -0.134130 -0.121170  0.197050 -0.292570 -0.349690 -0.322820
# 14  -0.391330  0.255540  0.227910  0.161250 -0.654050 -0.670060 -0.371160
# 16  -0.367780  0.699280  0.635780  0.292200 -0.463030 -0.545270 -0.203230
# 18  -0.230140  0.620040  0.570010  0.313020 -0.455040 -0.469060 -0.143330
# 20  -0.121030  0.080550  0.058614  0.060248 -0.137510 -0.156480 -0.074083
# ..        ...       ...       ...       ...       ...       ...       ...
# 290 -0.155500  0.597550  0.585120  0.155110 -0.497830 -0.492170 -0.133120
# 292  0.097150  0.078057  0.084993  0.030012  0.165220  0.154520 -0.039340
# 294  0.056691 -0.061606 -0.064976  0.024933  0.112500  0.081841 -0.028175
# 296 -0.058015 -0.054617 -0.068953  0.041535  0.077927 -0.056419 -0.059348
# 298 -0.058545 -0.071344 -0.080024 -0.022251  0.045747 -0.036961 -0.051677
#
#         ks238
# 12   0.267480
# 14   0.469350
# 16   0.417000
# 18   0.260370
# 20   0.104870
# ..        ...
# 290  0.241290
# 292 -0.085260
# 294 -0.053385
# 296  0.047265
# 298  0.049158
#
# [120 rows x 240 columns]

# %%
#knn
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
knn5 = KNeighborsClassifier(n_neighbors=10)
knn5.fit(X_training, y)
y_pred_5 = knn5.predict(X_testing)
print(y_pred_5)
print(accuracy(y_pred_5,['DNA',"MT","HSP","PROT","HDAC"]))
#print("Accuracy with k=5", accuracy_score(y_test, y_pred_5)*100)
# Out:
# ['DNA' 'DNA' 'DNA' 'DNA' 'DNA' 'DNA' 'MT' 'MT' 'MT' 'MT' 'MT' 'MT' 'HSP'
#  'HSP' 'HSP' 'HSP' 'HSP' 'HSP' 'PROT' 'PROT' 'PROT' 'PROT' 'PROT' 'PROT'
#  'HDAC' 'HDAC' 'HDAC' 'HDAC' 'HDAC' 'HDAC']
# 1.0

# %% [markdown]
# ## most results show the accuracy is 100%.
# ks5: 93.3%
# ks4: 100%
# ks3: 100%
# ks2: 100%
# Maybe it is because our data is little. So the accuracy is incredibly high.
# And it is obvious that different classes are different.

# %%
# Out:
# 1.0
