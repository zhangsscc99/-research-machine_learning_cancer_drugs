# %%
#design of the program
#需求
#训练数据的浓度是可以被更改的（设置成许多的小函数 应该就可以参数一键直接改掉了）
#只要我想输入哪些药物 就能输入哪些 
#我想改component就能直接改
#我想用pca或者lda能够自己选定
#设置的药物label能直接根据我的需求去设定
#能有filter功能，只要我想要 就要给我更改filter的数据
#

# %%
def extract_Etoposide(frames1,concentration):
    for i in range(len(concentration)):
        frames1.append(df.loc[(df['drug_name'] =='Etoposide+Etoposide+'+str(concentration[i])) ])
    for i in range(len(concentration)):
        frames1.append(df.loc[(df['drug_name'] =='Etoposide+DMSO+'+str(concentration[i])) ])

def extract_Gemcitabine(frames2,concentration):
    for i in range(len(concentration)):
        frames2.append(df.loc[(df['drug_name'] =='Gemcitabine+Gemcitabine+'+str(concentration[i])) ])
    for i in range(len(concentration)):
        frames2.append(df.loc[(df['drug_name'] =='Gemcitabine+DMSO+'+str(concentration[i])) ])

def extract_Paclitaxel(frames3,concentration):
    for i in range(len(concentration)):
        frames3.append(df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+'+str(concentration[i])) ])
    for i in range(len(concentration)):
        frames3.append(df.loc[(df['drug_name'] =='Paclitaxel+DMSO+'+str(concentration[i])) ])

def extract_Vinblastine(frames4,concentration):
    for i in range(len(concentration)):
        frames4.append(df.loc[(df['drug_name'] =='Vinblastine+Vinblastine+'+str(concentration[i])) ])
    for i in range(len(concentration)):
        frames4.append(df.loc[(df['drug_name'] =='Vinblastine+DMSO+'+str(concentration[i])) ])

def extract_AUY922(frames5,concentration):
    for i in range(len(concentration)):
        frames5.append(df.loc[(df['drug_name'] =='AUY922+AUY922+'+str(concentration[i])) ])
    for i in range(len(concentration)):
        frames5.append(df.loc[(df['drug_name'] =='AUY922+DMSO+'+str(concentration[i])) ])

def extract_17AAG(frames6,concentration):
    for i in range(len(concentration)):
        frames6.append(df.loc[(df['drug_name'] =='17AAG+17AAG+'+str(concentration[i])) ])
    for i in range(len(concentration)):
        frames6.append(df.loc[(df['drug_name'] =='17AAG+DMSO+'+str(concentration[i])) ])
#7
def extract_17AAG(frames7,concentration):
    for i in range(len(concentration)):
        frames7.append(df.loc[(df['drug_name'] =='MG132+MG132+'+str(concentration[i])) ])
    for i in range(len(concentration)):
        frames7.append(df.loc[(df['drug_name'] =='MG132+DMSO+'+str(concentration[i])) ])
    
#8
def extract_PS341(frames8,concentration):
    for i in range(len(concentration)):
        frames8.append(df.loc[(df['drug_name'] =='PS341+PS341+'+str(concentration[i])) ])
    for i in range(len(concentration)):
        frames8.append(df.loc[(df['drug_name'] =='PS341+DMSO+'+str(concentration[i])) ])

#9
def extract_SAHA(frames9,concentration):
    for i in range(len(concentration)):
        frames9.append(df.loc[(df['drug_name'] =='SAHA+SAHA+'+str(concentration[i])) ])
    for i in range(len(concentration)):
        frames9.append(df.loc[(df['drug_name'] =='SAHA+DMSO+'+str(concentration[i])) ])
    
def extract_Apicidin(frames10,concentration):
    for i in range(len(concentration)):
        frames10.append(df.loc[(df['drug_name'] =='Apicidin+Apicidin+'+str(concentration[i])) ])
    for i in range(len(concentration)):
        frames10.append(df.loc[(df['drug_name'] =='Apicidin+DMSO+'+str(concentration[i])) ])

# %%
if 'Etoposide' in namelist:
        frames1=[]
        extract_any_drug_set(frames1,concentration,'Etoposide',"Etoposide")
        global Etoposide
        Etoposide=pd.concat(frames1)
        set_training_label(Etoposide,training_label,'Etoposide')
    

    if 'Gemcitabine' in namelist:
        frames2=[]
        extract_any_drug_set(frames2,concentration,'Gemcitabine',"Gemcitabine")
        global Gemcitabine
        Gemcitabine=pd.concat(frames2)
        set_training_label(Gemcitabine,training_label,'Gemcitabine')

    if 'Paclitaxel' in namelist:
        frames3=[]
        global Paclitaxel
        extract_any_drug_set(frames3,concentration,"Paclitaxel","Paclitaxel")
        
        Paclitaxel=pd.concat(frames3)
        set_training_label(Paclitaxel,training_label,'Paclitaxel')
    
    if 'Vinblastine' in namelist:
        frames4=[]
        extract_any_drug_set(frames3,concentration,"Vinblastine","Vinblastine")
        global Vinblastine
        Vinblastine=pd.concat(frames4)
        set_training_label(Vinblastine,training_label,'Vinblastine')
    
    #5
    if 'AUY922' in namelist:
        frames5=[]
        extract_any_drug_set(frames3,concentration,"Vinblastine","Vinblastine")
        global AUY922
        AUY922=pd.concat(frames5)
        set_training_label(AUY922,training_label,'AUY922')
    #6
    if '17AAG' in namelist:
        frames6=[]
        extract_any_drug_set(frames3,concentration,"Vinblastine","Vinblastine")
        global _17AAG
        _17AAG=pd.concat(frames6)
        set_training_label(_17AAG,training_label,'17AAG')
    #7
    if 'MG132' in namelist:
        frames7=[]
        extract_any_drug_set(frames3,concentration,"Vinblastine","Vinblastine")
        global MG132
        MG132=pd.concat(frames7)
        set_training_label(MG132,training_label,'MG132')
    #8
    if 'PS341' in namelist:
        frames8=[]
        extract_PS341(frames8,concentration)
        global PS341
        PS341=pd.concat(frames8)
        set_training_label(PS341,training_label,'PS341')
    #9
    if 'SAHA' in namelist:
        frames9=[]
        extract_SAHA(frames9,concentration)
        global SAHA
        SAHA=pd.concat(frames9)
        set_training_label(SAHA,training_label,'SAHA')

    #10
    if 'Apicidin' in namelist:
        frames10=[]
        extract_Apicidin(frames10,concentration)
        global Apicidin
        Apicidin=pd.concat(frames10)
        set_training_label(Apicidin,training_label,'Apicidin')
