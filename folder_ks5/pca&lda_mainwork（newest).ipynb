# %%
#a code block that deals with concentration and drug names
#we do not use this block for now.

import pandas as pd
f1 = pd.read_csv('B.csv')
f2 = pd.read_csv('C.csv')
f3=pd.read_csv('D.csv')
f4=pd.read_csv('E.csv')
f5=pd.read_csv('A_ks5.csv')
file = [f1,f2,f3,f5]
train = pd.concat(file,axis=1)
train.to_csv("train.csv", index=0, sep=',')

# %%
#do some further processing with "A" because there are some data error in it
def remove_extradots(string):
    counter=0
    lst=[]
    for i in range(len(string)):
        if string[i]=='.' and counter<1 :
            lst.append(string[i])
            counter+=1
        elif string[i]!='.':
            lst.append(string[i])
    res="".join(lst)
    return res



import csv
res_list=[]
print(remove_extradots("-0.29444.2"))
with open('A_ks5.csv') as file2:
    reader=csv.reader(file2)

    for row in reader:
        data=[]
        for i in range(len(row)):
            
            data.append(remove_extradots(row[i]))
        res_list.append(data)
    


with open('modified_A.csv', 'w') as file3:
    writer = csv.writer(file3)
    writer.writerows(res_list)
file3.close()
# Out:
# -0.294442

# %%
#test file A
import pandas as pd
df_A=pd.read_csv("A_ks5.csv")
df_A.shape
#df_A2=pd.read_csv("A_modified.csv")
#df_A2.shape
# Out:
# (767, 239)

# %%
#a block that is used to concate the drug names(drug combinations and related concentration)

import csv
res_list=[]
with open('train.csv', 'r') as file:
    reader = csv.reader(file)
    
    for row in reader:
        data=[]
        data.append(row[0]+'+'+row[1]+"+"+row[2])
        res_list.append(data)

        
        
with open('concatenated.csv', 'w') as file2:
    writer = csv.writer(file2)
    writer.writerows(res_list)

# %%
#a block that is used to concate concentration and ks numbers.
import pandas as pd
f1 = pd.read_csv('concatenated.csv')
#f2 = pd.read_csv('C.csv')
f3=pd.read_csv('D.csv')
f4=pd.read_csv('E.csv')
f5=pd.read_csv('modified_A.csv')
file = [f1,f5]
train = pd.concat(file,axis=1)
train.to_csv("train3.csv", index=0, sep=',')

# %%
#a block that sets the fields for the drug data
import csv
fields=['drug_name','default']
for i in range(1,239):
    fields.append('ks'+str(i))
rows=[]
with open('train3.csv', 'r') as file:
    reader = csv.reader(file)
    
    for row in reader:
        rows.append(row)

        
        
with open('drug_withfields2.csv', 'w') as file2:
    writer = csv.writer(file2)
    writer.writerow(fields)
    writer.writerows(rows)

# %%
#do some further processing with "drug_withfields" because there are still some data error in it
def remove_extradots(string):
    counter=0
    lst=[]
    for i in range(len(string)):
        if string[i]=='.' and counter<1 :
            lst.append(string[i])
            counter+=1
        elif string[i]!='.':
            lst.append(string[i])
    res="".join(lst)
    return res



import csv
res_list=[]
print(remove_extradots("-0.29444.2"))
with open('drug_withfields2.csv') as file2:
    reader=csv.reader(file2)

    for row in reader:
        data=[]
        for i in range(len(row)):
            
            data.append(remove_extradots(row[i]))
        res_list.append(data)
    


with open('drug_with_fields.csv', 'w') as file3:
    writer = csv.writer(file3)
    writer.writerows(res_list)
file3.close()
# Out:
# -0.294442

# %%
#we take etoposide and palitaxel out. 
df=pd.read_csv('drug_with_fields.csv')
df11=df.loc[(df['drug_name'] =='Etoposide+Etoposide+1') ]
df12=df.loc[(df['drug_name'] =='Etoposide+Etoposide+2') ]
df13=df.loc[(df['drug_name'] =='Etoposide+Etoposide+3') ]
df14=df.loc[(df['drug_name'] =='Etoposide+Etoposide+4') ]
df15=df.loc[(df['drug_name'] =='Etoposide+Etoposide+5') ]
df16=df.loc[(df['drug_name'] =='Etoposide+Etoposide+6') ]
df21=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+1') ]
df22=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+2') ]
df23=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+3') ]
df24=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+4') ]
df25=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+5') ]
df26=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+6') ]
df31=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+1')]
df32=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+2')]
df33=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+3')]
df34=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+4')]
df35=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+5')]
df36=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+6')]
df41=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+1') ]
df42=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+2') ]
df43=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+3') ]
df44=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+4') ]
df45=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+5') ]
df46=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+6') ]
#df51=df.loc[(df['drug_name'] =='DMSO+DMSO+1') ]
#df52=df.loc[(df['drug_name'] =='DMSO+DMSO+2') ]
##df53=df.loc[(df['drug_name'] =='DMSO+DMSO+3') ]
#df54=df.loc[(df['drug_name'] =='DMSO+DMSO+4') ]
#df55=df.loc[(df['drug_name'] =='DMSO+DMSO+5') ]
#df56=df.loc[(df['drug_name'] =='DMSO+DMSO+6') ]


frames = [df11, df12,df13,df14,df15,df16,df21,df22,df23,df24,df25,df26,df31,df32,df33,df34,df35,df36,df41,df42,df43,df44,df45,df46]

e_and_p = pd.concat(frames)
#etoposide and paclitaxel combination. 
e_and_p
# Out:
#                    drug_name  default       ks1       ks2       ks3       ks4  \
# 0      Etoposide+Etoposide+1        0 -0.930830 -0.494530 -0.571140 -0.799580
# 2      Etoposide+Etoposide+2        0 -0.925000 -0.400790 -0.318350 -0.538470
# 4      Etoposide+Etoposide+3        0 -0.612500  0.097551 -0.134220  0.145150
# 6      Etoposide+Etoposide+4        0  0.097702 -0.056872  0.052675  0.092692
# 8      Etoposide+Etoposide+5        0  0.086735  0.059167  0.080377  0.131050
# 10     Etoposide+Etoposide+6        0  0.101740 -0.058135  0.029234  0.118040
# 144  Paclitaxel+Paclitaxel+1        0 -0.300830 -0.840350 -1.000000 -0.997500
# 146  Paclitaxel+Paclitaxel+2        0 -0.701670  0.215270  0.294070  0.091438
#  -1.02425884 -1.31976062 -1.17286077  0.6155541  -0.17981904 -0.63297802
#  -1.94782592 -0.93715307 -1.46937759 -1.54157145 -1.33879463  1.43572481
#   1.22010978 -1.57675148 -1.60045349  1.52874304 -1.70305523  1.56270736
#  -1.52662889 -1.57887544 -1.63377604 -1.56799346 -1.47232771  1.33955212
#  -1.56775773 -1.57675567 -1.47233451  0.2309783   0.42431296  0.76109341
#   1.001332   -0.41890092  0.27970533 -0.53020268  0.32856802 -0.30487888
#   0.92493433 -0.84914634  0.27149632  0.23098157  0.92494271 -0.98965072
#  -0.9667245  -0.99880004  0.82279653]

# %%
#see that again
from sklearn.decomposition import PCA
pca = PCA(n_components = 0.99)
pca.fit(X_drug)
reduced = pca.transform(X_drug)
print(len(X_drug[0]))
print(len(reduced[0]))
print(pca.explained_variance_ratio_)
# Out:
# 237
# 13
# [0.44053213 0.2954552  0.11318077 0.05610314 0.02841037 0.01561718
#  0.01144243 0.00847993 0.00645861 0.00559623 0.00505356 0.00283523
#  0.00251545]

# %%
#we take etoposide and palitaxel out. 
df=pd.read_csv('drug_with_fields.csv')
df11=df.loc[(df['drug_name'] =='Etoposide+Etoposide+1') ]
df12=df.loc[(df['drug_name'] =='Etoposide+Etoposide+2') ]
df13=df.loc[(df['drug_name'] =='Etoposide+Etoposide+3') ]
df14=df.loc[(df['drug_name'] =='Etoposide+Etoposide+4') ]
df15=df.loc[(df['drug_name'] =='Etoposide+Etoposide+5') ]
df16=df.loc[(df['drug_name'] =='Etoposide+Etoposide+6') ]
df21=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+1') ]
df22=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+2') ]
df23=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+3') ]
df24=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+4') ]
df25=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+5') ]
df26=df.loc[(df['drug_name'] =='Paclitaxel+Paclitaxel+6') ]
df31=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+1')]
df32=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+2')]
df33=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+3')]
df34=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+4')]
df35=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+5')]
df36=df.loc[(df['drug_name'] =='Etoposide+Paclitaxel+6')]
df41=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+1') ]
df42=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+2') ]
df43=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+3') ]
df44=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+4') ]
df45=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+5') ]
df46=df.loc[(df['drug_name'] =='Paclitaxel+Etoposide+6') ]
df51=df.loc[(df['drug_name'] =='DMSO+DMSO+1') ]
df52=df.loc[(df['drug_name'] =='DMSO+DMSO+2') ]
# 130 -0.052602 -0.120470 -0.120970  0.051104  0.114700  0.097026 -0.079702
# 24   0.144050 -0.641330 -0.617780 -0.206660  0.290100  0.157730 -0.151070
# 26  -0.294710  0.363940  0.299500  0.347530 -0.392750 -0.471340 -0.406250
# 28  -0.025455 -0.045671 -0.043672  0.030062  0.098858  0.063011 -0.089129
# 30  -0.034935 -0.099975 -0.100070  0.040860  0.186760  0.164590 -0.066861
# 32  -0.036996 -0.106860 -0.108240  0.028553  0.143890  0.111840 -0.063498
# 34  -0.043650 -0.109740 -0.115690  0.059551  0.128050  0.093462 -0.065218
#
#         ks238
# 0    0.244280
# 2    0.410580
# 4    0.358140
# 6   -0.056829
# 8   -0.047169
# 10  -0.039229
# 144 -0.573130
# 146  0.206270
# 148  0.039240
# 150  0.103550
# 152 -0.049703
# 154 -0.042617
# 120  0.213200
# 122  0.373620
# 124  0.289440
# 126  0.097613
# 128 -0.052766
# 130 -0.041883
# 24   0.081429
# 26   0.367560
# 28  -0.021140
# 30  -0.060081
# 32  -0.046282
# 34  -0.046354
#
# [24 rows x 240 columns]

# %%
#see DMSO
e_and_p.iloc[24:,:]
#e_and_p.shape
#72 rows
#dmso each concentration 8 samples. 6*8=48
# Out:
#        drug_name  default       ks1       ks2       ks3       ks4       ks5  \
# 360  DMSO+DMSO+1        0 -0.050000  0.088765  0.045054  0.201330  0.026972
# 361  DMSO+DMSO+1        0  0.023127  0.040922  0.049528  0.045583 -0.032832
# 372  DMSO+DMSO+1        0  0.078791 -0.021792  0.078186 -0.032950  0.051335
# 373  DMSO+DMSO+1        0  0.035676  0.034145  0.071192 -0.045774  0.073008
# 744  DMSO+DMSO+1        0 -0.065346  0.120600  0.065723  0.168690  0.065016
# 745  DMSO+DMSO+1        0  0.034188  0.105910  0.118920  0.033165  0.071428
# 756  DMSO+DMSO+1        0 -0.033766 -0.020477  0.046106 -0.057283 -0.044341
# 757  DMSO+DMSO+1        0  0.026336  0.038513  0.056108 -0.044023  0.067181
# 362  DMSO+DMSO+2        0 -0.025911  0.026684  0.027831  0.096734 -0.024139
# 363  DMSO+DMSO+2        0  0.053535 -0.024524  0.028197  0.047200  0.024892
# 374  DMSO+DMSO+2        0  0.036716  0.030891  0.040907 -0.074596  0.027648
# 375  DMSO+DMSO+2        0  0.015952 -0.054167 -0.032143 -0.090357 -0.049167
# 746  DMSO+DMSO+2        0 -0.042973 -0.025315 -0.043370 -0.045655 -0.043962
# 747  DMSO+DMSO+2        0  0.062548  0.056347  0.076880  0.067773  0.044976
# 758  DMSO+DMSO+2        0  0.030810 -0.034466 -0.021589  0.019510 -0.033170
# 759  DMSO+DMSO+2        0  0.042815 -0.042039 -0.044535 -0.046190 -0.056454
# 364  DMSO+DMSO+3        0  0.082548 -0.038465  0.051054  0.029949  0.032434
# 365  DMSO+DMSO+3        0 -0.144430 -0.101920 -0.397750  0.295320 -0.449850
# 376  DMSO+DMSO+3        0  0.021702  0.028221  0.090171 -0.068765  0.046430
# 369 -0.042241 -0.057107  0.022555  0.027466 -0.016811 -0.040342  0.033314
# 380 -0.031277 -0.040819  0.036737 -0.043314 -0.053240 -0.036934  0.051070
# 381  0.030397  0.026563  0.031572 -0.075066 -0.077302 -0.021560  0.054184
# 752  0.051305  0.051116  0.047626 -0.058724 -0.069231 -0.034795 -0.027756
# 753 -0.028857 -0.022868 -0.024225  0.039671  0.061318  0.030601 -0.025950
# 764  0.044161  0.033478 -0.025664 -0.023576 -0.032045  0.024038  0.021119
# 765  0.028140 -0.025318  0.033267 -0.049073 -0.051091 -0.043315  0.020061
# 370 -0.067341 -0.069312  0.021190  0.062695  0.053049  0.030970 -0.019994
# 371 -0.042032 -0.051583  0.041094 -0.028517 -0.032949 -0.037583  0.051173
# 382  0.039642  0.033877  0.033822 -0.057308 -0.062674 -0.018630  0.040258
# 383  0.053810  0.046548  0.040714  0.031270  0.034286 -0.026349 -0.024881
# 754  0.038929  0.049717 -0.035263  0.024070  0.033969  0.039007 -0.029900
# 755 -0.026051 -0.035638  0.027777  0.032834  0.049933 -0.028290 -0.025389
# 766  0.027821  0.037879 -0.017844  0.032547  0.040583 -0.021958 -0.037541
# 767  0.084520  0.080177  0.037045  0.029949  0.052727 -0.040000 -0.051263
#
# [48 rows x 240 columns]

# %%
#a code block that is used to deal with the data using PCA models(dimensionality reduction)
import pandas as pd
import plotly.express as px
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

X_drug = e_and_p.iloc[:, 3:240].values

X_drug = StandardScaler().fit_transform(X_drug)

pca_drug = PCA(n_components=6)
components = pca_drug.fit_transform(X_drug)
X_drug=pca_drug.fit_transform(X_drug)
principalDf = pd.DataFrame(data = components
             , columns =['principal component 1', 'principal component 2','principal component 3','principal component 4','principal component 5','principal component 6'])
principalDf
# Out:
#     principal component 1  principal component 2  principal component 3  \
# 0               31.082573               3.708360              -7.171873
# 1               29.359152              -7.890841              -9.552274
# 2               18.568658             -17.974591               6.295521
# 3               -5.159766               5.290520              -4.634525
# 4               -6.798756               3.904579              -3.760283
# ..                    ...                    ...                    ...
# 67              -4.647186              -0.237671               1.153413
# 68              -5.284041               0.996069               1.830081
# 69              -5.047084               0.820461               0.694562
# 70              -5.677845               0.318496               2.240056
# 71              -5.673866              -2.792318               4.285191
#
#     principal component 4  principal component 5  principal component 6
# 0               -9.549675              -4.137955              -1.071317
# 1                0.030481               2.126325              -3.859415
# 2               -2.339402              -1.171000               2.078801
# 3                1.115174              -4.764829               1.826283
# 4                0.467714              -4.275147               1.597271
# ..                    ...                    ...                    ...
# 67              -3.798161               2.817764               1.064542
# 68              -1.235920               2.205623               0.586267
# 69              -0.726723               0.343034              -0.935564
# 70              -1.840480               1.899189              -1.029665
# 71              -1.064438              -0.084762               0.290524
#
# [72 rows x 6 columns]

# %%
#see the principalDf
principalDf.iloc[0,:]
# Out:
# principal component 1    31.082573
# principal component 2     3.708360
# principal component 3    -7.171873
# principal component 4    -9.549675
# principal component 5    -4.137955
# principal component 6    -1.071317
# Name: 0, dtype: float64

# %%
#wipe out those whose concentration is not valid
def get_centroid(point_lst):
    x_sum=0
    y_sum=0
    z1_sum=0
    z2_sum=0
    z3_sum=0
    z4_sum=0


    for i in range(len(point_lst)):
        x_sum+=point_lst[i][0]
        y_sum+=point_lst[i][1]
        z1_sum+=point_lst[i][2]
        z2_sum+=point_lst[i][3]
        z3_sum+=point_lst[i][4]
        z4_sum+=point_lst[i][5]


    x_mean=x_sum/len(point_lst)
    y_mean=y_sum/len(point_lst)
    z1_mean=z1_sum/len(point_lst)
    z2_mean=z2_sum/len(point_lst)
    z3_mean=z3_sum/len(point_lst)
    z4_mean=z4_sum/len(point_lst)
    centroid=[]
    centroid.append(x_mean)
    centroid.append(y_mean)
    centroid.append(z1_mean)
    centroid.append(z2_mean)
    centroid.append(z3_mean)
    centroid.append(z4_mean)
    centroid.append(point_lst[0][-1])
    return centroid

# %%
#calculate DMSO circle
p_DMSO=[]
for i in range(24,72):
    p_DMSO.append([principalDf.iloc[i,:][0],principalDf.iloc[i,:][1],principalDf.iloc[i,:][2],principalDf.iloc[i,:][3],principalDf.iloc[i,:][4],principalDf.iloc[i,:][5],'DMSO+DMSO'])
p_DMSO[0]
p=[]
for i in range(24):
    p.append([principalDf.iloc[i,:][0],principalDf.iloc[i,:][1],principalDf.iloc[i,:][2],principalDf.iloc[i,:][3],principalDf.iloc[i,:][4],principalDf.iloc[i,:][5]])
len(p)
p_combi=p[12:]
len(p_combi)
#print(p_combi)
#for j in range(6):
   # p_combi[j].append('Etoposide+Paclitaxel')
#for k in range(6,12):
   # p_combi[k].append('Paclitaxel+Etoposide')
#print(p_combi)
# Out:
# 12

# %%
#get the centroid of DMSO
centroid_DMSO=get_centroid(p_DMSO)
centroid_DMSO
# Out:
# [-4.1193680866313676,
#  -0.026229118730960354,
#  0.7666683982491062,
#  -0.7044872053265215,
#  0.9776421774336047,
#  -0.49900206671557074,
#  'DMSO+DMSO']

# %%
#get the DMSO circle
#
#
#
#max_dist we got
from math import sqrt
def euclidean_distance(row1, row2):
    distance =0
	#print(len(row1)-1) this is to ensure that we calculate 6 points
    for i in range(len(row1)-1):

	

        distance += (row1[i] - row2[i])**2
    return sqrt(distance)

	

import math
dist_lst=[]
for i in range(len(p_DMSO)):

    dist_lst.append(euclidean_distance(centroid_DMSO,p_DMSO[i]))
#print(dist_lst)
print(len(dist_lst))
dist_lst.sort()
ave_dist=sum(dist_lst)/len(dist_lst)

max_dist=(dist_lst[-1]+dist_lst[-2]+dist_lst[-3]+dist_lst[-4]+dist_lst[-5])/5.0
max_dist*=2
print(max_dist)
print(dist_lst)
# Out:
# 48
# 18.07708674622705
# [1.4753125253420105, 1.4933932297979775, 1.5640837756948445, 1.8546864016601474, 1.9062898842857638, 2.170861691093922, 2.2543458071220543, 2.2878386773685557, 2.2990159448984766, 2.301054732783932, 2.3524079886188516, 2.3885572804175195, 2.401648831144469, 2.5035826527476894, 2.5255177849008614, 2.5496208859665104, 2.672056808699318, 2.7427252317703537, 2.7582985512942018, 2.7632673510070727, 2.7873889374155545, 2.816758794311446, 2.896996411539966, 2.9048721322565396, 2.909668806327338, 2.927278786499856, 3.0834357339547322, 3.0880603873051053, 3.1807733692848617, 3.2308473674367497, 3.3224073438547865, 3.3573531307602438, 3.4836018298189937, 3.5100937126536587, 3.535398303671353, 3.5699846314812094, 3.5870201902761267, 3.5999164970746333, 3.937317384414007, 3.9842696854199198, 4.041602663487789, 4.4223316334833145, 4.7132597178806614, 4.932476812093257, 5.13300079629058, 5.372852032485674, 7.472562429843531, 22.281824794854582]

# %%
#still wiping out not effective concentration
p=[]
for i in range(24):
    p.append([principalDf.iloc[i,:][0],principalDf.iloc[i,:][1],principalDf.iloc[i,:][2],principalDf.iloc[i,:][3],principalDf.iloc[i,:][4],principalDf.iloc[i,:][5]])
for i in range(6):
    p[i].append('Etoposide')
for j in range(6):
    p[j+6].append('Paclitaxel')
for k in range(6):
    p[k+12].append('Etoposide+Paclitaxel')
for m in range(6):
    p[m+18].append("Paclitaxel+Etoposide")
#print(p)
dist_lst2=[]
for i in range(24):
    dist_lst2.append(euclidean_distance(centroid_DMSO,p[i]))
#print(dist_lst2)
#record the index
#then, according to the index, wipe out those same index in p
effect=[]
indexlst=[]
for i in range(12):
    dist=euclidean_distance(centroid_DMSO,p[i])
    
    if dist>max_dist:
        effect.append(p[i])
        indexlst.append(i)
#24 becomes 24
print(effect,len(effect),indexlst)
#1,2,3
#1,2,3,4
print(len(X_drug))

print(len(X_drug2[-1]))
print(len(indexlst))
# Out:
# [[31.082573374148907, 3.7083601625702647, -7.171873096303236, -9.54967536611297, -4.1379550817795545, -1.071317195315243, 'Etoposide'], [29.3591519376586, -7.890841269976076, -9.55227406987147, 0.030481160443819787, 2.12632457916015, -3.859414570139245, 'Etoposide'], [18.568658025902117, -17.97459127718217, 6.295520517742844, -2.3394024839944856, -1.171000455666021, 2.0788009277304, 'Etoposide'], [25.101164091268483, 28.69661798157474, 24.30365531282373, -3.4483973792283638, 2.028560481513741, 5.612168662390705, 'Paclitaxel'], [8.605018117407024, -11.40727016868823, -4.7480172837025005, 6.369350689381509, 9.211189238296168, 5.897233519491883, 'Paclitaxel'], [3.542536727276388, -18.07696696138169, 7.913874853828221, 3.851152847027281, -3.2560351081050154, -1.7180444564954356, 'Paclitaxel'], [4.876977618148952, -16.016701615986367, 4.707451943400009, 0.7711988528809964, -2.7787058858952336, -2.440035010170243, 'Paclitaxel']] 7 [0, 1, 2, 6, 7, 8, 9]
# 72
# 237
# 7

# %%
#again. computing distances.
#0-5  etoposide
#6-11 paclitaxel
#plus 12 first. then plus 18
import math
distance=[]
#between effective etoposide and combination (average distance)
for i in range(3):
    distance.append(euclidean_distance(p[indexlst[i]],p[i+12]))
distance=sum(distance)/len(distance)
print(distance)
distance2=[]
for j in range(3,7):
    distance2.append(euclidean_distance(p[indexlst[j]],p[j+6]))
distance2=sum(distance2)/len(distance2)
print(distance2)
#since distance<distance2, etoposide is more similar to the combination
# Out:
# 8.417336876344073
# 38.11402245284994

# %%
#the last set of the combination
distance3=[]
for m in range(3):
    distance3.append(euclidean_distance(p[indexlst[m]],p[m+18]))
print(distance3)
distance3=sum(distance3)/len(distance3)

distance4=[]
for n in range(3,7):
    distance4.append(euclidean_distance(p[indexlst[n]],p[n+12]))
distance4=sum(distance4)/len(distance4)
print(distance3,distance4)
#still etoposide is more effective. 
#one question 
#this time, conclusion: etoposide is more effective
# Out:
# [41.321383816873016, 24.292319961261015, 29.783819593407557]
# 31.79917445718053 39.39116074287088

# %%
#considering that the combination may not be effective
effect2=[]
indexlst2=[]
for i in range(12,24):
    dist2=euclidean_distance(centroid_DMSO,p[i])
    
    if dist2>max_dist:
        effect2.append(p[i])
        indexlst2.append(i)

print(effect2,indexlst2)
#
#1,2,3
#1,2,3,4
#above are for etoposide or paclitaxel
#1,2,3,4(1,2,3;1,2,3,4)
#1,2(1,2;1,2)
# Out:
# [[33.21618866607083, 12.793331792397534, -3.542650200444837, -11.122754501438424, -4.919627940352849, 0.7716647735700131, 'Etoposide+Paclitaxel'], [30.627237846608928, -7.645156483988682, -11.657266603634216, 1.1536221253639414, 3.2370699172558792, -2.3517574336034426, 'Etoposide+Paclitaxel'], [23.59759528891401, -15.354794710348491, -1.6173651535551534, 2.927777739020848, -1.9898991978841107, -1.3753460643182462, 'Etoposide+Paclitaxel'], [4.833586865381985, -15.912967042389031, 8.07652250189483, 1.9884645108988541, -3.775562111669105, -0.9256340737942234, 'Etoposide+Paclitaxel'], [23.015173786313806, 31.46260052811963, 1.4270313785255422, 16.771988196760553, 4.685782096799219, -6.310257687616724, 'Paclitaxel+Etoposide'], [12.742554852758321, -11.708775851669408, -3.4893161177177188, 6.4109617173341515, 5.3636591350257135, 10.682887849190129, 'Paclitaxel+Etoposide']] [12, 13, 14, 15, 18, 19]

# %%
#calculate every point in here



lst1=[]
lst2=[]
lst3=[]
lst4=[]
for i in range(len(indexlst)):
    if indexlst[i]<6:
        lst1.append(indexlst[i])
    else:
        lst2.append(indexlst[i]-6)
for j in range(len(indexlst2)):
    if indexlst2[j]<18:
        lst3.append(indexlst2[j]-12)
    else:
        lst4.append(indexlst2[j]-18)
#print(lst1,lst2,lst3,lst4)
intersectlst1=list(set(lst1)&set(lst2)&set(lst3))
intersectlst2=list(set(lst1)&set(lst2)&set(lst4))
print(intersectlst1,intersectlst2)

e1=0
p1=0
for i in range(len(intersectlst1)):
    if min(euclidean_distance(p[intersectlst1[i]],p[intersectlst1[i]+12]),euclidean_distance(p[intersectlst1[i]+6],p[intersectlst1[i]+12]))\
        ==euclidean_distance(p[intersectlst1[i]],p[intersectlst1[i]+12]):
        e1+=1
    else:
        p1+=1
e2=0
p2=0
for j in range(len(intersectlst2)):
    if min(euclidean_distance(p[intersectlst1[j]],p[intersectlst1[j]+18]),euclidean_distance(p[intersectlst1[j]+6],p[intersectlst1[j]+18]))\
        ==euclidean_distance(p[intersectlst1[j]],p[intersectlst1[j]+18]):
        e2+=1
    else:
        p2+=1
print(e1,p1,e2,p2)
et=e1+e2
pt=p1+p2
print(et,pt)



"""
min_l1=min(len(lst1),len(lst2),len(lst3))
if len(lst1)==min_l1:
    lst_1=lst1
elif len(lst2)==min_l1:
    lst_1=lst2
elif len(lst3)==min_l1:
    lst_1=lst3
#not the shortest list, but the overlapped list. 
min_l2=min(len(lst1),len(lst2),len(lst4))
if len(lst1)==min_l2:
    lst_2=lst1
elif len(lst2)==min_l2:
    lst_2=lst2
elif len(lst4)==min_l2:
    lst_2=lst3
print(lst_1,lst_2)
#for i in range(min_l1):
 #   if min(euclidean_distance(p[lst_1[i]]))
 """
# Out:
# [0, 1, 2] [0, 1]
# 3 0 0 2
# 3 2
# '\nmin_l1=min(len(lst1),len(lst2),len(lst3))\nif len(lst1)==min_l1:\n    lst_1=lst1\nelif len(lst2)==min_l1:\n    lst_1=lst2\nelif len(lst3)==min_l1:\n    lst_1=lst3\n#not the shortest list, but the overlapped list. \nmin_l2=min(len(lst1),len(lst2),len(lst4))\nif len(lst1)==min_l2:\n    lst_2=lst1\nelif len(lst2)==min_l2:\n    lst_2=lst2\nelif len(lst4)==min_l2:\n    lst_2=lst3\nprint(lst_1,lst_2)\n#for i in range(min_l1):\n #   if min(euclidean_distance(p[lst_1[i]]))\n '

# %%
#do distance comparison again(both effective)
"""
import math
distance=[]
#between effective etoposide and combination (average distance)
for i in range(3):
    #1,2,3
    distance.append(euclidean_distance(p[indexlst[i]],p[i+12]))
distance=sum(distance)/len(distance)
print(distance)
distance2=[]
for j in range(3,7):
    #1,2,3,4
    distance2.append(euclidean_distance(p[indexlst[j]],p[j+6]))
distance2=sum(distance2)/len(distance2)
print(distance2)
if distance<distance2:
    similar='Etoposide'
else:
    similar='Paclitaxel'
print(similar)
"""
# Out:
# "\nimport math\ndistance=[]\n#between effective etoposide and combination (average distance)\nfor i in range(3):\n    #1,2,3\n    distance.append(euclidean_distance(p[indexlst[i]],p[i+12]))\ndistance=sum(distance)/len(distance)\nprint(distance)\ndistance2=[]\nfor j in range(3,7):\n    #1,2,3,4\n    distance2.append(euclidean_distance(p[indexlst[j]],p[j+6]))\ndistance2=sum(distance2)/len(distance2)\nprint(distance2)\nif distance<distance2:\n    similar='Etoposide'\nelse:\n    similar='Paclitaxel'\nprint(similar)\n"

# %%
#do distance comparison again
"""
distance3=[]
for m in range(2):
    distance3.append(euclidean_distance(p[indexlst[m]],p[m+18]))

distance3=sum(distance3)/len(distance3)
#print(distance3)

distance4=[]
for n in range(3,5):
    distance4.append(euclidean_distance(p[indexlst[n]],p[n+12]))
distance4=sum(distance4)/len(distance4)
print(distance3,distance4)

#so still, etoposide is more similar
#the conclusion changes after the second problem got solved

#find similar drug response(below markdown)
if distance3<distance4:
    similar='Etoposide'
else:
    similar='Paclitaxel'
print(similar)
"""
# Out:
# "\ndistance3=[]\nfor m in range(2):\n    distance3.append(euclidean_distance(p[indexlst[m]],p[m+18]))\n\ndistance3=sum(distance3)/len(distance3)\n#print(distance3)\n\ndistance4=[]\nfor n in range(3,5):\n    distance4.append(euclidean_distance(p[indexlst[n]],p[n+12]))\ndistance4=sum(distance4)/len(distance4)\nprint(distance3,distance4)\n\n#so still, etoposide is more similar\n#the conclusion changes after the second problem got solved\n\n#find similar drug response(below markdown)\nif distance3<distance4:\n    similar='Etoposide'\nelse:\n    similar='Paclitaxel'\nprint(similar)\n"

# %% [markdown]
# # Since we calculated the distances twice and made comparisons twice, and we got that the distance between drug combination and etoposide is smaller that the distance between drug combination and paclitaxel,  we got that etoposide is a more similar single drug. (This time the conclusion changes. When I changed the number of components, the conclusion did not change. still, paclitaxel was more similar. But after I removed those drugs whose location is within the domain of DMSO control group, I found that etoposide is more similar to "Etoposide+Paclitaxel" drug combination. )

# %%
#see first version X_drug(but take only training data)
X_drug2
# Out:
# array([[-1.16687180e+00, -1.19894410e+00, -1.71147433e+00, ...,
#         -9.66724497e-01, -9.98800038e-01,  8.22796527e-01],
#        [-8.73089087e-01, -5.06056690e-01, -1.11445495e+00, ...,
#         -1.60132342e+00, -1.82926288e+00,  1.61316007e+00],
#        [ 6.88719855e-01, -1.36362786e-03,  4.48619579e-01, ...,
#         -1.12667836e+00, -8.83387780e-02,  1.36393178e+00],
#        ...,
#        [ 1.05031955e+00,  1.13084494e+00,  4.34054785e-01, ...,
#         -4.41268865e-01,  1.83732529e-01,  1.53957915e-01],
#        [ 8.66854222e-01,  8.33176624e-01,  5.10834344e-01, ...,
#          5.08658195e-01,  5.90676572e-01, -5.74397971e-01],
#        [ 5.44544516e-02,  2.54110339e-01,  2.47284733e-01, ...,
#          5.76749543e-01,  4.78512652e-01, -5.40720785e-01]])

# %%
#LDA model 
#from sklearn.lda import LDA
#lda = LDA(n_components=2)
#X_r2 = lda.fit(X, y).transform(X)
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
y=[]
for i in range(6):
    y.append('Etoposide')
for j in range(6):
    y.append("Paclitaxel")

lda = LinearDiscriminantAnalysis(n_components=None)
X_lda = lda.fit(X_drug2, y)
lda_var_ratios=lda.explained_variance_ratio_

# %%
# Create a function for lda to "select n components"
def select_n_components(var_ratio, goal_var: float) -> int:
    # Set initial variance explained so far
    total_variance = 0.0
    
    # Set initial number of features
    n_components = 0
    
    # For the explained variance of each feature:
    for explained_variance in var_ratio:
        
        # Add the explained variance to the total
        total_variance += explained_variance
        
        # Add one to the number of components
        n_components += 1
        
        # If we reach our goal level of explained variance
        if total_variance >= goal_var:
            # End the loop
            break
            
    # Return the number of components
    return n_components

# %%
select_n_components(lda_var_ratios, 0.95)
# Out:
# 1

# %%
#test iris
# Load the Iris flower dataset:
"""
from sklearn import datasets
iris = datasets.load_iris()
X = iris.data
y = iris.target
X
y
lda = LinearDiscriminantAnalysis(n_components=None)
X_lda = lda.fit(X, y)
lda_var_ratios = lda.explained_variance_ratio_
lda_var_ratios
select_n_components(lda_var_ratios, 0.95)
"""
# Out:
# '\nfrom sklearn import datasets\niris = datasets.load_iris()\nX = iris.data\ny = iris.target\nX\ny\nlda = LinearDiscriminantAnalysis(n_components=None)\nX_lda = lda.fit(X, y)\nlda_var_ratios = lda.explained_variance_ratio_\nlda_var_ratios\nselect_n_components(lda_var_ratios, 0.95)\n'

# %%
lda = LinearDiscriminantAnalysis(n_components=1)

# either use: lda.fit_transform(X, y)
X_r2 = lda.fit_transform(X_drug2, y)

## PREFERRED WAY
# or, use: lda.fit(X, y)
# followed by lda.transform(X)
lda.fit(X_drug2, y)
X_r2 = lda.transform(X_drug2)
X_r2
# Out:
# array([[-1.98134982],
#        [-1.48256598],
#        [-1.60992807],
#        [-0.51379718],
#        [-0.60565913],
#        [ 0.03630397],
#        [ 1.82678693],
#        [ 1.55918863],
#        [ 1.73790763],
#        [ 1.46824129],
#        [ 0.84298088],
#        [-1.27810916]])

# %%
#prepare training data and testing data
p=[]
for i in range(24):
    p.append([principalDf.iloc[i,:][0],principalDf.iloc[i,:][1],principalDf.iloc[i,:][2],principalDf.iloc[i,:][3],principalDf.iloc[i,:][4],principalDf.iloc[i,:][5]])

X_train=[]
for i in range(len(indexlst)):
    X_train.append(p[indexlst[i]])

y_train=[]
#for y setting, we also need to write a general function here.
for i in range(len(indexlst)):
    if indexlst[i]<6:
        y_train.append('Etoposide')
    else:
        y_train.append('Paclitaxel')
y_train
len(X_train)
p_combi_effect=[]
for i in range(len(indexlst2)):

    p_combi_effect.append(p[indexlst2[i]])
p_combi_effect=[]  
for i in range(12,24):
    p_combi_effect.append(p[i])
print(len(p_combi_effect))
p_combi_effect[0]
# Out:
# 12
# [33.21618866607083,
#  12.793331792397534,
#  -3.542650200444837,
#  -11.122754501438424,
#  -4.919627940352849,
#  0.7716647735700131]

# %%
#model
# make a prediction with a lda model on the dataset
from sklearn.datasets import make_classification
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
# define dataset
# define model
model = LinearDiscriminantAnalysis(n_components=1)
# fit model
model.fit(X_train,y_train)
# define new data
row = [0.12777556,-3.64400522,-2.23268854,-1.82114386,1.75466361,0.1243966,1.03397657,2.35822076,1.01001752,0.56768485]
# make a prediction
#yhat=model.predict([row])
yhat = model.predict(p_combi_effect)
# summarize prediction
print('Predicted Class: %s' % yhat)
cne=0
cnp=0
for i in range(len(yhat)):
    if yhat[i]=='Etoposide':
        cne+=1
    elif yhat[i]=='Paclitaxel':
        cnp+=1

if cne>cnp:
    similar_drug='Etoposide'
else:
    similar_drug="Paclitaxel"

print(similar_drug)
# Out:
# Predicted Class: ['Etoposide' 'Etoposide' 'Paclitaxel' 'Paclitaxel' 'Paclitaxel'
#  'Paclitaxel' 'Paclitaxel' 'Paclitaxel' 'Paclitaxel' 'Paclitaxel'
#  'Paclitaxel' 'Paclitaxel']
# Paclitaxel

# %%
#indexlst for the single drug. indexlst2 for the drug combination
print(indexlst)
print(indexlst2)
len(p)
p_combi_effect=[]
for i in range(len(indexlst2)):

    p_combi_effect.append(p[indexlst2[i]])
print(len(p_combi_effect))
# Out:
# [0, 1, 2, 6, 7, 8, 9]
# [12, 13, 14, 15, 18, 19]
# 6

# %%
#conclusion:
# PCA: etoposide :2 . paclitaxel: 0(PCA: etoposide)
#LDA: paclitaxel

# %%
#final conclusion and stats:
#PCA: ks5: etoposide:2 paclitaxel:0
# ks4: etoposide:2. paclitaxel:0
#ks3: etoposide:2 paclitaxel:0

#LDA: ks2: ks3:Paclitaxel ks4: Paclitaxel. ks5: Paclitaxel
print(len(indexlst),len(indexlst2))
# Out:
# 7 6
